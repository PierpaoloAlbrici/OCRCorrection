# %%
import pymongo
import string
from tqdm.notebook import tqdm
from collections import Counter 

client = pymongo.MongoClient('mongodb://localhost:27017')
db = client['vatican']
dataset = db['perturbedDataset']
wordsDataset = db['wordsDataset']

docs = list(dataset.find())

# %%
#wordsDataset.drop()
wordsDataset.count()
# Out:
# <ipython-input-2-ab340a24988d>:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   wordsDataset.count()
# 0

# %%
chars = "solenità'd\mczkwfhjuxgbvrpyq8192!#"
CHAR_INDEX = dict((c, i) for i, c in enumerate(chars))

def preprocess(s):
    out = ""
    for c in s.lower():
        if c in CHAR_INDEX.keys():
            out += c
        else:
            out += '#'
    return "".join(out)

# %%
word = dict()

for i, d in tqdm(enumerate(docs)):
    for j, s in enumerate(d['sentences']):
        for k, w in enumerate(s[0]):
            word.setdefault(s[1][k], []).append(preprocess(w))            
            
for wk in tqdm(word.keys()):
    item = dict(Counter(word.get(wk)))
    wordsDataset.insert_one({'word': preprocess(wk), 'occurrences': item})
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14564.0), HTML(value='')))

# %%
a = list(wordsDataset.find())
a
# Out:
# [{'_id': ObjectId('60e57ab457a8f66820acfb06'),
#   'word': 'solennità',
#   'occurrences': {'solennità': 41, 'solenpnità': 1, "solennita'̀": 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb07'),
#   'word': "dell\\'immacolata",
#   'occurrences': {"dell\\'immacolata": 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb08'),
#   'word': 'concezione',
#   'occurrences': {'concezione': 7, 'conceziohe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb09'),
#   'word': 'della',
#   'occurrences': {'della': 1724,
#    'dellk': 1,
#    'delbla': 2,
#    'dsella': 1,
#    'dellxa': 2,
#    'drlla': 1,
#    'dellla': 2,
#    'dulla': 1,
#    'mdella': 2,
#    'dqlla': 1,
#    'djlla': 1,
#    'delll': 1,
#    'dbella': 1,
#    'deglla': 1,
#    'dellfa': 1,
#    'derla': 1,
#    'detla': 1,
#    'delila': 1,
#    'delsla': 1,
#    'dnlla': 1,
#    'dxella': 1,
#    'delma': 1,
#    'detlla': 1,
#    'dellra': 1,
#    'dtella': 2,
#    'dellva': 1,
#    'zdella': 1,
#    'drella': 1,
#    'dzella': 1,
#    'bdella': 1,
#    'kella': 1,
#    'delrla': 1,
#    'dellza': 1,
#    'dglla': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0a'),
#   'word': 'beata',
#   'occurrences': {'bekata': 1, 'beata': 15}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0b'),
#   'word': 'vergine',
#   'occurrences': {'vergine': 21, 'vergiwe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0c'),
#   'word': 'maria',
#   'occurrences': {'maria': 138, 'umaria': 1, 'mxaria': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0d'),
#   'word': 'omelia',
#   'occurrences': {'omelia': 44, 'omelya': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0e'),
#   'word': 'del',
#   'occurrences': {'del': 1498,
#    'dpl': 2,
#    'detl': 1,
#    'dfel': 1,
#    'dkl': 1,
#    'dekl': 2,
#    'deal': 1,
#    'doel': 1,
#    'deql': 2,
#    'nel': 1,
#    'odel': 1,
#    'hdel': 2,
#    'wel': 1,
#    'deq': 1,
#    'deh': 1,
#    'ddel': 2,
#    'dpel': 2,
#    'decl': 1,
#    'dgel': 1,
#    'dfl': 1,
#    'duel': 1,
#    'def': 1,
#    'lel': 1,
#    'dell': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb0f'),
#   'word': 'santo',
#   'occurrences': {'santo': 155, 'sbnto': 1, 'sante': 1, 'sanvto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb10'),
#   'word': 'padre',
#   'occurrences': {'padre': 111, 'padoe': 1, 'padrre': 1, 'qadre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb11'),
#   'word': 'giovanni',
#   'occurrences': {'giovanni': 103, 'egiovanni': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb12'),
#   'word': 'xxiii',
#   'occurrences': {'xxiii': 48}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb13'),
#   'word': 'basilica',
#   'occurrences': {'basilica': 82, 'basipica': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb14'),
#   'word': 'vaticana',
#   'occurrences': {'vaticana': 102,
#    'vatiuana': 1,
#    'vaticanf': 1,
#    'vaticans': 2,
#    'vaticzna': 1,
#    'vatpicana': 1,
#    'dvaticana': 1,
#    'vaticanka': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb15'),
#   'word': 'lunedì',
#   'occurrences': {'lunedì': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb16'),
#   'word': '#',
#   'occurrences': {'#': 9416}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb17'),
#   'word': '8',
#   'occurrences': {'8': 33}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb18'),
#   'word': 'dicembre',
#   'occurrences': {'dicembre': 30, 'dirembre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb19'),
#   'word': '1982',
#   'occurrences': {'1982': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1a'),
#   'word': 'diletti',
#   'occurrences': {'diletti': 170,
#    'dizletti': 1,
#    'diietti': 1,
#    'dilettv': 1,
#    'yiletti': 1,
#    'diaetti': 1,
#    'diledtti': 1,
#    'idiletti': 1,
#    'duiletti': 1,
#    'dileiti': 1,
#    'diretti': 1,
#    'diletsti': 1,
#    'dinetti': 1,
#    'dizetti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1b'),
#   'word': 'figli',
#   'occurrences': {'figyi': 1,
#    'figli': 266,
#    'figgli': 1,
#    'figlp': 1,
#    'sfigli': 1,
#    'jigli': 1,
#    'frigli': 1,
#    'fiyli': 1,
#    'rfigli': 1,
#    'figwli': 1,
#    'figci': 1,
#    'fhigli': 1,
#    'figlh': 1,
#    'fihli': 1,
#    'fjigli': 1,
#    'mfigli': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1c'),
#   'word': 'nostri',
#   'occurrences': {'nostri': 159, 'nosttri': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1d'),
#   'word': '!',
#   'occurrences': {'!': 271}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1e'),
#   'word': 'per',
#   'occurrences': {'per': 1121,
#    'pen': 1,
#    'pir': 1,
#    'rer': 1,
#    'pwer': 1,
#    'pser': 1,
#    'pxr': 1,
#    'peer': 2,
#    'pem': 1,
#    'eper': 1,
#    'perr': 1,
#    'pcr': 1,
#    'gper': 1,
#    'pyr': 1,
#    'pee': 1,
#    'peur': 1,
#    'iper': 1,
#    'pekr': 1,
#    'hper': 1,
#    'pef': 1,
#    'pet': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb1f'),
#   'word': 'ogni',
#   'occurrences': {'ogni': 211, 'oygni': 1, 'ognni': 2, 'obni': 1, 'orgni': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb20'),
#   'word': 'giorno',
#   'occurrences': {'giorno': 62, 'gworno': 1, 'siorno': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb21'),
#   'word': 'vita',
#   'occurrences': {'vita': 316,
#    'vitn': 1,
#    'vibta': 1,
#    'lita': 1,
#    'vnta': 1,
#    'vitja': 1,
#    'yita': 1,
#    'pvita': 1,
#    'cvita': 1,
#    'vikta': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb22'),
#   'word': 'il',
#   'occurrences': {'il': 1849,
#    'gl': 2,
#    'in': 3,
#    'cl': 2,
#    'al': 1,
#    'jl': 2,
#    'gil': 2,
#    'ib': 1,
#    'is': 2,
#    'wil': 1,
#    'ihl': 1,
#    'iu': 2,
#    'iml': 2,
#    'til': 2,
#    'im': 1,
#    'ol': 1,
#    'ig': 1,
#    'itl': 1,
#    'ip': 1,
#    'sil': 1,
#    'vl': 1,
#    'ifl': 2,
#    'tl': 1,
#    'ix': 1,
#    'isl': 1,
#    'ih': 1,
#    'eil': 1,
#    'ic': 1,
#    'icl': 1,
#    'idl': 1,
#    'ikl': 1,
#    'fl': 2,
#    'hil': 1,
#    'ij': 1,
#    'iw': 1,
#    'oil': 1,
#    'iv': 1,
#    'qil': 1,
#    'iq': 1,
#    'iel': 1,
#    'ii': 1,
#    'igl': 2,
#    'it': 1,
#    'xil': 1,
#    'vil': 1,
#    'if': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb23'),
#   'word': 'signore',
#   'occurrences': {'signore': 201,
#    'signnore': 1,
#    'sighore': 1,
#    'signorbe': 1,
#    'signotre': 1,
#    'sigqnore': 1,
#    'sigjore': 1,
#    'signxre': 1,
#    'signoert': 1,
#    'qsignore': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb24'),
#   'word': 'riserva',
#   'occurrences': {'riserva': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb25'),
#   'word': 'alle',
#   'occurrences': {'alle': 173, 'rlle': 1, 'aloe': 1, 'ralle': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb26'),
#   'word': 'anime',
#   'occurrences': {'anime': 121}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb27'),
#   'word': 'nostre',
#   'occurrences': {'nostre': 83, 'nostri': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb28'),
#   'word': 'le',
#   'occurrences': {'le': 831,
#    'kle': 1,
#    'vle': 1,
#    'gle': 2,
#    'ele': 1,
#    'ls': 1,
#    'lp': 1,
#    'lce': 1,
#    'lfe': 1,
#    'ie': 1,
#    'sle': 1,
#    'ne': 1,
#    'lqe': 1,
#    'me': 1,
#    'lge': 1,
#    'lte': 2,
#    'lse': 1,
#    'lae': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb29'),
#   'word': 'sue',
#   'occurrences': {'sue': 77}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2a'),
#   'word': 'consolazioni',
#   'occurrences': {'consolazioni': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2b'),
#   'word': 'e',
#   'occurrences': {'e': 4315}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2c'),
#   'word': 'grazie',
#   'occurrences': {'grazie': 22}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2d'),
#   'word': '#',
#   'occurrences': {'#': 3680}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2e'),
#   'word': 'questo',
#   'occurrences': {'questo': 452,
#    'queslo': 1,
#    'quesbo': 1,
#    'questj': 1,
#    'nquesto': 1,
#    'quesho': 1,
#    'quyesto': 1,
#    'quebsto': 1,
#    'quzesto': 1,
#    'qudesto': 1,
#    'xquesto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb2f'),
#   'word': 'dedicato',
#   'occurrences': {'dedicato': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb30'),
#   'word': 'al',
#   'occurrences': {'al': 571,
#    'aql': 1,
#    'axl': 1,
#    'nal': 1,
#    'agl': 1,
#    'sal': 1,
#    'gl': 1,
#    'an': 1,
#    'ar': 1,
#    'arl': 1,
#    'ajl': 1,
#    'cal': 1,
#    'ak': 1,
#    'fl': 1,
#    'awl': 1,
#    'atf': 1,
#    'aal': 1,
#    'ap': 1,
#    'adl': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb31'),
#   'word': 'culto',
#   'occurrences': {'culto': 43, 'chulto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb32'),
#   'word': 'di',
#   'occurrences': {'di': 4508,
#    'pi': 2,
#    'dk': 3,
#    'fdi': 2,
#    'ydi': 1,
#    'ndi': 1,
#    'zi': 1,
#    'gdi': 3,
#    'dyi': 2,
#    'dki': 1,
#    'dh': 2,
#    'dwi': 2,
#    'ldi': 1,
#    'dd': 1,
#    'udi': 1,
#    'adi': 2,
#    'odi': 1,
#    'bdi': 1,
#    'oi': 2,
#    'dw': 1,
#    'dx': 2,
#    'doi': 2,
#    'vi': 1,
#    'dz': 2,
#    'dgi': 1,
#    'ti': 2,
#    'dni': 2,
#    'hdi': 3,
#    'df': 6,
#    'dmi': 3,
#    'dci': 2,
#    'rdi': 2,
#    'ii': 1,
#    'jdi': 1,
#    'kdi': 1,
#    'dn': 3,
#    'gi': 1,
#    'pdi': 1,
#    'ui': 1,
#    'ddi': 1,
#    'ai': 1,
#    'dbi': 1,
#    'dvi': 1,
#    'ki': 1,
#    'mi': 1,
#    'dli': 1,
#    'dii': 1,
#    'sdi': 3,
#    'dqi': 1,
#    'dsi': 2,
#    'si': 1,
#    'dui': 2,
#    'dti': 1,
#    'idi': 1,
#    'dg': 1,
#    'fi': 1,
#    'dji': 1,
#    'ri': 2,
#    'dp': 1,
#    'wi': 1,
#    'ji': 1,
#    'yi': 1,
#    'li': 1,
#    'dv': 1,
#    'dai': 1,
#    'dpi': 1,
#    'dl': 1,
#    'de': 1,
#    'bi': 1,
#    'zdi': 1,
#    'sqi': 1,
#    'qi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb33'),
#   'word': 'nel',
#   'occurrences': {'nel': 397,
#    'neg': 1,
#    'nei': 1,
#    'nhel': 1,
#    'pnel': 1,
#    'nael': 1,
#    'ael': 1,
#    'nmel': 1,
#    'nep': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb34'),
#   'word': 'suo',
#   'occurrences': {'suo': 285,
#    'suy': 1,
#    'euo': 1,
#    'seo': 2,
#    'gsuo': 1,
#    'xsuo': 1,
#    'cuo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb35'),
#   'word': 'altissimo',
#   'occurrences': {'altissimo': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb36'),
#   'word': 'privilegio',
#   'occurrences': {'privilegio': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb37'),
#   'word': "dell\\'immacolato",
#   'occurrences': {"dell\\'immacolato": 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb38'),
#   'word': 'concepimento',
#   'occurrences': {'concepimento': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb39'),
#   'word': 'è',
#   'occurrences': {'è': 889,
#    'tè': 2,
#    "e'̀": 10,
#    'z̀': 1,
#    'b̀': 1,
#    'el': 2,
#    'ef': 1,
#    'eu': 1,
#    'ù': 1,
#    'ef̀': 1,
#    'ep': 1,
#    'eè': 1,
#    'ev̀': 1,
#    'nè': 1,
#    'ex̀': 1,
#    'es': 1,
#    'ed': 1,
#    'm̀': 1,
#    'el̀': 1,
#    'eà': 1,
#    'hè': 1,
#    'eq': 1,
#    'en': 1,
#    'ǹ': 1,
#    'h̀': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3a'),
#   'word': 'nostro',
#   'occurrences': {'nostro': 335,
#    'nystro': 1,
#    'nlstro': 1,
#    'nostrko': 1,
#    'postro': 1,
#    'cnostro': 1,
#    'nosxro': 1,
#    'nyostro': 1,
#    'nbstro': 1,
#    'noxtro': 1,
#    'noetro': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3b'),
#   'word': 'spirito',
#   'occurrences': {'spirito': 186,
#    'spiuito': 1,
#    'spirsto': 1,
#    'spgirito': 1,
#    'scpirito': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3c'),
#   'word': 'uno',
#   'occurrences': {'uno': 44, 'uxno': 1, 'uhno': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3d'),
#   'word': 'dei',
#   'occurrences': {'dei': 626,
#    'lei': 1,
#    'dbi': 1,
#    'dpei': 1,
#    'deu': 1,
#    'doi': 1,
#    'dgi': 1,
#    'pdei': 1,
#    'deii': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3e'),
#   'word': 'più',
#   'occurrences': {'più': 462,
#    'ziù': 1,
#    "piu'̀": 1,
#    'kpiù': 1,
#    'pisù': 1,
#    'pliù': 1,
#    'pqù': 1,
#    'pqiù': 1,
#    'piẁ': 1,
#    'ppù': 1,
#    'pid̀': 1,
#    'piuc': 1,
#    'wiù': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb3f'),
#   'word': 'fausti',
#   'occurrences': {'fausti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb40'),
#   'word': 'questi',
#   'occurrences': {'qhesti': 1,
#    'questi': 112,
#    'qubesti': 1,
#    'quepsti': 1,
#    'qkuesti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb41'),
#   'word': 'ultimi',
#   'occurrences': {'ultimi': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb42'),
#   'word': 'mesi',
#   'occurrences': {'mesi': 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb43'),
#   'word': 'la',
#   'occurrences': {'la': 2167,
#    'ra': 1,
#    'lda': 3,
#    'lu': 2,
#    'ha': 2,
#    'na': 2,
#    'lqa': 1,
#    'lr': 1,
#    'zla': 1,
#    'ls': 3,
#    'lha': 1,
#    'rla': 1,
#    'lsa': 1,
#    'ta': 2,
#    'ld': 1,
#    'lv': 1,
#    'ka': 1,
#    'lia': 1,
#    'ln': 1,
#    'wla': 1,
#    'lga': 1,
#    'lja': 1,
#    'ula': 1,
#    'lta': 1,
#    'nla': 1,
#    'kla': 1,
#    'ly': 1,
#    'lla': 2,
#    'xla': 1,
#    'll': 1,
#    'lz': 1,
#    'pa': 1,
#    'lq': 1,
#    'lh': 1,
#    'lka': 1,
#    'ia': 1,
#    'ma': 2,
#    'le': 1,
#    'lfa': 1,
#    'lj': 1,
#    'hla': 1,
#    'fa': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb44'),
#   'word': 'vostra',
#   'occurrences': {'vostra': 63, 'vjostra': 1, 'vostrh': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb45'),
#   'word': 'presenza',
#   'occurrences': {'presenza': 30, 'prenenza': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb46'),
#   'word': 'cari',
#   'occurrences': {'cari': 30}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb47'),
#   'word': 'fratelli',
#   'occurrences': {'fratelli': 165,
#    'fratelooi': 1,
#    'fratplli': 1,
#    'frautelli': 1,
#    'fdatelli': 1,
#    'frtatelli': 1,
#    'fratelgli': 1,
#    'fraatelli': 1,
#    'fratelgi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb48'),
#   'word': 'bergamo',
#   'occurrences': {'bergamo': 20, 'beruamo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb49'),
#   'word': 'circostanze',
#   'occurrences': {'circostanze': 26}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4a'),
#   'word': 'che',
#   'occurrences': {'che': 2040,
#    'chpe': 1,
#    'cye': 1,
#    'ihe': 1,
#    'coe': 1,
#    'mhe': 1,
#    'chw': 1,
#    'chj': 1,
#    'cqhe': 1,
#    'yhe': 1,
#    'chye': 1,
#    'chb': 1,
#    'fche': 1,
#    'she': 1,
#    'chie': 1,
#    'nche': 1,
#    'chae': 2,
#    'chxe': 1,
#    'rhe': 2,
#    'chge': 1,
#    'sche': 3,
#    'tche': 1,
#    'cha': 1,
#    'cqe': 1,
#    'jhe': 1,
#    'chce': 1,
#    'clhe': 1,
#    'cre': 1,
#    'wche': 1,
#    'chje': 1,
#    'chte': 1,
#    'cwe': 1,
#    'eche': 1,
#    'chh': 1,
#    'cze': 1,
#    'czhe': 1,
#    'phe': 2,
#    'cihe': 1,
#    'cahe': 1,
#    'cne': 1,
#    'cohe': 1,
#    'rche': 1,
#    'chfe': 1,
#    'cie': 1,
#    'choe': 1,
#    'cche': 1,
#    'vhe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4b'),
#   'word': "l\\'hanno",
#   'occurrences': {"l\\'hanno": 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4c'),
#   'word': 'effettuata',
#   'occurrences': {'effettuata': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4d'),
#   'word': 'con',
#   'occurrences': {'con': 610,
#    'rcon': 1,
#    'cln': 1,
#    'acon': 1,
#    'cok': 1,
#    'cotn': 1,
#    'cvon': 1,
#    'von': 1,
#    'jcon': 1,
#    'kcon': 1,
#    'cop': 1,
#    'cen': 1,
#    'ocon': 1,
#    'ton': 1,
#    'czn': 1,
#    'gcon': 1,
#    'coc': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4e'),
#   'word': 'cui',
#   'occurrences': {'cui': 307,
#    'uui': 1,
#    'cuwi': 1,
#    'hui': 1,
#    'jcui': 1,
#    'cyi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb4f'),
#   'word': 'si',
#   'occurrences': {'si': 600,
#    'se': 1,
#    'jsi': 2,
#    'xi': 1,
#    'sgi': 1,
#    'ski': 1,
#    'sbi': 1,
#    'ti': 1,
#    'usi': 1,
#    'ci': 2,
#    'swi': 1,
#    'hsi': 1,
#    'sii': 1,
#    'smi': 1,
#    'ri': 2,
#    'wsi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb50'),
#   'word': 'afferma',
#   'occurrences': {'afferma': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb51'),
#   'word': 'sotto',
#   'occurrences': {'sotto': 47, 'asotto': 1, 'solto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb52'),
#   'word': 'queste',
#   'occurrences': {'queste': 81,
#    'qxueste': 1,
#    'qvueste': 1,
#    'quzste': 1,
#    'quewte': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb53'),
#   'word': 'magnifiche',
#   'occurrences': {'magnifiche': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb54'),
#   'word': 'volte',
#   'occurrences': {'volte': 24}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb55'),
#   'word': 'innanzi',
#   'occurrences': {'innanzi': 52, 'innanxzi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb56'),
#   'word': 'a',
#   'occurrences': {'a': 1523}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb57'),
#   'word': 'tanti',
#   'occurrences': {'tanti': 45, 'ganti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb58'),
#   'word': 'altri',
#   'occurrences': {'altri': 60}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb59'),
#   'word': 'tutti',
#   'occurrences': {'tutti': 398,
#    'xtutti': 2,
#    'ptutti': 1,
#    'txtti': 1,
#    'jutti': 1,
#    'tuttm': 1,
#    'iutti': 2,
#    'tuteti': 1,
#    'autti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5a'),
#   'word': 'nella',
#   'occurrences': {'nella': 448,
#    'neilla': 1,
#    'nelua': 1,
#    'nellda': 1,
#    'pella': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5b'),
#   'word': 'fede',
#   'occurrences': {'fede': 96, 'wfede': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5c'),
#   'word': 'appartenenti',
#   'occurrences': {'appartenenti': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5d'),
#   'word': 'diverse',
#   'occurrences': {'diverse': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5e'),
#   'word': 'diocesi',
#   'occurrences': {'diocesi': 44}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb5f'),
#   'word': "d\\'italia",
#   'occurrences': {"d\\'italia": 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb60'),
#   'word': 'mondo',
#   'occurrences': {'mondo': 316,
#    'mando': 1,
#    'monddo': 1,
#    'mvndo': 1,
#    'monxo': 1,
#    'xmondo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb61'),
#   'word': 'i',
#   'occurrences': {'i': 810}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb62'),
#   'word': 'occhi',
#   'occurrences': {'occhi': 50, 'occhii': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb63'),
#   'word': 'cuore',
#   'occurrences': {'cuore': 143,
#    'coore': 2,
#    'cupore': 1,
#    'kuore': 1,
#    'cuoqre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb64'),
#   'word': 'motivo',
#   'occurrences': {'motivo': 40, 'motcvo': 1, 'motijo': 1, 'imotivo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb65'),
#   'word': 'gioia',
#   'occurrences': {'gioia': 42}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb66'),
#   'word': 'composta',
#   'occurrences': {'composta': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb67'),
#   'word': 'profonda',
#   'occurrences': {'profonda': 21}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb68'),
#   'word': 'ma',
#   'occurrences': {'ma': 300, 'xma': 1, 'za': 1, 'mya': 1, 'ima': 1, 'md': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb69'),
#   'word': 'straordinariamente',
#   'occurrences': {'straordinariamente': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6a'),
#   'word': 'benedetta',
#   'occurrences': {'benedetta': 18}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6b'),
#   'word': 'vi',
#   'occurrences': {'vi': 266, 'vd': 1, 'vq': 1, 'ci': 1, 'tvi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6c'),
#   'word': 'ringraziamo',
#   'occurrences': {'ringraziamo': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6d'),
#   'word': 'già',
#   'occurrences': {'già': 58}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6e'),
#   'word': 'ci',
#   'occurrences': {'ci': 456,
#    'pce': 1,
#    'ti': 1,
#    'oi': 1,
#    'cxi': 1,
#    'tci': 1,
#    'uci': 1,
#    'xi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb6f'),
#   'word': 'preme',
#   'occurrences': {'preme': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb70'),
#   'word': 'effondere',
#   'occurrences': {'effondere': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb71'),
#   'word': 'piene',
#   'occurrences': {'piene': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb72'),
#   'word': 'mani',
#   'occurrences': {'emani': 1, 'mani': 28, 'manti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb73'),
#   'word': 'sopra',
#   'occurrences': {'sopra': 47}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb74'),
#   'word': 'voi',
#   'occurrences': {'voi': 225,
#    'vci': 1,
#    'vobi': 1,
#    'voh': 1,
#    'nvoi': 1,
#    'vboi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb75'),
#   'word': 'primizia',
#   'occurrences': {'primizia': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb76'),
#   'word': 'delle',
#   'occurrences': {'delle': 363,
#    'dellfe': 1,
#    'della': 1,
#    'dhlle': 1,
#    'dellde': 1,
#    'dehle': 1,
#    'dllle': 1,
#    'deslle': 1,
#    'delte': 1,
#    'delfle': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb77'),
#   'word': 'benedizioni',
#   'occurrences': {'benedizijni': 1, 'benedizioni': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb78'),
#   'word': 'gratitudine',
#   'occurrences': {'gratitudine': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb79'),
#   'word': 'presenti',
#   'occurrences': {'presenti': 19, 'presejti': 1, 'pvesenti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7a'),
#   'word': 'quanti',
#   'occurrences': {'quanti': 84}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7b'),
#   'word': 'rappresentate',
#   'occurrences': {'rappresentate': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7c'),
#   'word': 'portate',
#   'occurrences': {'pbrtate': 1, 'portate': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7d'),
#   'word': 'viva',
#   'occurrences': {'viva': 33, 'yiva': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7e'),
#   'word': 'vibrante',
#   'occurrences': {'vibrante': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb7f'),
#   'word': 'essa',
#   'occurrences': {'essa': 75}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb80'),
#   'word': 'volge',
#   'occurrences': {'volge': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb81'),
#   'word': 'innanzitutto',
#   'occurrences': {'innanzitutto': 18}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb82'),
#   'word': 'venerato',
#   'occurrences': {'venerato': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb83'),
#   'word': 'fratello',
#   'occurrences': {'fratello': 19}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb84'),
#   'word': 'figlio',
#   'occurrences': {'figlio': 27, 'figljio': 1, 'liglio': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb85'),
#   'word': 'monsignor',
#   'occurrences': {'monsignor': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb86'),
#   'word': 'giuseppe',
#   'occurrences': {'giuseppe': 13, 'ghuseppe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb87'),
#   'word': 'piazzi',
#   'occurrences': {'piazzi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb88'),
#   'word': 'degnissimo',
#   'occurrences': {'degnissimo': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb89'),
#   'word': 'tanto',
#   'occurrences': {'tanto': 61, 'tawnto': 1, 'tasto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8a'),
#   'word': 'caro',
#   'occurrences': {'caro': 20}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8b'),
#   'word': 'ed',
#   'occurrences': {'ed': 452,
#    'ek': 1,
#    'xd': 1,
#    'ecd': 1,
#    'vd': 1,
#    'er': 1,
#    'sed': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8c'),
#   'word': 'amato',
#   'occurrences': {'amato': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8d'),
#   'word': 'presule',
#   'occurrences': {'presule': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8e'),
#   'word': 'nostra',
#   'occurrences': {'nostra': 376,
#    'ndostra': 1,
#    'notstra': 1,
#    'anostra': 1,
#    'nostira': 1,
#    'nostfa': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb8f'),
#   'word': '#',
#   'occurrences': {'#': 570}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb90'),
#   'word': 'ai',
#   'occurrences': {'ai': 226,
#    'ap': 1,
#    'xai': 1,
#    'ri': 1,
#    'aw': 1,
#    'aai': 1,
#    'ji': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb91'),
#   'word': 'signori',
#   'occurrences': {'signori': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb92'),
#   'word': 'canonici',
#   'occurrences': {'canonici': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb93'),
#   'word': 'ceto',
#   'occurrences': {'ceto': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb94'),
#   'word': 'fu',
#   'occurrences': {'fu': 89, 'fo': 1, 'pu': 1, 'vu': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb95'),
#   'word': 'così',
#   'occurrences': {'così': 203,
#    'cosii': 1,
#    "cosi'̀": 1,
#    'cosuì': 1,
#    'cdosì': 1,
#    'cosz̀': 1,
#    'codsì': 1,
#    'cosiv': 1,
#    'cosm̀': 1,
#    'coseì': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb96'),
#   'word': 'appartenere',
#   'occurrences': {'appartenere': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb97'),
#   'word': 'anche',
#   'occurrences': {'anche': 214,
#    'anehe': 1,
#    'anchp': 1,
#    'ancehe': 1,
#    'ancoe': 1,
#    'agnche': 1,
#    'ayche': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb98'),
#   'word': 'se',
#   'occurrences': {'se': 111}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb99'),
#   'word': 'semplice',
#   'occurrences': {'semplice': 26}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9a'),
#   'word': 'titolo',
#   'occurrences': {'titolo': 27}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9b'),
#   'word': 'onore',
#   'occurrences': {'onore': 65, 'onwre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9c'),
#   'word': 'anni',
#   'occurrences': {'anni': 78, 'annwi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9d'),
#   'word': 'parroci',
#   'occurrences': {'parroci': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9e'),
#   'word': 'sacerdoti',
#   'occurrences': {'sacerdoti': 47, 'sacezdoti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfb9f'),
#   'word': 'venuti',
#   'occurrences': {'venuti': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba0'),
#   'word': 'sacrificio',
#   'occurrences': {'sacrificio': 48, 'yacrificio': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba1'),
#   'word': 'personale',
#   'occurrences': {'personale': 26, 'peersonale': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba2'),
#   'word': 'in',
#   'occurrences': {'in': 1261,
#    'iu': 1,
#    'is': 1,
#    'ign': 1,
#    'ixn': 1,
#    'xin': 2,
#    'zn': 1,
#    'ikn': 1,
#    'izn': 1,
#    'ihn': 2,
#    'ib': 1,
#    'icn': 1,
#    'ivn': 1,
#    'rn': 1,
#    'qn': 1,
#    'ic': 1,
#    'ir': 1,
#    'iw': 1,
#    'gin': 1,
#    'mn': 1,
#    'ibn': 1,
#    'ein': 1,
#    'iq': 1,
#    'itn': 1,
#    'un': 1,
#    'isn': 1,
#    'iyn': 1,
#    'hin': 1,
#    'an': 1,
#    'qin': 1,
#    'vn': 1,
#    'ie': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba3'),
#   'word': 'eletta',
#   'occurrences': {'eletta': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba4'),
#   'word': 'schiera',
#   'occurrences': {'schiera': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba5'),
#   'word': 'salutare',
#   'occurrences': {'salutare': 16}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba6'),
#   'word': 'loro',
#   'occurrences': {'loro': 230,
#    'lorpo': 1,
#    'lorgo': 1,
#    'loqro': 1,
#    'louro': 1,
#    'yloro': 1,
#    'ltoro': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba7'),
#   'word': 'antico',
#   'occurrences': {'antico': 8, 'anthco': 1, 'antipo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba8'),
#   'word': 'condiscepolo',
#   'occurrences': {'condiscepolo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfba9'),
#   'word': 'o',
#   'occurrences': {'o': 174}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbaa'),
#   'word': 'maestro',
#   'occurrences': {'maestro': 19, 'maestbro': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbab'),
#   'word': 'direttore',
#   'occurrences': {'direttore': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbac'),
#   'word': 'spirituale',
#   'occurrences': {'spirituale': 81,
#    'spiritualt': 1,
#    'spiritoale': 1,
#    'rspirituale': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbad'),
#   'word': 'negli',
#   'occurrences': {'negli': 36}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbae'),
#   'word': 'servizio',
#   'occurrences': {'servizio': 65, 'serjvizio': 1, 'pservizio': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbaf'),
#   'word': 'poi',
#   'occurrences': {'poi': 78, 'joi': 2, 'pohi': 1, 'uoi': 1, 'poti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb0'),
#   'word': 'nei',
#   'occurrences': {'nei': 123, 'nec': 1, 'npei': 1, 'unei': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb1'),
#   'word': '##',
#   'occurrences': {'##': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb2'),
#   'word': 'trascorse',
#   'occurrences': {'trascorse': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb3'),
#   'word': 'vari',
#   'occurrences': {'vari': 24}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb4'),
#   'word': 'uffici',
#   'occurrences': {'uffici': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb5'),
#   'word': 'ministeri',
#   'occurrences': {'ministeri': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb6'),
#   'word': 'affidatigli',
#   'occurrences': {'affidatigli': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb7'),
#   'word': 'dalla',
#   'occurrences': {'dalla': 151,
#    'xdalla': 1,
#    'dapla': 1,
#    'daqlla': 1,
#    'dhlla': 1,
#    'dallq': 1,
#    'dxlla': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb8'),
#   'word': 'santa',
#   'occurrences': {'santa': 168, 'aanta': 1, 'saxta': 1, 'saonta': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbb9'),
#   'word': 'sede',
#   'occurrences': {'sede': 32}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbba'),
#   'word': 'non',
#   'occurrences': {'non': 538,
#    'pon': 1,
#    'jon': 1,
#    'nmn': 1,
#    'ion': 1,
#    'noyn': 1,
#    'nqon': 1,
#    'eon': 1,
#    'con': 1,
#    'nmon': 1,
#    'von': 1,
#    'nwn': 1,
#    'nxon': 1,
#    'nov': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbbb'),
#   'word': 'desiderò',
#   'occurrences': {'desiderò': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbbc'),
#   'word': 'altro',
#   'occurrences': {'altro': 31, 'altrj': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbbd'),
#   'word': 'essere',
#   'occurrences': {'essere': 106, 'esvsere': 1, 'essexre': 1, 'eessere': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbbe'),
#   'word': 'amico',
#   'occurrences': {'amico': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbbf'),
#   'word': 'ciascuno',
#   'occurrences': {'ciascuno': 65}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc0'),
#   'word': 'grato',
#   'occurrences': {'grato': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc1'),
#   'word': 'saluto',
#   'occurrences': {'saluto': 31, 'salmto': 1, 'saljuto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc2'),
#   'word': 'particolare',
#   'occurrences': {'particolare': 41, 'particonare': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc3'),
#   'word': 'accento',
#   'occurrences': {'accento': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc4'),
#   'word': 'rispetto',
#   'occurrences': {'rispetto': 34}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc5'),
#   'word': 'affezione',
#   'occurrences': {'affezione': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc6'),
#   'word': 'nobili',
#   'occurrences': {'nobili': 14}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc7'),
#   'word': 'copiosi',
#   'occurrences': {'copiosi': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc8'),
#   'word': 'rappresentanti',
#   'occurrences': {'rappresentanti': 14, 'rappresentauti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbc9'),
#   'word': "dell\\'ordine",
#   'occurrences': {"dell\\'ordine": 15}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbca'),
#   'word': 'civico',
#   'occurrences': {'civico': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbcb'),
#   'word': 'sociale',
#   'occurrences': {'sociale': 55, 'soclale': 1, 'socialge': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbcc'),
#   'word': 'variamente',
#   'occurrences': {'variamente': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbcd'),
#   'word': 'disposti',
#   'occurrences': {'disposti': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbce'),
#   'word': 'gradi',
#   'occurrences': {'gradi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbcf'),
#   'word': 'competenze',
#   'occurrences': {'competenze': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd0'),
#   'word': 'attribuzioni',
#   'occurrences': {'attribuzioni': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd1'),
#   'word': 'furono',
#   'occurrences': {'furono': 29}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd2'),
#   'word': 'sempre',
#   'occurrences': {'sempre': 209,
#    'pempre': 1,
#    'scempre': 1,
#    'sempmre': 1,
#    'semple': 1,
#    'oempre': 1,
#    'sempzre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd3'),
#   'word': 'cortesi',
#   'occurrences': {'cortesui': 1, 'cortesi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd4'),
#   'word': 'amabili',
#   'occurrences': {'amabili': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd5'),
#   'word': 'verso',
#   'occurrences': {'verso': 61, 'gerso': 1, 'vmrso': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd6'),
#   'word': 'persona',
#   'occurrences': {'persona': 49}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd7'),
#   'word': 'seminaristi',
#   'occurrences': {'seminaristi': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd8'),
#   'word': 'riguardiamo',
#   'occurrences': {'riguardiamo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbd9'),
#   'word': 'speciale',
#   'occurrences': {'speciale': 25}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbda'),
#   'word': 'predilezione',
#   'occurrences': {'predilezione': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbdb'),
#   'word': 'perchè',
#   'occurrences': {'perchè': 70, 'perzhè': 1, 'percheì': 1, 'perchep': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbdc'),
#   'word': 'essi',
#   'occurrences': {'essi': 43, 'essgi': 1, 'uessi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbdd'),
#   'word': 'sono',
#   'occurrences': {'sono': 234,
#    'dsono': 1,
#    'cono': 1,
#    'sotno': 1,
#    'osuno': 1,
#    'sonyo': 1,
#    'bsono': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbde'),
#   'word': 'fiore',
#   'occurrences': {'fiore': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbdf'),
#   'word': 'speranze',
#   'occurrences': {'speranze': 18}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe0'),
#   'word': 'belle',
#   'occurrences': {'belle': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe1'),
#   'word': '#',
#   'occurrences': {'#': 1015}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe2'),
#   'word': 'spes',
#   'occurrences': {'spes': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe3'),
#   'word': 'messis',
#   'occurrences': {'messis': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe4'),
#   'word': 'semine',
#   'occurrences': {'semine': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe5'),
#   'word': 'membri',
#   'occurrences': {'membri': 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe6'),
#   'word': 'associazioni',
#   'occurrences': {'associazioni': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe7'),
#   'word': 'cattoliche',
#   'occurrences': {'cattoliche': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe8'),
#   'word': 'tutte',
#   'occurrences': {'tutte': 135, 'tuttae': 1, 'thutte': 1, 'ututte': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbe9'),
#   'word': 'altre',
#   'occurrences': {'altre': 37, 'altrce': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbea'),
#   'word': 'istituzioni',
#   'occurrences': {'istituzioni': 16, 'istituzieoni': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbeb'),
#   'word': 'qui',
#   'occurrences': {'qui': 196, 'rqui': 1, 'qux': 1, 'qvui': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbec'),
#   'word': 'convenuti',
#   'occurrences': {'convenuti': 14}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbed'),
#   'word': 'inoltre',
#   'occurrences': {'inoltre': 16, 'ynoltre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbee'),
#   'word': 'fedeli',
#   'occurrences': {'fedeli': 72, 'nfedeli': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbef'),
#   'word': 'poterono',
#   'occurrences': {'poterono': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf0'),
#   'word': 'venire',
#   'occurrences': {'venire': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf1'),
#   'word': 'roma',
#   'occurrences': {'roma': 150, 'rvma': 1, 'romx': 1, 'rhma': 1, 'uoma': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf2'),
#   'word': 'agli',
#   'occurrences': {'agli': 54, 'aglwi': 1, 'amli': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf3'),
#   'word': 'ammalati',
#   'occurrences': {'ammalati': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf4'),
#   'word': 'sofferenti',
#   'occurrences': {'sofferenti': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf5'),
#   'word': 'poveri',
#   'occurrences': {'poveri': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf6'),
#   'word': 'tribolati',
#   'occurrences': {'tribolati': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf7'),
#   'word': 'nello',
#   'occurrences': {'nello': 26, 'nelly': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf8'),
#   'word': 'bambini',
#   'occurrences': {'bambini': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbf9'),
#   'word': 'anziani',
#   'occurrences': {'anziani': 10, 'anyiani': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbfa'),
#   'word': 'abbraccio',
#   'occurrences': {'abbraccio': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbfb'),
#   'word': 'come',
#   'occurrences': {'come': 408,
#    'cpme': 1,
#    'cogme': 1,
#    'comn': 1,
#    'coome': 1,
#    'copme': 1,
#    'ycome': 1,
#    'comp': 1,
#    'lome': 1,
#    'hcome': 1,
#    'ctme': 1,
#    'coqe': 1,
#    'coime': 1,
#    'coma': 1,
#    'fome': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbfc'),
#   'word': 'sguardo',
#   'occurrences': {'sguardo': 24}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbfd'),
#   'word': 'va',
#   'occurrences': {'va': 24}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbfe'),
#   'word': 'cercare',
#   'occurrences': {'cercare': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfbff'),
#   'word': 'punti',
#   'occurrences': {'punti': 54, 'punrti': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc00'),
#   'word': 'noi',
#   'occurrences': {'noi': 327,
#    'nhi': 1,
#    'noj': 1,
#    'zoi': 1,
#    'nyoi': 1,
#    'choi': 1,
#    'noei': 1,
#    'not': 1,
#    'enoi': 1,
#    'npoi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc01'),
#   'word': 'noti',
#   'occurrences': {'noti': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc02'),
#   'word': 'cara',
#   'occurrences': {'cara': 19}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc03'),
#   'word': 'terra',
#   'occurrences': {'terra': 116,
#    'terrya': 1,
#    'terrma': 1,
#    'tqrra': 1,
#    'teirra': 1,
#    'terura': 1,
#    'terha': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc04'),
#   'word': 'natìa',
#   'occurrences': {'natìa': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc05'),
#   'word': 'dove',
#   'occurrences': {'dove': 63, 'bove': 1, 'dovz': 1, 'dovu': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc06'),
#   'word': 'un',
#   'occurrences': {'un': 403, 'lun': 1, 'qn': 1, 'sn': 1, 'uln': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc07'),
#   'word': 'tutto',
#   'occurrences': {'tutto': 192, 'tuttd': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc08'),
#   'word': 'bello',
#   'occurrences': {'bello': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc09'),
#   'word': 'degno',
#   'occurrences': {'degno': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0a'),
#   'word': 'immutato',
#   'occurrences': {'immutato': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0b'),
#   'word': 'immutabile',
#   'occurrences': {'immutabile': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0c'),
#   'word': 'amore',
#   'occurrences': {'amore': 54, 'amorbe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0d'),
#   'word': 'mistero',
#   'occurrences': {'mistero': 29, 'mismero': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0e'),
#   'word': 'misericordia',
#   'occurrences': {'misericordia': 23, 'mibsericordia': 1, 'miseeicordia': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc0f'),
#   'word': 'avvolge',
#   'occurrences': {'avvolge': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc10'),
#   'word': 'nulla',
#   'occurrences': {'nulla': 21, 'nzulla': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc11'),
#   'word': 'toglie',
#   'occurrences': {'toglie': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc12'),
#   'word': 'alla',
#   'occurrences': {'alla': 580,
#    'vlla': 1,
#    'xalla': 1,
#    'allm': 1,
#    'adla': 1,
#    'apla': 1,
#    'falla': 1,
#    'alma': 1,
#    'slla': 1,
#    'alfa': 1,
#    'talla': 1,
#    'asla': 1,
#    'alloa': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc13'),
#   'word': 'umiltà',
#   'occurrences': {'umiltà': 14, 'pmiltà': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc14'),
#   'word': 'povertà',
#   'occurrences': {'povertà': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc15'),
#   'word': 'neppure',
#   'occurrences': {'neppure': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc16'),
#   'word': 'impedisce',
#   'occurrences': {'impedisce': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc17'),
#   'word': 'entrare',
#   'occurrences': {'entrare': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc18'),
#   'word': 'cantico',
#   'occurrences': {'cantico': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc19'),
#   'word': 'ringraziamento',
#   'occurrences': {'ringraziamento': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1a'),
#   'word': 'da',
#   'occurrences': {'da': 469,
#    'dea': 1,
#    'dx': 1,
#    'dda': 1,
#    'ka': 1,
#    'dl': 1,
#    'ada': 1,
#    'nda': 1,
#    'ma': 1,
#    'dna': 1,
#    'rda': 1,
#    'dv': 1,
#    'xa': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1b'),
#   'word': 'parecchi',
#   'occurrences': {'parecchi': 11, 'payecchi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1c'),
#   'word': 'giorni',
#   'occurrences': {'giorni': 49}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1d'),
#   'word': 'levate',
#   'occurrences': {'levate': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1e'),
#   'word': 'intorno',
#   'occurrences': {'intorno': 43, 'inatorno': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc1f'),
#   'word': 'altari',
#   'occurrences': {'altari': 5, 'algtari': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc20'),
#   'word': 'serena',
#   'occurrences': {'serena': 19}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc21'),
#   'word': 'vostre',
#   'occurrences': {'vostre': 49, 'vosatre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc22'),
#   'word': 'case',
#   'occurrences': {'case': 14, 'cmse': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc23'),
#   'word': 'ricordo',
#   'occurrences': {'ricordo': 43}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc24'),
#   'word': 'vostro',
#   'occurrences': {'vostro': 44, 'rostro': 1, 'vosdtro': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc25'),
#   'word': 'concittadino',
#   'occurrences': {'concittadino': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc26'),
#   'word': 'solcata',
#   'occurrences': {'solcata': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc27'),
#   'word': 'prodigi',
#   'occurrences': {'prodigi': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc28'),
#   'word': 'pietà',
#   'occurrences': {'pietà': 60}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc29'),
#   'word': 'religiosa',
#   'occurrences': {'religiosa': 54, 'religfiosa': 1, 'religioha': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2a'),
#   'word': 'sentita',
#   'occurrences': {'sentita': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2b'),
#   'word': 'generosità',
#   'occurrences': {'generosità': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2c'),
#   'word': 'operosa',
#   'occurrences': {'operosa': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2d'),
#   'word': 'costante',
#   'occurrences': {'costante': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2e'),
#   'word': 'questa',
#   'occurrences': {'questa': 405,
#    'questc': 1,
#    'quezsta': 1,
#    'qyesta': 1,
#    'questb': 1,
#    'qujesta': 1,
#    'quoesta': 1,
#    'qnesta': 1,
#    'quqesta': 1,
#    'qmesta': 1,
#    'qulsta': 1,
#    'questoa': 1,
#    'xquesta': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc2f'),
#   'word': 'volta',
#   'occurrences': {'volta': 35, 'voltya': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc30'),
#   'word': 'fece',
#   'occurrences': {'fece': 15, 'flce': 1, 'cece': 1, 'feye': 1, 'hece': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc31'),
#   'word': "l\\'antico",
#   'occurrences': {"l\\'antico": 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc32'),
#   'word': 'popolo',
#   'occurrences': {'popolo': 104, 'pdopolo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc33'),
#   'word': 'traendo',
#   'occurrences': {'traendo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc34'),
#   'word': 'piccolo',
#   'occurrences': {'piccolo': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc35'),
#   'word': 'davide',
#   'occurrences': {'davide': 4, 'danide': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc36'),
#   'word': 'dai',
#   'occurrences': {'dai': 69, 'qai': 1, 'dki': 1, 'jai': 1, 'dapi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc37'),
#   'word': 'pastori',
#   'occurrences': {'pastori': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc38'),
#   'word': 'betlemme',
#   'occurrences': {'betlemme': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc39'),
#   'word': 'abbia',
#   'occurrences': {'abbia': 20}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3a'),
#   'word': 'scelto',
#   'occurrences': {'scelto': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3b'),
#   'word': 'nuovo',
#   'occurrences': {'nuovo': 71, 'cuovo': 1, 'nuowvo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3c'),
#   'word': 'sommo',
#   'occurrences': {'sommo': 14}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3d'),
#   'word': 'pontefice',
#   'occurrences': {'pontefice': 36}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3e'),
#   'word': 'facendolo',
#   'occurrences': {'facendolo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc3f'),
#   'word': 'depositario',
#   'occurrences': {'depositario': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc40'),
#   'word': 'grande',
#   'occurrences': {'grande': 210, 'igrande': 1, 'grandc': 1, 'gracde': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc41'),
#   'word': 'tradizione',
#   'occurrences': {'tradizione': 28}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc42'),
#   'word': 'apostolica',
#   'occurrences': {'apostolica': 66, 'apostrolica': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc43'),
#   'word': 'suggellata',
#   'occurrences': {'suggellata': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc44'),
#   'word': 'dal',
#   'occurrences': {'dap': 1,
#    'dal': 166,
#    'dkal': 1,
#    'bal': 1,
#    'xdal': 1,
#    'cal': 1,
#    'sal': 1,
#    'zdal': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc45'),
#   'word': 'sangue',
#   'occurrences': {'sangue': 41, 'sanhue': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc46'),
#   'word': 'figliolo',
#   'occurrences': {'figliolo': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc47'),
#   'word': 'tale',
#   'occurrences': {'tale': 45, 'fale': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc48'),
#   'word': 'avvenimento',
#   'occurrences': {'avvenimento': 28}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc49'),
#   'word': 'parliamo',
#   'occurrences': {'parliamo': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4a'),
#   'word': 'obbligarci',
#   'occurrences': {'obbligarci': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4b'),
#   'word': 'sciogliere',
#   'occurrences': {'sciogliere': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4c'),
#   'word': 'calzari',
#   'occurrences': {'calzari': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4d'),
#   'word': "nell\\'atto",
#   'occurrences': {"nell\\'atto": 8, "nelx\\'atto": 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4e'),
#   'word': 'procedere',
#   'occurrences': {'procedere': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc4f'),
#   'word': 'roveto',
#   'occurrences': {'roveto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc50'),
#   'word': 'ardente',
#   'occurrences': {'ardente': 17}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc51'),
#   'word': 'carità',
#   'occurrences': {'carità': 114, 'cardità': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc52'),
#   'word': 'divina',
#   'occurrences': {'divina': 61, 'divinq': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc53'),
#   'word': 'attende',
#   'occurrences': {'attende': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc54'),
#   'word': 'consuma',
#   'occurrences': {'consuma': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc55'),
#   'word': 'constatare',
#   'occurrences': {'constatare': 6, 'constftare': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc56'),
#   'word': 'manifestazione',
#   'occurrences': {'manifestazione': 17}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc57'),
#   'word': 'bontà',
#   'occurrences': {'bontà': 29, 'gbontà': 1, 'bontaà': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc58'),
#   'word': 'dio',
#   'occurrences': {'dio': 214,
#    'wdio': 1,
#    'dpo': 1,
#    'dbio': 1,
#    'dioo': 1,
#    'dcio': 1,
#    'dno': 1,
#    'bdio': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc59'),
#   'word': 'alte',
#   'occurrences': {'alte': 21, 'avte': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5a'),
#   'word': 'considerazioni',
#   'occurrences': {'considerazioni': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5b'),
#   'word': 'potrebbero',
#   'occurrences': {'potrebbero': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5c'),
#   'word': 'intrattenerci',
#   'occurrences': {'intrattenerci': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5d'),
#   'word': 'convenga',
#   'occurrences': {'convenga': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5e'),
#   'word': 'liturgica',
#   'occurrences': {'liturgica': 25, 'lituraica': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc5f'),
#   'word': 'celebrazione',
#   'occurrences': {'celebrazione': 58}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc60'),
#   'word': 'fatto',
#   'occurrences': {'fatto': 63,
#    'fattq': 1,
#    'fratto': 1,
#    'fathto': 1,
#    'fktto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfc61'),
#   'word': 'bonum',
#   'occurrences': {'bonum': 8}},
# ...
#  {'_id': ObjectId('60e57ab457a8f66820acfe5b'),
#   'word': 'cordiale',
#   'occurrences': {'cordiale': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe5c'),
#   'word': 'benvenuto',
#   'occurrences': {'benvenuto': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe5d'),
#   'word': 'incoraggiante',
#   'occurrences': {'incoraggiante': 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe5e'),
#   'word': 'benedicente',
#   'occurrences': {'benedicente': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe5f'),
#   'word': 'giornata',
#   'occurrences': {'giornata': 22}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe60'),
#   'word': 'ricordi',
#   'occurrences': {'ricordi': 30}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe61'),
#   'word': 'immacolata',
#   'occurrences': {'immacolata': 26}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe62'),
#   'word': 'fanno',
#   'occurrences': {'fanno': 15}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe63'),
#   'word': 'esaltare',
#   'occurrences': {'esaltare': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe64'),
#   'word': 'tempio',
#   'occurrences': {'tempio': 34, 'teipio': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe65'),
#   'word': 'vaticano',
#   'occurrences': {'vaticano': 52}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe66'),
#   'word': 'quando',
#   'occurrences': {'quando': 47, 'xquando': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe67'),
#   'word': '1\\',
#   'occurrences': {'1\\': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe68'),
#   'word': "'",
#   'occurrences': {"'": 38}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe69'),
#   'word': '18##',
#   'occurrences': {'18##': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6a'),
#   'word': 'ix',
#   'occurrences': {'ix': 21, 'six': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6b'),
#   'word': 'leggeva',
#   'occurrences': {'leggeva': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6c'),
#   'word': 'bolla',
#   'occurrences': {'bolla': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6d'),
#   'word': 'definizione',
#   'occurrences': {'definizione': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6e'),
#   'word': 'dogmatica',
#   'occurrences': {'dogmatica': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe6f'),
#   'word': 'raggio',
#   'occurrences': {'raggio': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe70'),
#   'word': 'sole',
#   'occurrences': {'sole': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe71'),
#   'word': 'irruppe',
#   'occurrences': {'irruppe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe72'),
#   'word': 'avvolse',
#   'occurrences': {'avvolse': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe73'),
#   'word': 'luce',
#   'occurrences': {'luce': 104, 'lumce': 1, 'luhe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe74'),
#   'word': 'madre',
#   'occurrences': {'madre': 88, 'mtadre': 1, 'mladre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe75'),
#   'word': 'celeste',
#   'occurrences': {'celeste': 56, 'celesxe': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe76'),
#   'word': 'diffonde',
#   'occurrences': {'diffonde': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe77'),
#   'word': 'trasmette',
#   'occurrences': {'trasmette': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe78'),
#   'word': 'letizia',
#   'occurrences': {'letizia': 48, 'lertizia': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe79'),
#   'word': 'rafforza',
#   'occurrences': {'rafforza': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7a'),
#   'word': 'buone',
#   'occurrences': {'buone': 31, 'busone': 1, 'lbuone': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7b'),
#   'word': 'volontà',
#   'occurrences': {'volontà': 43, 'volontpà': 1, 'kvolontà': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7c'),
#   'word': 'affratella',
#   'occurrences': {'affratella': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7d'),
#   'word': 'animi',
#   'occurrences': {'animi': 14, 'lnimi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7e'),
#   'word': 'rammentiamo',
#   'occurrences': {'rammentiamo': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe7f'),
#   'word': "l\\'altro",
#   'occurrences': {"l\\'altro": 11, "l\\'pltro": 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe80'),
#   'word': 'celebrando',
#   'occurrences': {'celebrando': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe81'),
#   'word': 'mezzo',
#   'occurrences': {'mezzo': 32}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe82'),
#   'word': 'secolo',
#   'occurrences': {'secolo': 36}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe83'),
#   'word': 'quella',
#   'occurrences': {'quella': 105, 'quelkla': 1, 'quesla': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe84'),
#   'word': 'proclamazione',
#   'occurrences': {'proclamazione': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe85'),
#   'word': 'apparve',
#   'occurrences': {'apparve': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe86'),
#   'word': 'giovanissimo',
#   'occurrences': {'giovanissimo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe87'),
#   'word': 'emanazione',
#   'occurrences': {'emanazione': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe88'),
#   'word': 'dissipò',
#   'occurrences': {'dissipò': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe89'),
#   'word': 'volto',
#   'occurrences': {'volto': 17}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8a'),
#   'word': 'traccia',
#   'occurrences': {'traccia': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8b'),
#   'word': 'preoccupazione',
#   'occurrences': {'preoccupazione': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8c'),
#   'word': 'gravi',
#   'occurrences': {'gravi': 28, 'grazi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8d'),
#   'word': 'interessi',
#   'occurrences': {'interessi': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8e'),
#   'word': 'rese',
#   'occurrences': {'rese': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe8f'),
#   'word': 'splendente',
#   'occurrences': {'splendente': 18}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe90'),
#   'word': 'quello',
#   'occurrences': {'quello': 51}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe91'),
#   'word': 'mosè',
#   'occurrences': {'mosè': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe92'),
#   'word': 'sul',
#   'occurrences': {'sul': 70, 'suyl': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe93'),
#   'word': 'sinai',
#   'occurrences': {'sinai': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe94'),
#   'word': 'conforto',
#   'occurrences': {'conforto': 30, 'ctnforto': 1, 'conforzto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe95'),
#   'word': 'benedizione',
#   'occurrences': {'benedizione': 76, 'oenedizione': 1, 'benjdizione': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe96'),
#   'word': 'lei',
#   'occurrences': {'lei': 21}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe97'),
#   'word': 'prepararci',
#   'occurrences': {'prepararci': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe98'),
#   'word': 'attendevano',
#   'occurrences': {'attendevano': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe99'),
#   'word': "quest\\'ultimo",
#   'occurrences': {"quest\\'ultimo": 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9a'),
#   'word': 'margine',
#   'occurrences': {'margine': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9b'),
#   'word': 'volle',
#   'occurrences': {'volle': 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9c'),
#   'word': 'riservato',
#   'occurrences': {'riservato': 10}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9d'),
#   'word': 'singolare',
#   'occurrences': {'singolare': 25}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9e'),
#   'word': 'consacrare',
#   'occurrences': {'consacrare': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfe9f'),
#   'word': 'lourdes',
#   'occurrences': {'lourdes': 17}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea0'),
#   'word': 'vastissimo',
#   'occurrences': {'vastissimo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea1'),
#   'word': 'sotterraneo',
#   'occurrences': {'sotterraneo': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea2'),
#   'word': 'congiunge',
#   'occurrences': {'congiunge': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea3'),
#   'word': 'unico',
#   'occurrences': {'unico': 9, 'uyico': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea4'),
#   'word': 'palpito',
#   'occurrences': {'palpito': 14}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea5'),
#   'word': 'entusiasmo',
#   'occurrences': {'entusiasmo': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea6'),
#   'word': 'x#',
#   'occurrences': {'x#': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea7'),
#   'word': 'offrire',
#   'occurrences': {'offrire': 17, 'offrqire': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea8'),
#   'word': 'redenti',
#   'occurrences': {'redenti': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfea9'),
#   'word': 'eleva',
#   'occurrences': {'eleva': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeaa'),
#   'word': 'divenuta',
#   'occurrences': {'divenuta': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeab'),
#   'word': 'supplicazione',
#   'occurrences': {'supplicazione': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeac'),
#   'word': 'affinche#',
#   'occurrences': {'affinche#': 76}},
#  {'_id': ObjectId('60e57ab457a8f66820acfead'),
#   'word': 'ottenga',
#   'occurrences': {'ottenga': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeae'),
#   'word': 'sovrabbondanza',
#   'occurrences': {'sovrabbondanza': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeaf'),
#   'word': 'favori',
#   'occurrences': {'favori': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb0'),
#   'word': 'fiducioso',
#   'occurrences': {'fiducioso': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb1'),
#   'word': 'abbandono',
#   'occurrences': {'abbandono': 7}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb2'),
#   'word': 'preservi',
#   'occurrences': {'preservi': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb3'),
#   'word': 'pericoli',
#   'occurrences': {'pericoli': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb4'),
#   'word': 'futuri',
#   'occurrences': {'futuri': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb5'),
#   'word': 'costruire',
#   'occurrences': {'costruire': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb6'),
#   'word': 'sabbia',
#   'occurrences': {'sabbia': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb7'),
#   'word': "dell\\'agitarci",
#   'occurrences': {"dell\\'agitarci": 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb8'),
#   'word': 'invano',
#   'occurrences': {'invano': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeb9'),
#   'word': 'piuttosto',
#   'occurrences': {'piuttosto': 14}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeba'),
#   'word': 'chiarifichi',
#   'occurrences': {'chiarifichi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfebb'),
#   'word': 'menti',
#   'occurrences': {'menti': 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfebc'),
#   'word': 'purifichi',
#   'occurrences': {'purifichi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfebd'),
#   'word': 'dia',
#   'occurrences': {'dia': 9, 'tdia': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfebe'),
#   'word': 'sicurezza',
#   'occurrences': {'sicurezza': 26, 'sicurezaza': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfebf'),
#   'word': 'passi',
#   'occurrences': {'passi': 13}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec0'),
#   'word': "l\\'avvento",
#   'occurrences': {"l\\'avvento": 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec1'),
#   'word': 'regno',
#   'occurrences': {'regno': 37}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec2'),
#   'word': 'sulle',
#   'occurrences': {'sulle': 49, 'sullf': 1, 'sullue': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec3'),
#   'word': 'singole',
#   'occurrences': {'singole': 15, 'sinuole': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec4'),
#   'word': 'religiose',
#   'occurrences': {'religiose': 24}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec5'),
#   'word': 'civiche',
#   'occurrences': {'civiche': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec6'),
#   'word': "sull\\'intera",
#   'occurrences': {"sull\\'intera": 2}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec7'),
#   'word': 'umanità',
#   'occurrences': {'umanità': 15}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec8'),
#   'word': 'messa',
#   'occurrences': {'messa': 25, 'mesasa': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfec9'),
#   'word': "nell\\'arcibasilica",
#   'occurrences': {"nell\\'arcibasilica": 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeca'),
#   'word': 'lateranense',
#   'occurrences': {'lateranense': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfecb'),
#   'word': 'domenica',
#   'occurrences': {'domenica': 135, 'gomenica': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfecc'),
#   'word': '2#',
#   'occurrences': {'2#': 7, '2i#': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfecd'),
#   'word': 'novembre',
#   'occurrences': {'novembre': 28, 'noyvembre': 1, 'novbembre': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfece'),
#   'word': '19#8',
#   'occurrences': {'19#8': 6, '19#g': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfecf'),
#   'word': 'venerabili',
#   'occurrences': {'venerabili': 88,
#    'venerabhli': 1,
#    'evenerabili': 1,
#    'venerapili': 1,
#    'qenerabili': 1,
#    'veneraeili': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed0'),
#   'word': 'scambiato',
#   'occurrences': {'scambiato': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed1'),
#   'word': 'soglie',
#   'occurrences': {'soglie': 6}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed2'),
#   'word': 'cattedrale',
#   'occurrences': {'cattedrale': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed3'),
#   'word': 'signor',
#   'occurrences': {'signor': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed4'),
#   'word': 'cardinale',
#   'occurrences': {'cardinale': 32, 'coardinale': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed5'),
#   'word': 'arciprete',
#   'occurrences': {'arciprete': 3}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed6'),
#   'word': 'amiamo',
#   'occurrences': {'amiamo': 31}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed7'),
#   'word': 'aggiungere',
#   'occurrences': {'aggiungere': 8}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed8'),
#   'word': 'edificazione',
#   'occurrences': {'edificazione': 29}},
#  {'_id': ObjectId('60e57ab457a8f66820acfed9'),
#   'word': 'tre',
#   'occurrences': {'tre': 40, 'ire': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeda'),
#   'word': 'pensieri',
#   'occurrences': {'pensieri': 32}},
#  {'_id': ObjectId('60e57ab457a8f66820acfedb'),
#   'word': 'vorremmo',
#   'occurrences': {'vorremmo': 11}},
#  {'_id': ObjectId('60e57ab457a8f66820acfedc'),
#   'word': 'pervenissero',
#   'occurrences': {'pervenissero': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfedd'),
#   'word': 'eco',
#   'occurrences': {'eco': 12}},
#  {'_id': ObjectId('60e57ab457a8f66820acfede'),
#   'word': 'due',
#   'occurrences': {'due': 89, 'duae': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfedf'),
#   'word': 'solenni',
#   'occurrences': {'solenni': 17, 'solenyi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee0'),
#   'word': 'voci',
#   'occurrences': {'voci': 23, 'vocf': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee1'),
#   'word': 'risuonarono',
#   'occurrences': {'risuonarono': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee2'),
#   'word': 'sommi',
#   'occurrences': {'sommi': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee3'),
#   'word': 'pontefici',
#   'occurrences': {'pontefici': 13, 'pontmfici': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee4'),
#   'word': 'leone',
#   'occurrences': {'leone': 42, 'lebne': 1, 'leine': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee5'),
#   'word': 'gregorio',
#   'occurrences': {'gregorio': 30}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee6'),
#   'word': 'gloriosi',
#   'occurrences': {'gloriosi': 9}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee7'),
#   'word': 'ambedue',
#   'occurrences': {'ambedue': 5}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee8'),
#   'word': 'dottori',
#   'occurrences': {'dottori': 10, 'dottomri': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfee9'),
#   'word': 'padri',
#   'occurrences': {'padri': 25, 'padrui': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeea'),
#   'word': 'riflette',
#   'occurrences': {'riflette': 4}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeeb'),
#   'word': 'rito',
#   'occurrences': {'rito': 49, 'rikto': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeec'),
#   'word': 'odierno',
#   'occurrences': {'odierno': 9, 'odiewno': 1}},
#  {'_id': ObjectId('60e57ab457a8f66820acfeed'),
#   'word': 'alta',
#   'occurrences': {'alta': 25}},
#  ...]
