# %%
import pymongo
import string
from tqdm.notebook import tqdm
from collections import Counter 

client = pymongo.MongoClient('mongodb://localhost:27017')
db = client['vatican']
dataset = db['phrasesDataset']
wordsDataset = db['wordsDataset']

docs = list(dataset.find())

# %%
#wordsDataset.drop()
wordsDataset.count()
# Out:
# <ipython-input-12-ab340a24988d>:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   wordsDataset.count()
# 0

# %%
chars = "solenità'd\mczkwfhjuxgbvrpyq8192!#"
CHAR_INDEX = dict((c, i) for i, c in enumerate(chars))

def preprocess(s):
    out = ""
    for c in s.lower():
        if c in CHAR_INDEX.keys():
            out += c
        else:
            out += '#'
    return "".join(out)

# %%
word = dict()

for i, d in tqdm(enumerate(docs)):
    for j, s in enumerate(d['sentences']):
        for k, w in enumerate(s[0]):
            word.setdefault(s[1][k], []).append(preprocess(w))            
            
for wk in word.keys():
    item = dict(Counter(word.get(wk)))
    wordsDataset.insert_one({'word': preprocess(wk), 'occurrences': item})
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
a = list(wordsDataset.find())
a
# Out:
# [{'_id': ObjectId('60e030600d9eac679f7fa9d7'),
#   'word': 'solennità',
#   'occurrences': {'solennità': 36,
#    'solennvità': 1,
#    'solejnità': 1,
#    "solennita'̀": 4,
#    'solennitat': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9d8'),
#   'word': "dell\\'immacolata",
#   'occurrences': {"dell\\'immacolata": 12}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9d9'),
#   'word': 'concezione',
#   'occurrences': {'cofcezione': 1, 'concezione': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9da'),
#   'word': 'della',
#   'occurrences': {'della': 1718,
#    'delda': 1,
#    'delja': 1,
#    'derlla': 1,
#    'delld': 1,
#    'dellua': 1,
#    'dehlla': 1,
#    'dellaa': 1,
#    'deula': 2,
#    'detlla': 1,
#    'zella': 1,
#    'delbla': 2,
#    'dellea': 1,
#    'deltla': 2,
#    'fella': 1,
#    'dellx': 1,
#    'cdella': 1,
#    'bdella': 1,
#    'dellza': 1,
#    'dewlla': 1,
#    'dellda': 1,
#    'dqlla': 1,
#    'delly': 1,
#    'delma': 1,
#    'idella': 1,
#    'dellb': 1,
#    'deala': 1,
#    'debla': 1,
#    'deklla': 1,
#    'dglla': 1,
#    'dellxa': 1,
#    'oella': 1,
#    'deila': 1,
#    'dtella': 1,
#    'dsella': 2,
#    'dellva': 1,
#    'dellfa': 1,
#    'delula': 1,
#    'pdella': 1,
#    'demla': 1,
#    'denlla': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9db'),
#   'word': 'beata',
#   'occurrences': {'beata': 15, 'meata': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9dc'),
#   'word': 'vergine',
#   'occurrences': {'vergine': 22}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9dd'),
#   'word': 'maria',
#   'occurrences': {'maria': 136,
#    'muaria': 1,
#    'mhria': 1,
#    'mazia': 1,
#    'maruia': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9de'),
#   'word': 'omelia',
#   'occurrences': {'omelia': 45}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9df'),
#   'word': 'del',
#   'occurrences': {'del': 1485,
#    'wdel': 1,
#    'kel': 1,
#    'sel': 1,
#    'dpl': 1,
#    'dll': 1,
#    'adel': 1,
#    'oel': 1,
#    'dil': 1,
#    'mel': 2,
#    'deol': 1,
#    'dbel': 1,
#    'pdel': 1,
#    'ddel': 1,
#    'deal': 2,
#    'detl': 1,
#    'diel': 1,
#    'dexl': 1,
#    'dcel': 1,
#    'gel': 1,
#    'djel': 1,
#    'idel': 1,
#    'cdel': 1,
#    'ddl': 1,
#    'deel': 1,
#    'sdel': 1,
#    'wel': 1,
#    'dsel': 1,
#    'eel': 1,
#    'dnel': 1,
#    'jdel': 1,
#    'dell': 2,
#    'deql': 1,
#    'dpel': 1,
#    'dek': 1,
#    'deb': 1,
#    'dejl': 1,
#    'der': 1,
#    'dkl': 1,
#    'decl': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e0'),
#   'word': 'santo',
#   'occurrences': {'santo': 155, 'sanuo': 1, 'santpo': 1, 'osanto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e1'),
#   'word': 'padre',
#   'occurrences': {'padre': 111, 'padte': 1, 'podre': 1, 'tpadre': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e2'),
#   'word': 'giovanni',
#   'occurrences': {'giovanni': 102, 'giovantni': 1, 'ginovanni': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e3'),
#   'word': 'xxiii',
#   'occurrences': {'xxiii': 47, 'xxiiv': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e4'),
#   'word': 'basilica',
#   'occurrences': {'basilica': 81, 'boasilica': 1, 'ebasilica': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e5'),
#   'word': 'vaticana',
#   'occurrences': {'vaticana': 96,
#    'vatvcana': 1,
#    'vaticaqna': 1,
#    'vaticpana': 1,
#    'vatigcana': 1,
#    'vaticzna': 1,
#    'vhaticana': 1,
#    'vatizcana': 1,
#    'vatkcana': 1,
#    'vaticwna': 1,
#    'vaticadna': 1,
#    'vatoicana': 1,
#    'vatichana': 1,
#    'haticana': 1,
#    'vaticanqf': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e6'),
#   'word': 'lunedì',
#   'occurrences': {'lunedì': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e7'),
#   'word': '#',
#   'occurrences': {'#': 9416}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e8'),
#   'word': '8',
#   'occurrences': {'8': 33}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9e9'),
#   'word': 'dicembre',
#   'occurrences': {'dicembre': 31}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ea'),
#   'word': '1982',
#   'occurrences': {'1982': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9eb'),
#   'word': 'diletti',
#   'occurrences': {'diletti': 173,
#    'dilletti': 1,
#    'dqiuetti': 1,
#    'dilettd': 1,
#    'dildetti': 1,
#    'dileutti': 1,
#    'dilktti': 1,
#    'dilettpi': 1,
#    'dsiletti': 1,
#    'ndiletti': 1,
#    'dilnetti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ec'),
#   'word': 'figli',
#   'occurrences': {'figli': 272,
#    'figdi': 1,
#    'figlni': 1,
#    'figoli': 1,
#    'fzigli': 1,
#    'ficgli': 1,
#    'figlfi': 1,
#    'zigli': 1,
#    'fisli': 1,
#    'figlpi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ed'),
#   'word': 'nostri',
#   'occurrences': {'nostri': 155,
#    'bnostri': 2,
#    'nontri': 1,
#    'nostrdi': 1,
#    'naostri': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ee'),
#   'word': '!',
#   'occurrences': {'!': 271}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ef'),
#   'word': 'per',
#   'occurrences': {'per': 1110,
#    'peqr': 1,
#    'psr': 1,
#    'pee': 2,
#    'pei': 2,
#    'ner': 1,
#    'pec': 1,
#    'peyr': 1,
#    'kper': 1,
#    'lper': 1,
#    'uer': 1,
#    'pjr': 1,
#    'fper': 1,
#    'jer': 2,
#    'iper': 1,
#    'vper': 1,
#    'pez': 1,
#    'peq': 1,
#    'pxer': 1,
#    'pmer': 1,
#    'pehr': 1,
#    'prer': 1,
#    'ler': 1,
#    'pzer': 1,
#    'eer': 1,
#    'pes': 1,
#    'pver': 1,
#    'ptr': 1,
#    'peor': 1,
#    'perr': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f0'),
#   'word': 'ogni',
#   'occurrences': {'ogni': 211,
#    'ogvi': 1,
#    'ogndi': 1,
#    'eogni': 1,
#    'jgni': 1,
#    'ougni': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f1'),
#   'word': 'giorno',
#   'occurrences': {'giorno': 63, 'gliorno': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f2'),
#   'word': 'vita',
#   'occurrences': {'vita': 319,
#    'vitna': 1,
#    'victa': 1,
#    'xita': 1,
#    'wita': 1,
#    'vipa': 1,
#    'vxta': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f3'),
#   'word': 'il',
#   'occurrences': {'il': 1853,
#    'io': 2,
#    'ii': 1,
#    'jil': 2,
#    'ip': 3,
#    'kil': 1,
#    'xl': 2,
#    'irl': 1,
#    'ih': 1,
#    'kl': 2,
#    'll': 1,
#    'qil': 2,
#    'if': 2,
#    'sl': 1,
#    'iq': 1,
#    'yl': 1,
#    'mil': 2,
#    'ib': 1,
#    'wil': 1,
#    'sil': 1,
#    'itl': 1,
#    'uil': 1,
#    'vil': 1,
#    'idl': 1,
#    'ihl': 1,
#    'ik': 1,
#    'dil': 2,
#    'in': 1,
#    'nl': 1,
#    'ig': 1,
#    'gil': 1,
#    'ml': 1,
#    'iwl': 2,
#    'xil': 1,
#    'fl': 1,
#    'bil': 1,
#    'iol': 1,
#    'iil': 1,
#    'nil': 1,
#    'pil': 1,
#    'iw': 1,
#    'iu': 1,
#    'zl': 1,
#    'inl': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f4'),
#   'word': 'signore',
#   'occurrences': {'signore': 205,
#    'signsre': 1,
#    'gignore': 1,
#    'signlore': 1,
#    'signfre': 1,
#    'signorve': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f5'),
#   'word': 'riserva',
#   'occurrences': {'riserva': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f6'),
#   'word': 'alle',
#   'occurrences': {'alle': 173, 'aile': 1, 'ahle': 1, 'xalle': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f7'),
#   'word': 'anime',
#   'occurrences': {'anime': 120, 'zanime': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f8'),
#   'word': 'nostre',
#   'occurrences': {'nostre': 79,
#    'nottre': 1,
#    'nostri': 1,
#    'nostra': 1,
#    'uostre': 1,
#    'nostxe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9f9'),
#   'word': 'le',
#   'occurrences': {'le': 830,
#    'ale': 1,
#    'lc': 2,
#    'lw': 1,
#    're': 1,
#    'lp': 1,
#    'ce': 2,
#    'lce': 1,
#    'ble': 1,
#    'lye': 1,
#    'ls': 1,
#    'lj': 1,
#    'ne': 1,
#    'nle': 1,
#    'ltz': 1,
#    'ld': 1,
#    'lr': 1,
#    'lle': 1,
#    'te': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9fa'),
#   'word': 'sue',
#   'occurrences': {'sue': 75, 'psue': 1, 'hue': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9fb'),
#   'word': 'consolazioni',
#   'occurrences': {'consolazioni': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9fc'),
#   'word': 'e',
#   'occurrences': {'e': 4315}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9fd'),
#   'word': 'grazie',
#   'occurrences': {'grazie': 20, 'gxrazie': 1, 'grazihe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9fe'),
#   'word': '#',
#   'occurrences': {'#': 3680}},
#  {'_id': ObjectId('60e030600d9eac679f7fa9ff'),
#   'word': 'questo',
#   'occurrences': {'questo': 455,
#    'quesbto': 1,
#    'queslo': 1,
#    'qucsto': 1,
#    'quessto': 1,
#    'quusto': 1,
#    'quepsto': 1,
#    'quewstb': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa00'),
#   'word': 'dedicato',
#   'occurrences': {'dedicato': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7faa01'),
#   'word': 'al',
#   'occurrences': {'al': 579,
#    'xl': 1,
#    'agl': 1,
#    'lal': 1,
#    'axl': 1,
#    'apl': 1,
#    'aw': 1,
#    'ab': 1,
#    'sal': 1,
#    'au': 1,
#    'pal': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa02'),
#   'word': 'culto',
#   'occurrences': {'curto': 1, 'culto': 42, 'ctlto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa03'),
#   'word': 'di',
#   'occurrences': {'di': 4517,
#    'dz': 1,
#    'gdi': 1,
#    'dd': 1,
#    'bi': 3,
#    'hi': 4,
#    'fdi': 1,
#    'dfi': 3,
#    'de': 1,
#    'dhi': 3,
#    'dw': 2,
#    'jdi': 2,
#    'ai': 1,
#    'dri': 2,
#    'xi': 1,
#    'qi': 1,
#    'ni': 1,
#    'dci': 1,
#    'ndi': 1,
#    'dpi': 1,
#    'ydi': 1,
#    'ti': 1,
#    'pi': 1,
#    'ii': 2,
#    'du': 1,
#    'db': 2,
#    'dk': 1,
#    'dq': 1,
#    'ci': 3,
#    'dt': 1,
#    'udi': 1,
#    'dm': 1,
#    'df': 1,
#    'dti': 1,
#    'hdi': 2,
#    'li': 3,
#    'edi': 3,
#    'mi': 2,
#    'dc': 2,
#    'dr': 1,
#    'dv': 1,
#    'pdi': 1,
#    'dy': 1,
#    'dsi': 1,
#    'dui': 1,
#    'dii': 1,
#    'dx': 2,
#    'sdi': 2,
#    'dqi': 1,
#    'ddi': 2,
#    'odi': 1,
#    'bdi': 2,
#    'wi': 1,
#    'dj': 1,
#    'dl': 2,
#    'dni': 2,
#    'oi': 1,
#    'mdi': 1,
#    'ui': 1,
#    'gi': 1,
#    'do': 2,
#    'da': 1,
#    'dwi': 1,
#    'dg': 1,
#    'ji': 1,
#    'dyi': 1,
#    'xdi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa04'),
#   'word': 'nel',
#   'occurrences': {'nel': 394,
#    'ncl': 1,
#    'qel': 1,
#    'nqel': 1,
#    'nefl': 1,
#    'nepl': 1,
#    'ner': 1,
#    'hnel': 1,
#    'vnel': 1,
#    'nejl': 1,
#    'xnel': 1,
#    'ned': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa05'),
#   'word': 'suo',
#   'occurrences': {'suo': 288, 'huo': 1, 'suxo': 1, 'sno': 1, 'suv': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa06'),
#   'word': 'altissimo',
#   'occurrences': {'altissimo': 5, 'baltissimo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa07'),
#   'word': 'privilegio',
#   'occurrences': {'privilegio': 8, 'privilyegio': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa08'),
#   'word': "dell\\'immacolato",
#   'occurrences': {"dell\\'immacolato": 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faa09'),
#   'word': 'concepimento',
#   'occurrences': {'concepimento': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0a'),
#   'word': 'è',
#   'occurrences': {'è': 889,
#    'eu': 1,
#    'zè': 1,
#    'x̀': 1,
#    "e'̀": 6,
#    'g̀': 2,
#    'en': 1,
#    'd̀': 1,
#    'ev': 1,
#    'ez̀': 3,
#    'ed̀': 1,
#    'b̀': 1,
#    'l̀': 2,
#    'eg̀': 1,
#    'es': 1,
#    'eè': 1,
#    'eg': 1,
#    'yè': 1,
#    'eq': 1,
#    'rè': 1,
#    'z̀': 2,
#    'c̀': 1,
#    'wè': 1,
#    'eà': 1,
#    'ez': 1,
#    'ec̀': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0b'),
#   'word': 'nostro',
#   'occurrences': {'nostro': 332,
#    'nodstro': 1,
#    'noxstro': 2,
#    'noscro': 1,
#    'nostrko': 1,
#    'nosftro': 1,
#    'nostry': 1,
#    'nomstro': 1,
#    'nonstro': 1,
#    'nostdo': 1,
#    'nosturo': 1,
#    'ncstro': 1,
#    'noytro': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0c'),
#   'word': 'spirito',
#   'occurrences': {'spirito': 185,
#    'sgirito': 1,
#    'sypirito': 1,
#    'swpirito': 1,
#    'jpirito': 1,
#    'snirito': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0d'),
#   'word': 'uno',
#   'occurrences': {'uno': 44, 'unto': 1, 'unpo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0e'),
#   'word': 'dei',
#   'occurrences': {'dei': 618,
#    'adei': 1,
#    'mdei': 1,
#    'ndei': 2,
#    'dyei': 1,
#    'xei': 1,
#    'dexi': 1,
#    'diei': 1,
#    'gdei': 1,
#    'dvi': 1,
#    'den': 1,
#    'lei': 1,
#    'deb': 1,
#    'dtei': 1,
#    'dehi': 1,
#    'cei': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa0f'),
#   'word': 'più',
#   'occurrences': {'più': 466,
#    'pbù': 1,
#    'ypiù': 1,
#    'piuv̀': 1,
#    'pir̀': 1,
#    'piul̀': 1,
#    'priù': 1,
#    'piue': 1,
#    'hiù': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa10'),
#   'word': 'fausti',
#   'occurrences': {'fausti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa11'),
#   'word': 'questi',
#   'occurrences': {'questi': 114, 'questui': 1, 'quetsti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa12'),
#   'word': 'ultimi',
#   'occurrences': {'ultimi': 11}},
#  {'_id': ObjectId('60e030600d9eac679f7faa13'),
#   'word': 'mesi',
#   'occurrences': {'mesi': 11, 'mewi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa14'),
#   'word': 'la',
#   'occurrences': {'la': 2164,
#    'wla': 1,
#    'ja': 2,
#    'ba': 1,
#    'rla': 1,
#    'ma': 1,
#    'ta': 1,
#    'aa': 2,
#    'ola': 1,
#    'za': 1,
#    'lt': 1,
#    'na': 1,
#    'ga': 1,
#    'lla': 2,
#    'wa': 2,
#    'oa': 2,
#    'lya': 1,
#    'ea': 1,
#    'lqa': 1,
#    'lja': 1,
#    'lpa': 1,
#    'va': 1,
#    'lj': 2,
#    'lx': 1,
#    'lca': 1,
#    'fla': 2,
#    'ia': 1,
#    'ln': 1,
#    'nla': 1,
#    'lk': 2,
#    'dla': 1,
#    'mla': 2,
#    'lka': 1,
#    'lna': 1,
#    'qa': 1,
#    'ha': 1,
#    'lw': 1,
#    'zla': 1,
#    'lc': 1,
#    'pa': 1,
#    'ala': 1,
#    'lga': 1,
#    'lfa': 1,
#    'da': 1,
#    'lg': 1,
#    'lba': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa15'),
#   'word': 'vostra',
#   'occurrences': {'vostra': 62, 'vosptra': 1, 'vostlra': 1, 'vosstra': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa16'),
#   'word': 'presenza',
#   'occurrences': {'presenza': 31}},
#  {'_id': ObjectId('60e030600d9eac679f7faa17'),
#   'word': 'cari',
#   'occurrences': {'cari': 28, 'vari': 1, 'scari': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa18'),
#   'word': 'fratelli',
#   'occurrences': {'fratelli': 166,
#    'frdatelli': 1,
#    'fkratelli': 1,
#    'cratelli': 1,
#    'fraetelli': 1,
#    'fralelli': 1,
#    'frxtelli': 1,
#    'fratjjlli': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa19'),
#   'word': 'bergamo',
#   'occurrences': {'bergamo': 20, 'berqgamo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1a'),
#   'word': 'circostanze',
#   'occurrences': {'circostanze': 26}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1b'),
#   'word': 'che',
#   'occurrences': {'che': 2046,
#    'vche': 1,
#    'chte': 1,
#    'chye': 2,
#    'chp': 2,
#    'chwe': 1,
#    'vhe': 1,
#    'ckhe': 1,
#    'cvhe': 1,
#    'wche': 1,
#    'lche': 1,
#    'bche': 1,
#    'rhe': 1,
#    'cshe': 1,
#    'chb': 1,
#    'ehe': 2,
#    'cthe': 1,
#    'ohe': 1,
#    'chw': 1,
#    'cwhe': 1,
#    'cjhe': 1,
#    'chx': 1,
#    'chfe': 1,
#    'chxe': 1,
#    'xhe': 1,
#    'ache': 1,
#    'chbe': 1,
#    'cce': 1,
#    'cyhe': 1,
#    'chle': 1,
#    'chae': 1,
#    'kche': 1,
#    'hche': 1,
#    'czhe': 1,
#    'dhe': 1,
#    'khe': 2,
#    'cht': 1,
#    'chce': 1,
#    'chh': 1,
#    'jhe': 1,
#    'uhe': 1,
#    'fche': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1c'),
#   'word': "l\\'hanno",
#   'occurrences': {"l\\'hanno": 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1d'),
#   'word': 'effettuata',
#   'occurrences': {'effettuata': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1e'),
#   'word': 'con',
#   'occurrences': {'con': 611,
#    'coq': 1,
#    'aon': 1,
#    'cson': 1,
#    'can': 1,
#    'cgon': 1,
#    'coi': 1,
#    'cnn': 1,
#    'coyn': 1,
#    'cotn': 1,
#    'covn': 1,
#    'pon': 1,
#    'cen': 1,
#    'coj': 1,
#    'gcon': 1,
#    'cmon': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa1f'),
#   'word': 'cui',
#   'occurrences': {'cui': 305,
#    'lcui': 1,
#    'xui': 1,
#    'cupi': 1,
#    'acui': 1,
#    'cumi': 1,
#    'cri': 1,
#    'cuui': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa20'),
#   'word': 'si',
#   'occurrences': {'si': 600,
#    'osi': 1,
#    'sa': 1,
#    'xsi': 1,
#    'se': 1,
#    'gsi': 1,
#    'li': 1,
#    'sp': 2,
#    'sj': 1,
#    'wi': 1,
#    'msi': 1,
#    'ei': 1,
#    'bi': 1,
#    'sf': 1,
#    'jsi': 1,
#    'sci': 1,
#    'so': 1,
#    'ss': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa21'),
#   'word': 'afferma',
#   'occurrences': {'afferma': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa22'),
#   'word': 'sotto',
#   'occurrences': {'sotto': 47, 'sottmo': 1, 'sotcto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa23'),
#   'word': 'queste',
#   'occurrences': {'queste': 85}},
#  {'_id': ObjectId('60e030600d9eac679f7faa24'),
#   'word': 'magnifiche',
#   'occurrences': {'magnifiche': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa25'),
#   'word': 'volte',
#   'occurrences': {'volte': 23, 'voltt': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa26'),
#   'word': 'innanzi',
#   'occurrences': {'innanzi': 51, 'insnanzi': 1, 'incanzi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa27'),
#   'word': 'a',
#   'occurrences': {'a': 1523}},
#  {'_id': ObjectId('60e030600d9eac679f7faa28'),
#   'word': 'tanti',
#   'occurrences': {'tanti': 44, 'tantxi': 1, 'mtanti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa29'),
#   'word': 'altri',
#   'occurrences': {'altri': 57, 'gltri': 1, 'altru': 1, 'altrz': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2a'),
#   'word': 'tutti',
#   'occurrences': {'tutti': 401,
#    'kutti': 1,
#    'tuttgi': 1,
#    'tutbti': 2,
#    'tutpti': 1,
#    'tudtti': 1,
#    'tututi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2b'),
#   'word': 'nella',
#   'occurrences': {'nella': 443,
#    'neltla': 1,
#    'nfella': 1,
#    'vella': 1,
#    'yella': 1,
#    'nello': 1,
#    'nehla': 1,
#    'neilla': 1,
#    'nelbla': 1,
#    'nnella': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2c'),
#   'word': 'fede',
#   'occurrences': {'fede': 97}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2d'),
#   'word': 'appartenenti',
#   'occurrences': {'appartenenti': 12, 'appaitenenti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2e'),
#   'word': 'diverse',
#   'occurrences': {'diverse': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faa2f'),
#   'word': 'diocesi',
#   'occurrences': {'diocesi': 44}},
#  {'_id': ObjectId('60e030600d9eac679f7faa30'),
#   'word': "d\\'italia",
#   'occurrences': {"d\\'italia": 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faa31'),
#   'word': 'mondo',
#   'occurrences': {'mondo': 316,
#    'monpo': 1,
#    'mobdo': 1,
#    'mindo': 1,
#    'moyndo': 1,
#    'montdo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa32'),
#   'word': 'i',
#   'occurrences': {'i': 810}},
#  {'_id': ObjectId('60e030600d9eac679f7faa33'),
#   'word': 'occhi',
#   'occurrences': {'occhi': 45,
#    'opcchi': 1,
#    'ofcchi': 1,
#    'occmi': 1,
#    'orchi': 1,
#    'mcchi': 1,
#    'dcchi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa34'),
#   'word': 'cuore',
#   'occurrences': {'cuore': 144,
#    'cuuore': 1,
#    'cuozre': 1,
#    'cfore': 1,
#    'cubre': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa35'),
#   'word': 'motivo',
#   'occurrences': {'motivo': 42, 'motvuvo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa36'),
#   'word': 'gioia',
#   'occurrences': {'gioia': 41, 'gixoia': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa37'),
#   'word': 'composta',
#   'occurrences': {'composta': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faa38'),
#   'word': 'profonda',
#   'occurrences': {'profonda': 20, 'profoxnda': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa39'),
#   'word': 'ma',
#   'occurrences': {'ma': 297,
#    'mya': 1,
#    'qma': 2,
#    'mqa': 1,
#    'mr': 1,
#    'oma': 1,
#    'hma': 1,
#    'mca': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3a'),
#   'word': 'straordinariamente',
#   'occurrences': {'straordinariamente': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3b'),
#   'word': 'benedetta',
#   'occurrences': {'benedetta': 18}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3c'),
#   'word': 'vi',
#   'occurrences': {'vi': 259,
#    'vbi': 1,
#    'ovx': 1,
#    'xi': 1,
#    'vt': 2,
#    'vii': 1,
#    'vfi': 1,
#    'si': 1,
#    'vwi': 2,
#    'vmi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3d'),
#   'word': 'ringraziamo',
#   'occurrences': {'ringraziamo': 9, 'zringraziamo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3e'),
#   'word': 'già',
#   'occurrences': {'già': 58}},
#  {'_id': ObjectId('60e030600d9eac679f7faa3f'),
#   'word': 'ci',
#   'occurrences': {'ci': 452,
#    'cv': 1,
#    'mci': 2,
#    'sci': 1,
#    'co': 1,
#    'fi': 1,
#    'cj': 1,
#    'chi': 1,
#    'coi': 1,
#    'cx': 1,
#    'cwk': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa40'),
#   'word': 'preme',
#   'occurrences': {'preme': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faa41'),
#   'word': 'effondere',
#   'occurrences': {'effondere': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa42'),
#   'word': 'piene',
#   'occurrences': {'piene': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa43'),
#   'word': 'mani',
#   'occurrences': {'mani': 30}},
#  {'_id': ObjectId('60e030600d9eac679f7faa44'),
#   'word': 'sopra',
#   'occurrences': {'sopra': 44, 'wsopra': 1, 'soprma': 1, 'sjpra': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa45'),
#   'word': 'voi',
#   'occurrences': {'voi': 226, 'vog': 1, 'xoi': 1, 'avoi': 1, 'boi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa46'),
#   'word': 'primizia',
#   'occurrences': {'lrimizia': 1, 'piimizia': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa47'),
#   'word': 'delle',
#   'occurrences': {'delle': 367,
#    'adelle': 1,
#    'celle': 1,
#    'deloe': 1,
#    'dhelle': 1,
#    'derlle': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa48'),
#   'word': 'benedizioni',
#   'occurrences': {'benedizioni': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7faa49'),
#   'word': 'gratitudine',
#   'occurrences': {'gratitudine': 12, 'grmatitudine': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4a'),
#   'word': 'presenti',
#   'occurrences': {'presenti': 21}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4b'),
#   'word': 'quanti',
#   'occurrences': {'quanti': 83, 'quanto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4c'),
#   'word': 'rappresentate',
#   'occurrences': {'rappresentate': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4d'),
#   'word': 'portate',
#   'occurrences': {'portate': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4e'),
#   'word': 'viva',
#   'occurrences': {'vsva': 1, 'viva': 33}},
#  {'_id': ObjectId('60e030600d9eac679f7faa4f'),
#   'word': 'vibrante',
#   'occurrences': {'vibrante': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7faa50'),
#   'word': 'essa',
#   'occurrences': {'essa': 75}},
#  {'_id': ObjectId('60e030600d9eac679f7faa51'),
#   'word': 'volge',
#   'occurrences': {'volge': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faa52'),
#   'word': 'innanzitutto',
#   'occurrences': {'innanzitutto': 17, 'innanzrtutto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa53'),
#   'word': 'venerato',
#   'occurrences': {'venerato': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faa54'),
#   'word': 'fratello',
#   'occurrences': {'fratello': 19}},
#  {'_id': ObjectId('60e030600d9eac679f7faa55'),
#   'word': 'figlio',
#   'occurrences': {'figlio': 29}},
#  {'_id': ObjectId('60e030600d9eac679f7faa56'),
#   'word': 'monsignor',
#   'occurrences': {'monsignor': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faa57'),
#   'word': 'giuseppe',
#   'occurrences': {'giuseppe': 13, 'giusqppe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa58'),
#   'word': 'piazzi',
#   'occurrences': {'piazzi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa59'),
#   'word': 'degnissimo',
#   'occurrences': {'degnissimo': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5a'),
#   'word': 'tanto',
#   'occurrences': {'tanto': 62, 'ytanto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5b'),
#   'word': 'caro',
#   'occurrences': {'caro': 19, 'jcaro': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5c'),
#   'word': 'ed',
#   'occurrences': {'ed': 446,
#    'ez': 2,
#    'ead': 1,
#    'ew': 2,
#    'od': 1,
#    'ei': 1,
#    'oed': 2,
#    'fed': 1,
#    'ged': 1,
#    'pd': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5d'),
#   'word': 'amato',
#   'occurrences': {'amato': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5e'),
#   'word': 'presule',
#   'occurrences': {'presule': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faa5f'),
#   'word': 'nostra',
#   'occurrences': {'nostra': 369,
#    'nostrxa': 1,
#    'rostra': 1,
#    'noswtra': 1,
#    'noftra': 1,
#    'nostlra': 1,
#    'nontra': 1,
#    'nostga': 1,
#    'nostpa': 1,
#    'nlstra': 1,
#    'nostrra': 1,
#    'nostnra': 1,
#    'noshtra': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa60'),
#   'word': '#',
#   'occurrences': {'#': 570}},
#  {'_id': ObjectId('60e030600d9eac679f7faa61'),
#   'word': 'ai',
#   'occurrences': {'ai': 227, 'yai': 1, 'ahi': 1, 'ap': 1, 'ci': 1, 'aa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa62'),
#   'word': 'signori',
#   'occurrences': {'signori': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faa63'),
#   'word': 'canonici',
#   'occurrences': {'canonici': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa64'),
#   'word': 'ceto',
#   'occurrences': {'ceto': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa65'),
#   'word': 'fu',
#   'occurrences': {'fu': 91, 'pfu': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa66'),
#   'word': 'così',
#   'occurrences': {'così': 201,
#    'cosiỳ': 1,
#    'cosil': 1,
#    'ccsì': 1,
#    'cisì': 1,
#    'coesì': 1,
#    'zcpsì': 1,
#    "cosi'̀": 1,
#    'sosì': 1,
#    'coshì': 1,
#    'losì': 1,
#    'cyosì': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa67'),
#   'word': 'appartenere',
#   'occurrences': {'appartenere': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faa68'),
#   'word': 'anche',
#   'occurrences': {'anche': 212,
#    'annhue': 1,
#    'ajche': 1,
#    'ancfe': 1,
#    'ancghe': 1,
#    'anvhe': 1,
#    'abche': 1,
#    'ancphe': 1,
#    'anqhe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa69'),
#   'word': 'se',
#   'occurrences': {'se': 109, 'sue': 1, 've': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6a'),
#   'word': 'semplice',
#   'occurrences': {'semplice': 25, 'sempylice': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6b'),
#   'word': 'titolo',
#   'occurrences': {'titolo': 25, 'tptolo': 1, 'titoelo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6c'),
#   'word': 'onore',
#   'occurrences': {'onore': 66}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6d'),
#   'word': 'anni',
#   'occurrences': {'anni': 78, 'annsi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6e'),
#   'word': 'parroci',
#   'occurrences': {'parroci': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faa6f'),
#   'word': 'sacerdoti',
#   'occurrences': {'sacerdoti': 47, 'saceardoti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa70'),
#   'word': 'venuti',
#   'occurrences': {'venuti': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7faa71'),
#   'word': 'sacrificio',
#   'occurrences': {'sacrificio': 46,
#    'spacrificio': 1,
#    'socrificio': 1,
#    'jsacrificio': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa72'),
#   'word': 'personale',
#   'occurrences': {'personale': 26, 'personali': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa73'),
#   'word': 'in',
#   'occurrences': {'in': 1262,
#    'un': 1,
#    'kin': 1,
#    'cin': 1,
#    'tin': 1,
#    'ifn': 1,
#    'ipn': 1,
#    'ir': 1,
#    'yin': 1,
#    'il': 1,
#    'zin': 1,
#    'ln': 2,
#    'sn': 1,
#    'ijn': 1,
#    'pin': 1,
#    'is': 1,
#    'ion': 1,
#    'id': 1,
#    'jin': 1,
#    'on': 1,
#    'nin': 1,
#    'uin': 1,
#    'ii': 1,
#    'iy': 1,
#    'fn': 1,
#    'ein': 2,
#    'iun': 1,
#    'ix': 1,
#    'imn': 1,
#    'ian': 1,
#    'lin': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa74'),
#   'word': 'eletta',
#   'occurrences': {'eletta': 5, 'elwtta': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa75'),
#   'word': 'schiera',
#   'occurrences': {'schiera': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faa76'),
#   'word': 'salutare',
#   'occurrences': {'salutare': 14, 'salutadre': 1, 'sslutare': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa77'),
#   'word': 'loro',
#   'occurrences': {'loro': 225,
#    'lxoro': 1,
#    'lorv': 1,
#    'uoro': 1,
#    'llro': 1,
#    'loiro': 1,
#    'gloro': 1,
#    'lorio': 1,
#    'lsro': 1,
#    'voro': 1,
#    'bloro': 1,
#    'lora': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa78'),
#   'word': 'antico',
#   'occurrences': {'antico': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faa79'),
#   'word': 'condiscepolo',
#   'occurrences': {'condiscepolo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7a'),
#   'word': 'o',
#   'occurrences': {'o': 174}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7b'),
#   'word': 'maestro',
#   'occurrences': {'maestro': 19, 'maesthro': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7c'),
#   'word': 'direttore',
#   'occurrences': {'direttore': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7d'),
#   'word': 'spirituale',
#   'occurrences': {'spirituale': 83, 'spikituale': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7e'),
#   'word': 'negli',
#   'occurrences': {'negli': 33, 'negpi': 1, 'xegli': 1, 'neigli': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa7f'),
#   'word': 'servizio',
#   'occurrences': {'servizio': 67}},
#  {'_id': ObjectId('60e030600d9eac679f7faa80'),
#   'word': 'poi',
#   'occurrences': {'poi': 80, 'pboi': 1, 'pon': 1, 'phi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa81'),
#   'word': 'nei',
#   'occurrences': {'nei': 122, 'inez': 1, 'aei': 1, 'kei': 1, 'nfei': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa82'),
#   'word': '##',
#   'occurrences': {'##': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa83'),
#   'word': 'trascorse',
#   'occurrences': {'trascorse': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa84'),
#   'word': 'vari',
#   'occurrences': {'vari': 24}},
#  {'_id': ObjectId('60e030600d9eac679f7faa85'),
#   'word': 'uffici',
#   'occurrences': {'uffici': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa86'),
#   'word': 'ministeri',
#   'occurrences': {'ministeri': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa87'),
#   'word': 'affidatigli',
#   'occurrences': {'affidatigli': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa88'),
#   'word': 'dalla',
#   'occurrences': {'dalla': 155, 'dalela': 1, 'dalxla': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa89'),
#   'word': 'santa',
#   'occurrences': {'santa': 167,
#    'santia': 1,
#    'sarnta': 1,
#    'sznta': 1,
#    'sianta': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8a'),
#   'word': 'sede',
#   'occurrences': {'sede': 30, 'esede': 1, 'sedg': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8b'),
#   'word': 'non',
#   'occurrences': {'non': 532,
#    'ton': 1,
#    'vnon': 1,
#    'neon': 1,
#    'oon': 1,
#    'npon': 1,
#    'mnon': 1,
#    'nson': 1,
#    'nkn': 1,
#    'kon': 1,
#    'noxn': 1,
#    'hnon': 1,
#    'noon': 1,
#    'jon': 1,
#    'nobn': 1,
#    'noh': 1,
#    'noz': 1,
#    'noyn': 1,
#    'nlon': 1,
#    'xnon': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8c'),
#   'word': 'desiderò',
#   'occurrences': {'desiderò': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8d'),
#   'word': 'altro',
#   'occurrences': {'altro': 32}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8e'),
#   'word': 'essere',
#   'occurrences': {'essere': 105,
#    'esserfe': 1,
#    'essebre': 1,
#    'elssere': 1,
#    'esaere': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa8f'),
#   'word': 'amico',
#   'occurrences': {'amico': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faa90'),
#   'word': 'ciascuno',
#   'occurrences': {'ciascuno': 64, 'ciascuto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa91'),
#   'word': 'grato',
#   'occurrences': {'grato': 2, 'gratgo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa92'),
#   'word': 'saluto',
#   'occurrences': {'saluto': 33}},
#  {'_id': ObjectId('60e030600d9eac679f7faa93'),
#   'word': 'particolare',
#   'occurrences': {'partizcolare': 1, 'particolare': 40, 'particoxlare': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa94'),
#   'word': 'accento',
#   'occurrences': {'accento': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faa95'),
#   'word': 'rispetto',
#   'occurrences': {'rispetto': 34}},
#  {'_id': ObjectId('60e030600d9eac679f7faa96'),
#   'word': 'affezione',
#   'occurrences': {'affezione': 8}},
#  {'_id': ObjectId('60e030600d9eac679f7faa97'),
#   'word': 'nobili',
#   'occurrences': {'nobili': 14}},
#  {'_id': ObjectId('60e030600d9eac679f7faa98'),
#   'word': 'copiosi',
#   'occurrences': {'copiosi': 7, 'cospiosi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa99'),
#   'word': 'rappresentanti',
#   'occurrences': {'rappresentanti': 15}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9a'),
#   'word': "dell\\'ordine",
#   'occurrences': {"dell\\'ordine": 15}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9b'),
#   'word': 'civico',
#   'occurrences': {'civico': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9c'),
#   'word': 'sociale',
#   'occurrences': {'sociale': 55, 'seociale': 1, 'socikale': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9d'),
#   'word': 'variamente',
#   'occurrences': {'variamente': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9e'),
#   'word': 'disposti',
#   'occurrences': {'disposti': 6, 'hisposti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faa9f'),
#   'word': 'gradi',
#   'occurrences': {'gradi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa0'),
#   'word': 'competenze',
#   'occurrences': {'competenze': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa1'),
#   'word': 'attribuzioni',
#   'occurrences': {'attribuzioni': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa2'),
#   'word': 'furono',
#   'occurrences': {'furono': 29}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa3'),
#   'word': 'sempre',
#   'occurrences': {'sempre': 213, 'msempre': 1, 'sempfre': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa4'),
#   'word': 'cortesi',
#   'occurrences': {'cortesi': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa5'),
#   'word': 'amabili',
#   'occurrences': {'amabili': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa6'),
#   'word': 'verso',
#   'occurrences': {'verso': 63}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa7'),
#   'word': 'persona',
#   'occurrences': {'persona': 48, 'persopa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa8'),
#   'word': 'seminaristi',
#   'occurrences': {'seminaristi': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faaa9'),
#   'word': 'riguardiamo',
#   'occurrences': {'riguardiamo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaaa'),
#   'word': 'speciale',
#   'occurrences': {'speciale': 25}},
#  {'_id': ObjectId('60e030600d9eac679f7faaab'),
#   'word': 'predilezione',
#   'occurrences': {'predilezione': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faaac'),
#   'word': 'perchè',
#   'occurrences': {'perchè': 71, 'cperchè': 1, 'pprchè': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaad'),
#   'word': 'essi',
#   'occurrences': {'essi': 45}},
#  {'_id': ObjectId('60e030600d9eac679f7faaae'),
#   'word': 'sono',
#   'occurrences': {'sono': 234,
#    'spno': 1,
#    'sogo': 1,
#    'lono': 1,
#    'srono': 1,
#    'sons': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faaaf'),
#   'word': 'fiore',
#   'occurrences': {'fiore': 9, 'fipre': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faab0'),
#   'word': 'speranze',
#   'occurrences': {'speranze': 18}},
#  {'_id': ObjectId('60e030600d9eac679f7faab1'),
#   'word': 'belle',
#   'occurrences': {'belle': 11}},
#  {'_id': ObjectId('60e030600d9eac679f7faab2'),
#   'word': '#',
#   'occurrences': {'#': 1015}},
#  {'_id': ObjectId('60e030600d9eac679f7faab3'),
#   'word': 'spes',
#   'occurrences': {'spes': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faab4'),
#   'word': 'messis',
#   'occurrences': {'messis': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faab5'),
#   'word': 'semine',
#   'occurrences': {'semine': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faab6'),
#   'word': 'membri',
#   'occurrences': {'membri': 12}},
#  {'_id': ObjectId('60e030600d9eac679f7faab7'),
#   'word': 'associazioni',
#   'occurrences': {'associazioni': 8}},
#  {'_id': ObjectId('60e030600d9eac679f7faab8'),
#   'word': 'cattoliche',
#   'occurrences': {'cattoliche': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faab9'),
#   'word': 'tutte',
#   'occurrences': {'tutte': 132,
#    'sutte': 1,
#    'tubte': 1,
#    'tutete': 1,
#    'tulte': 1,
#    'tyutte': 1,
#    'txtte': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaba'),
#   'word': 'altre',
#   'occurrences': {'altre': 38}},
#  {'_id': ObjectId('60e030600d9eac679f7faabb'),
#   'word': 'istituzioni',
#   'occurrences': {'istituzioni': 15, 'isiituzioni': 1, 'isticuzioni': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faabc'),
#   'word': 'qui',
#   'occurrences': {'qui': 198, 'qugi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faabd'),
#   'word': 'convenuti',
#   'occurrences': {'convenuti': 14}},
#  {'_id': ObjectId('60e030600d9eac679f7faabe'),
#   'word': 'inoltre',
#   'occurrences': {'inoltre': 16, 'inoltrce': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faabf'),
#   'word': 'fedeli',
#   'occurrences': {'fedeli': 73}},
#  {'_id': ObjectId('60e030600d9eac679f7faac0'),
#   'word': 'poterono',
#   'occurrences': {'poterono': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faac1'),
#   'word': 'venire',
#   'occurrences': {'venire': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faac2'),
#   'word': 'roma',
#   'occurrences': {'roma': 152, 'romka': 1, 'romd': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faac3'),
#   'word': 'agli',
#   'occurrences': {'agli': 56}},
#  {'_id': ObjectId('60e030600d9eac679f7faac4'),
#   'word': 'ammalati',
#   'occurrences': {'ammalati': 3, 'ammalarti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faac5'),
#   'word': 'sofferenti',
#   'occurrences': {'sofferenti': 12, 'soffhrenti': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faac6'),
#   'word': 'poveri',
#   'occurrences': {'poveri': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7faac7'),
#   'word': 'tribolati',
#   'occurrences': {'tribolati': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faac8'),
#   'word': 'nello',
#   'occurrences': {'nello': 27}},
#  {'_id': ObjectId('60e030600d9eac679f7faac9'),
#   'word': 'bambini',
#   'occurrences': {'bambini': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faaca'),
#   'word': 'anziani',
#   'occurrences': {'anziani': 11}},
#  {'_id': ObjectId('60e030600d9eac679f7faacb'),
#   'word': 'abbraccio',
#   'occurrences': {'abbraccio': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faacc'),
#   'word': 'come',
#   'occurrences': {'come': 411,
#    'combe': 1,
#    'compe': 1,
#    'ncome': 1,
#    'comle': 1,
#    'cxome': 1,
#    'comf': 1,
#    'pome': 1,
#    'code': 1,
#    'chome': 1,
#    'ceme': 1,
#    'csme': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faacd'),
#   'word': 'sguardo',
#   'occurrences': {'sguardo': 24}},
#  {'_id': ObjectId('60e030600d9eac679f7faace'),
#   'word': 'va',
#   'occurrences': {'va': 22, 'vu': 1, 'vfa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faacf'),
#   'word': 'cercare',
#   'occurrences': {'ceecare': 1, 'cercare': 7, 'cercsare': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faad0'),
#   'word': 'punti',
#   'occurrences': {'punti': 55}},
#  {'_id': ObjectId('60e030600d9eac679f7faad1'),
#   'word': 'noi',
#   'occurrences': {'noi': 327,
#    'noyi': 1,
#    'nofi': 1,
#    'ncoi': 1,
#    'nob': 1,
#    'nsoi': 1,
#    'coi': 2,
#    'nri': 1,
#    'noj': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faad2'),
#   'word': 'noti',
#   'occurrences': {'noti': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faad3'),
#   'word': 'cara',
#   'occurrences': {'cara': 19}},
#  {'_id': ObjectId('60e030600d9eac679f7faad4'),
#   'word': 'terra',
#   'occurrences': {'terra': 119, 'terroa': 1, 'tekrra': 1, 'terhra': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faad5'),
#   'word': 'natìa',
#   'occurrences': {'natìa': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faad6'),
#   'word': 'dove',
#   'occurrences': {'dove': 66}},
#  {'_id': ObjectId('60e030600d9eac679f7faad7'),
#   'word': 'un',
#   'occurrences': {'un': 390,
#    'uzn': 1,
#    'ua': 1,
#    'ug': 2,
#    'wun': 1,
#    'on': 1,
#    'uyn': 1,
#    'sun': 1,
#    'uxn': 1,
#    'uc': 1,
#    'tn': 1,
#    'cn': 1,
#    'ut': 1,
#    'um': 1,
#    'yn': 1,
#    'kun': 1,
#    'xun': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faad8'),
#   'word': 'tutto',
#   'occurrences': {'tutto': 187,
#    'tuttm': 1,
#    'tufto': 1,
#    'tutpto': 1,
#    'ututto': 1,
#    'tbutto': 1,
#    'tutte': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faad9'),
#   'word': 'bello',
#   'occurrences': {'bello': 13}},
#  {'_id': ObjectId('60e030600d9eac679f7faada'),
#   'word': 'degno',
#   'occurrences': {'degno': 9, 'negno': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faadb'),
#   'word': 'immutato',
#   'occurrences': {'mimmutato': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faadc'),
#   'word': 'immutabile',
#   'occurrences': {'immutabile': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faadd'),
#   'word': 'amore',
#   'occurrences': {'amore': 55}},
#  {'_id': ObjectId('60e030600d9eac679f7faade'),
#   'word': 'mistero',
#   'occurrences': {'mistero': 29, 'vistero': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faadf'),
#   'word': 'misericordia',
#   'occurrences': {'misericordia': 25}},
#  {'_id': ObjectId('60e030600d9eac679f7faae0'),
#   'word': 'avvolge',
#   'occurrences': {'avvolge': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7faae1'),
#   'word': 'nulla',
#   'occurrences': {'nulla': 21, 'nusla': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faae2'),
#   'word': 'toglie',
#   'occurrences': {'toglie': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faae3'),
#   'word': 'alla',
#   'occurrences': {'alla': 579,
#    'allna': 1,
#    'xlla': 1,
#    'allia': 1,
#    'abla': 1,
#    'clla': 1,
#    'acla': 2,
#    'alyla': 1,
#    'allma': 1,
#    'ualla': 1,
#    'alca': 1,
#    'aolla': 1,
#    'allba': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faae4'),
#   'word': 'umiltà',
#   'occurrences': {'umiltà': 15}},
#  {'_id': ObjectId('60e030600d9eac679f7faae5'),
#   'word': 'povertà',
#   'occurrences': {'povertà': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faae6'),
#   'word': 'neppure',
#   'occurrences': {'neppure': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7faae7'),
#   'word': 'impedisce',
#   'occurrences': {'impedisce': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7faae8'),
#   'word': 'entrare',
#   'occurrences': {'entrare': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7faae9'),
#   'word': 'cantico',
#   'occurrences': {'cantico': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faaea'),
#   'word': 'ringraziamento',
#   'occurrences': {'ringraziamento': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7faaeb'),
#   'word': 'da',
#   'occurrences': {'da': 473,
#    'dw': 1,
#    'dx': 1,
#    'dm': 1,
#    'cda': 1,
#    'ea': 1,
#    'dp': 1,
#    'uda': 1,
#    'xa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaec'),
#   'word': 'parecchi',
#   'occurrences': {'parecchi': 11, 'pareccci': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaed'),
#   'word': 'giorni',
#   'occurrences': {'giorni': 47, 'guiorni': 1, 'gixorni': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaee'),
#   'word': 'levate',
#   'occurrences': {'levate': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaef'),
#   'word': 'intorno',
#   'occurrences': {'intorno': 44}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf0'),
#   'word': 'altari',
#   'occurrences': {'altari': 6}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf1'),
#   'word': 'serena',
#   'occurrences': {'serena': 19}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf2'),
#   'word': 'vostre',
#   'occurrences': {'vostre': 48, 'vostne': 1, 'vosttre': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf3'),
#   'word': 'case',
#   'occurrences': {'case': 15}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf4'),
#   'word': 'ricordo',
#   'occurrences': {'ricordo': 42, 'rickrdo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf5'),
#   'word': 'vostro',
#   'occurrences': {'vostro': 46}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf6'),
#   'word': 'concittadino',
#   'occurrences': {'concittadino': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf7'),
#   'word': 'solcata',
#   'occurrences': {'solcata': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf8'),
#   'word': 'prodigi',
#   'occurrences': {'prodigi': 5, 'proyigi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faaf9'),
#   'word': 'pietà',
#   'occurrences': {'pietà': 58, 'pidetà': 1, 'pietc̀': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faafa'),
#   'word': 'religiosa',
#   'occurrences': {'religiosa': 55, 'relpigiosa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7faafb'),
#   'word': 'sentita',
#   'occurrences': {'sentita': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7faafc'),
#   'word': 'generosità',
#   'occurrences': {'generosità': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7faafd'),
#   'word': 'operosa',
#   'occurrences': {'operosa': 10}},
#  {'_id': ObjectId('60e030600d9eac679f7faafe'),
#   'word': 'costante',
#   'occurrences': {'costante': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7faaff'),
#   'word': 'questa',
#   'occurrences': {'questa': 402,
#    'queista': 1,
#    'quyesta': 1,
#    'queksta': 1,
#    'questi': 1,
#    'quesota': 1,
#    'euesta': 1,
#    'quesgta': 1,
#    'questxa': 1,
#    'questoa': 1,
#    'qufesta': 1,
#    'cuesta': 1,
#    'quensta': 1,
#    'qqesta': 1,
#    'quxspta': 1,
#    'quosta': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab00'),
#   'word': 'volta',
#   'occurrences': {'volta': 34, 'vojlta': 1, 'volita': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab01'),
#   'word': 'fece',
#   'occurrences': {'fece': 19}},
#  {'_id': ObjectId('60e030600d9eac679f7fab02'),
#   'word': "l\\'antico",
#   'occurrences': {"l\\'antico": 4, 'l\\antico': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fab03'),
#   'word': 'popolo',
#   'occurrences': {'popolo': 103, 'popolz': 1, 'pospolo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab04'),
#   'word': 'traendo',
#   'occurrences': {'traendo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab05'),
#   'word': 'piccolo',
#   'occurrences': {'piccolo': 6, 'pigcolo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab06'),
#   'word': 'davide',
#   'occurrences': {'davide': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7fab07'),
#   'word': 'dai',
#   'occurrences': {'dai': 68,
#    'dqi': 1,
#    'dcai': 1,
#    'dawi': 1,
#    'dabi': 1,
#    'daj': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab08'),
#   'word': 'pastori',
#   'occurrences': {'pastori': 11}},
#  {'_id': ObjectId('60e030600d9eac679f7fab09'),
#   'word': 'betlemme',
#   'occurrences': {'betlemme': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0a'),
#   'word': 'abbia',
#   'occurrences': {'abbia': 19, 'abbbia': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0b'),
#   'word': 'scelto',
#   'occurrences': {'scelto': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0c'),
#   'word': 'nuovo',
#   'occurrences': {'nuovo': 72, 'nunvo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0d'),
#   'word': 'sommo',
#   'occurrences': {'sommo': 14}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0e'),
#   'word': 'pontefice',
#   'occurrences': {'pontefice': 34, 'pontefict': 1, 'pobtefice': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab0f'),
#   'word': 'facendolo',
#   'occurrences': {'facendolo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab10'),
#   'word': 'depositario',
#   'occurrences': {'depositario': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fab11'),
#   'word': 'grande',
#   'occurrences': {'grande': 207,
#    'grrnde': 1,
#    'grnnde': 1,
#    'greande': 1,
#    'granfde': 1,
#    'ghande': 1,
#    'gfande': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab12'),
#   'word': 'tradizione',
#   'occurrences': {'tradizione': 27, 'triadizione': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab13'),
#   'word': 'apostolica',
#   'occurrences': {'apostolica': 66, 'apostmolica': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab14'),
#   'word': 'suggellata',
#   'occurrences': {'suggellata': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fab15'),
#   'word': 'dal',
#   'occurrences': {'dal': 168,
#    'eal': 1,
#    'ddl': 1,
#    'danl': 1,
#    'dao': 1,
#    'dul': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab16'),
#   'word': 'sangue',
#   'occurrences': {'sangue': 41, 'sanugue': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab17'),
#   'word': 'figliolo',
#   'occurrences': {'figliolo': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fab18'),
#   'word': 'tale',
#   'occurrences': {'tale': 46}},
#  {'_id': ObjectId('60e030600d9eac679f7fab19'),
#   'word': 'avvenimento',
#   'occurrences': {'avvenimento': 28}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1a'),
#   'word': 'parliamo',
#   'occurrences': {'parliamo': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1b'),
#   'word': 'obbligarci',
#   'occurrences': {'obbligarci': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1c'),
#   'word': 'sciogliere',
#   'occurrences': {'sciogliere': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1d'),
#   'word': 'calzari',
#   'occurrences': {'calzari': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1e'),
#   'word': "nell\\'atto",
#   'occurrences': {"nell\\'atto": 9}},
#  {'_id': ObjectId('60e030600d9eac679f7fab1f'),
#   'word': 'procedere',
#   'occurrences': {'procedere': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fab20'),
#   'word': 'roveto',
#   'occurrences': {'xoveto': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab21'),
#   'word': 'ardente',
#   'occurrences': {'ardente': 17}},
#  {'_id': ObjectId('60e030600d9eac679f7fab22'),
#   'word': 'carità',
#   'occurrences': {'carità': 113, 'caritmà': 1, 'carittà': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab23'),
#   'word': 'divina',
#   'occurrences': {'divina': 60, 'dilvina': 1, 'dlvina': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab24'),
#   'word': 'attende',
#   'occurrences': {'attende': 13}},
#  {'_id': ObjectId('60e030600d9eac679f7fab25'),
#   'word': 'consuma',
#   'occurrences': {'consuma': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fab26'),
#   'word': 'constatare',
#   'occurrences': {'constatare': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7fab27'),
#   'word': 'manifestazione',
#   'occurrences': {'manifestazione': 17}},
#  {'_id': ObjectId('60e030600d9eac679f7fab28'),
#   'word': 'bontà',
#   'occurrences': {'bontà': 31}},
#  {'_id': ObjectId('60e030600d9eac679f7fab29'),
#   'word': 'dio',
# ...
#   'word': 'incoraggiante',
#   'occurrences': {'incoraggiante': 11, 'incoraggnante': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad2f'),
#   'word': 'benedicente',
#   'occurrences': {'benedicente': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7fad30'),
#   'word': 'giornata',
#   'occurrences': {'giornata': 22}},
#  {'_id': ObjectId('60e030600d9eac679f7fad31'),
#   'word': 'ricordi',
#   'occurrences': {'ricordi': 29, 'ricorjdi': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad32'),
#   'word': 'immacolata',
#   'occurrences': {'immacolata': 26}},
#  {'_id': ObjectId('60e030600d9eac679f7fad33'),
#   'word': 'fanno',
#   'occurrences': {'fanno': 15}},
#  {'_id': ObjectId('60e030600d9eac679f7fad34'),
#   'word': 'esaltare',
#   'occurrences': {'esaltare': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7fad35'),
#   'word': 'tempio',
#   'occurrences': {'tempio': 34, 'tempxio': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad36'),
#   'word': 'vaticano',
#   'occurrences': {'vaticano': 50, 'vatilcano': 1, 'vhaticano': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad37'),
#   'word': 'quando',
#   'occurrences': {'quando': 44,
#    'quanhdo': 1,
#    'quandw': 1,
#    'tquando': 1,
#    'quanydo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad38'),
#   'word': '1\\',
#   'occurrences': {'1\\': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad39'),
#   'word': "'",
#   'occurrences': {"'": 38}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3a'),
#   'word': '18##',
#   'occurrences': {'18##': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3b'),
#   'word': 'ix',
#   'occurrences': {'ix': 20, 'fix': 1, 'iax': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3c'),
#   'word': 'leggeva',
#   'occurrences': {'leggeva': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3d'),
#   'word': 'bolla',
#   'occurrences': {'bolla': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3e'),
#   'word': 'definizione',
#   'occurrences': {'definizione': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fad3f'),
#   'word': 'dogmatica',
#   'occurrences': {'dogmaticoa': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad40'),
#   'word': 'raggio',
#   'occurrences': {'raggio': 7}},
#  {'_id': ObjectId('60e030600d9eac679f7fad41'),
#   'word': 'sole',
#   'occurrences': {'sole': 9}},
#  {'_id': ObjectId('60e030600d9eac679f7fad42'),
#   'word': 'irruppe',
#   'occurrences': {'irruppe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad43'),
#   'word': 'avvolse',
#   'occurrences': {'avvolse': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad44'),
#   'word': 'luce',
#   'occurrences': {'luce': 103, 'wluce': 1, 'mluce': 1, 'lume': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad45'),
#   'word': 'madre',
#   'occurrences': {'madre': 88, 'mwdre': 1, 'madree': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad46'),
#   'word': 'celeste',
#   'occurrences': {'celeste': 55, 'celxeste': 1, 'celeshe': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad47'),
#   'word': 'diffonde',
#   'occurrences': {'diffonde': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fad48'),
#   'word': 'trasmette',
#   'occurrences': {'trasmette': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad49'),
#   'word': 'letizia',
#   'occurrences': {'letizia': 49}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4a'),
#   'word': 'rafforza',
#   'occurrences': {'rafforza': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4b'),
#   'word': 'buone',
#   'occurrences': {'buone': 33}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4c'),
#   'word': 'volontà',
#   'occurrences': {'volontà': 43, 'volontxà': 1, 'voeontà': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4d'),
#   'word': 'affratella',
#   'occurrences': {'affratella': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4e'),
#   'word': 'animi',
#   'occurrences': {'animi': 15}},
#  {'_id': ObjectId('60e030600d9eac679f7fad4f'),
#   'word': 'rammentiamo',
#   'occurrences': {'rammentiamo': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad50'),
#   'word': "l\\'altro",
#   'occurrences': {"l\\'altro": 12}},
#  {'_id': ObjectId('60e030600d9eac679f7fad51'),
#   'word': 'celebrando',
#   'occurrences': {'celebrando': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad52'),
#   'word': 'mezzo',
#   'occurrences': {'mezzo': 30, 'vmezzo': 1, 'meztzo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad53'),
#   'word': 'secolo',
#   'occurrences': {'secolo': 36}},
#  {'_id': ObjectId('60e030600d9eac679f7fad54'),
#   'word': 'quella',
#   'occurrences': {'quella': 105, 'quelhla': 1, 'queella': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad55'),
#   'word': 'proclamazione',
#   'occurrences': {'proclamazione': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fad56'),
#   'word': 'apparve',
#   'occurrences': {'apparve': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad57'),
#   'word': 'giovanissimo',
#   'occurrences': {'giovanissimo': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad58'),
#   'word': 'emanazione',
#   'occurrences': {'emanazione': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad59'),
#   'word': 'dissipò',
#   'occurrences': {'dissipò': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5a'),
#   'word': 'volto',
#   'occurrences': {'volto': 16, 'volty': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5b'),
#   'word': 'traccia',
#   'occurrences': {'traccia': 3}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5c'),
#   'word': 'preoccupazione',
#   'occurrences': {'preoccupazione': 4}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5d'),
#   'word': 'gravi',
#   'occurrences': {'gravi': 29}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5e'),
#   'word': 'interessi',
#   'occurrences': {'interessi': 8}},
#  {'_id': ObjectId('60e030600d9eac679f7fad5f'),
#   'word': 'rese',
#   'occurrences': {'rese': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fad60'),
#   'word': 'splendente',
#   'occurrences': {'splendente': 15,
#    'splendenfte': 1,
#    'spjendente': 1,
#    'splendenxte': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad61'),
#   'word': 'quello',
#   'occurrences': {'quello': 50, 'quelli': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad62'),
#   'word': 'mosè',
#   'occurrences': {'mosè': 5}},
#  {'_id': ObjectId('60e030600d9eac679f7fad63'),
#   'word': 'sul',
#   'occurrences': {'sul': 71}},
#  {'_id': ObjectId('60e030600d9eac679f7fad64'),
#   'word': 'sinai',
#   'occurrences': {'sinai': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad65'),
#   'word': 'conforto',
#   'occurrences': {'conforto': 32}},
#  {'_id': ObjectId('60e030600d9eac679f7fad66'),
#   'word': 'benedizione',
#   'occurrences': {'benedizione': 78}},
#  {'_id': ObjectId('60e030600d9eac679f7fad67'),
#   'word': 'lei',
#   'occurrences': {'lei': 21}},
#  {'_id': ObjectId('60e030600d9eac679f7fad68'),
#   'word': 'prepararci',
#   'occurrences': {'prepararci': 2}},
#  {'_id': ObjectId('60e030600d9eac679f7fad69'),
#   'word': 'attendevano',
#   'occurrences': {'attendevano': 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad6a'),
#   'word': "quest\\'ultimo",
#   'occurrences': {"quest\\'ultimo": 1}},
#  {'_id': ObjectId('60e030600d9eac679f7fad6b'),
#   'word': 'margine',
#   'occurrences': {'margine': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad6c'),
#   'word': 'volle',
#   'occurrences': {'volle': 12}},
#  {'_id': ObjectId('60e030610d9eac679f7fad6d'),
#   'word': 'riservato',
#   'occurrences': {'riservato': 10}},
#  {'_id': ObjectId('60e030610d9eac679f7fad6e'),
#   'word': 'singolare',
#   'occurrences': {'singolare': 25}},
#  {'_id': ObjectId('60e030610d9eac679f7fad6f'),
#   'word': 'consacrare',
#   'occurrences': {'consacrare': 4}},
#  {'_id': ObjectId('60e030610d9eac679f7fad70'),
#   'word': 'lourdes',
#   'occurrences': {'lourdes': 16, 'lowrdes': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad71'),
#   'word': 'vastissimo',
#   'occurrences': {'vastissimo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad72'),
#   'word': 'sotterraneo',
#   'occurrences': {'sotterraneo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad73'),
#   'word': 'congiunge',
#   'occurrences': {'congiunge': 3}},
#  {'_id': ObjectId('60e030610d9eac679f7fad74'),
#   'word': 'unico',
#   'occurrences': {'unico': 10}},
#  {'_id': ObjectId('60e030610d9eac679f7fad75'),
#   'word': 'palpito',
#   'occurrences': {'palpito': 14}},
#  {'_id': ObjectId('60e030610d9eac679f7fad76'),
#   'word': 'entusiasmo',
#   'occurrences': {'entusiasmo': 6, 'eetusiasmo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad77'),
#   'word': 'x#',
#   'occurrences': {'x#': 3}},
#  {'_id': ObjectId('60e030610d9eac679f7fad78'),
#   'word': 'offrire',
#   'occurrences': {'offrire': 18}},
#  {'_id': ObjectId('60e030610d9eac679f7fad79'),
#   'word': 'redenti',
#   'occurrences': {'redenti': 4}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7a'),
#   'word': 'eleva',
#   'occurrences': {'eleva': 6}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7b'),
#   'word': 'divenuta',
#   'occurrences': {'divenuta': 8}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7c'),
#   'word': 'supplicazione',
#   'occurrences': {'supplicazione': 7, 'sugpplicazione': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7d'),
#   'word': 'affinche#',
#   'occurrences': {'affinche#': 75, 'affiqche#': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7e'),
#   'word': 'ottenga',
#   'occurrences': {'ottenga': 8, 'ottenge': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad7f'),
#   'word': 'sovrabbondanza',
#   'occurrences': {'sovrabbondanza': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad80'),
#   'word': 'favori',
#   'occurrences': {'favori': 8}},
#  {'_id': ObjectId('60e030610d9eac679f7fad81'),
#   'word': 'fiducioso',
#   'occurrences': {'fiducioso': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad82'),
#   'word': 'abbandono',
#   'occurrences': {'abbandono': 7}},
#  {'_id': ObjectId('60e030610d9eac679f7fad83'),
#   'word': 'preservi',
#   'occurrences': {'preservi': 2}},
#  {'_id': ObjectId('60e030610d9eac679f7fad84'),
#   'word': 'pericoli',
#   'occurrences': {'pericoli': 5, 'perizoli': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad85'),
#   'word': 'futuri',
#   'occurrences': {'futuri': 2}},
#  {'_id': ObjectId('60e030610d9eac679f7fad86'),
#   'word': 'costruire',
#   'occurrences': {'costruire': 4}},
#  {'_id': ObjectId('60e030610d9eac679f7fad87'),
#   'word': 'sabbia',
#   'occurrences': {'sabbia': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad88'),
#   'word': "dell\\'agitarci",
#   'occurrences': {"dell\\'agitarci": 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad89'),
#   'word': 'invano',
#   'occurrences': {'invano': 1, 'invalo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8a'),
#   'word': 'piuttosto',
#   'occurrences': {'piuttosto': 14}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8b'),
#   'word': 'chiarifichi',
#   'occurrences': {'chiarifichi': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8c'),
#   'word': 'menti',
#   'occurrences': {'menrti': 1, 'menti': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8d'),
#   'word': 'purifichi',
#   'occurrences': {'purifichi': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8e'),
#   'word': 'dia',
#   'occurrences': {'dia': 10}},
#  {'_id': ObjectId('60e030610d9eac679f7fad8f'),
#   'word': 'sicurezza',
#   'occurrences': {'sicurezza': 25, 'sicurezzz': 1, 'sicuiezza': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad90'),
#   'word': 'passi',
#   'occurrences': {'passi': 13}},
#  {'_id': ObjectId('60e030610d9eac679f7fad91'),
#   'word': "l\\'avvento",
#   'occurrences': {"l\\'avvento": 2}},
#  {'_id': ObjectId('60e030610d9eac679f7fad92'),
#   'word': 'regno',
#   'occurrences': {'regno': 37}},
#  {'_id': ObjectId('60e030610d9eac679f7fad93'),
#   'word': 'sulle',
#   'occurrences': {'sulle': 49, 'solle': 1, 'sulfe': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad94'),
#   'word': 'singole',
#   'occurrences': {'singole': 15, 'singode': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad95'),
#   'word': 'religiose',
#   'occurrences': {'religiose': 24}},
#  {'_id': ObjectId('60e030610d9eac679f7fad96'),
#   'word': 'civiche',
#   'occurrences': {'civiche': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad97'),
#   'word': "sull\\'intera",
#   'occurrences': {"sull\\'intera": 2}},
#  {'_id': ObjectId('60e030610d9eac679f7fad98'),
#   'word': 'umanità',
#   'occurrences': {'umanità': 15}},
#  {'_id': ObjectId('60e030610d9eac679f7fad99'),
#   'word': 'messa',
#   'occurrences': {'mezsa': 1, 'messa': 24, 'cmessa': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9a'),
#   'word': "nell\\'arcibasilica",
#   'occurrences': {"nell\\'arcibasilica": 3}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9b'),
#   'word': 'lateranense',
#   'occurrences': {'lateranense': 11}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9c'),
#   'word': 'domenica',
#   'occurrences': {'domenica': 134, 'domenoica': 1, 'zomenica': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9d'),
#   'word': '2#',
#   'occurrences': {'2#': 8}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9e'),
#   'word': 'novembre',
#   'occurrences': {'novembre': 30}},
#  {'_id': ObjectId('60e030610d9eac679f7fad9f'),
#   'word': '19#8',
#   'occurrences': {'19#8': 7}},
#  {'_id': ObjectId('60e030610d9eac679f7fada0'),
#   'word': 'venerabili',
#   'occurrences': {'venerabili': 87,
#    'veknerabili': 1,
#    'venerabuli': 1,
#    'venersabili': 1,
#    'veneratili': 1,
#    'venerabixli': 1,
#    'venexrabili': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fada1'),
#   'word': 'scambiato',
#   'occurrences': {'scambiato': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fada2'),
#   'word': 'soglie',
#   'occurrences': {'soglie': 6}},
#  {'_id': ObjectId('60e030610d9eac679f7fada3'),
#   'word': 'cattedrale',
#   'occurrences': {'cattedrale': 5}},
#  {'_id': ObjectId('60e030610d9eac679f7fada4'),
#   'word': 'signor',
#   'occurrences': {'signor': 11}},
#  {'_id': ObjectId('60e030610d9eac679f7fada5'),
#   'word': 'cardinale',
#   'occurrences': {'cardinale': 33}},
#  {'_id': ObjectId('60e030610d9eac679f7fada6'),
#   'word': 'arciprete',
#   'occurrences': {'arciprete': 3}},
#  {'_id': ObjectId('60e030610d9eac679f7fada7'),
#   'word': 'amiamo',
#   'occurrences': {'amiamo': 28, 'amiapmo': 1, 'amidamo': 1, 'amqamo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fada8'),
#   'word': 'aggiungere',
#   'occurrences': {'aggiungere': 6, 'aggiungerme': 1, 'aggiwngere': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fada9'),
#   'word': 'edificazione',
#   'occurrences': {'edificazione': 29}},
#  {'_id': ObjectId('60e030610d9eac679f7fadaa'),
#   'word': 'tre',
#   'occurrences': {'tre': 41}},
#  {'_id': ObjectId('60e030610d9eac679f7fadab'),
#   'word': 'pensieri',
#   'occurrences': {'pensieri': 31, 'pensiedri': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadac'),
#   'word': 'vorremmo',
#   'occurrences': {'vorremmo': 11}},
#  {'_id': ObjectId('60e030610d9eac679f7fadad'),
#   'word': 'pervenissero',
#   'occurrences': {'pervenissero': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadae'),
#   'word': 'eco',
#   'occurrences': {'eco': 11, 'ceco': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadaf'),
#   'word': 'due',
#   'occurrences': {'due': 88, 'dur': 1, 'xdue': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb0'),
#   'word': 'solenni',
#   'occurrences': {'solenni': 16, 'soqenni': 1, 'solenfi': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb1'),
#   'word': 'voci',
#   'occurrences': {'voci': 24}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb2'),
#   'word': 'risuonarono',
#   'occurrences': {'risuonarono': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb3'),
#   'word': 'sommi',
#   'occurrences': {'sommi': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb4'),
#   'word': 'pontefici',
#   'occurrences': {'pontefici': 14}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb5'),
#   'word': 'leone',
#   'occurrences': {'leone': 44}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb6'),
#   'word': 'gregorio',
#   'occurrences': {'gregorio': 29, 'gregoriv': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb7'),
#   'word': 'gloriosi',
#   'occurrences': {'gloriosi': 9}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb8'),
#   'word': 'ambedue',
#   'occurrences': {'ambedue': 5}},
#  {'_id': ObjectId('60e030610d9eac679f7fadb9'),
#   'word': 'dottori',
#   'occurrences': {'dottori': 11}},
#  {'_id': ObjectId('60e030610d9eac679f7fadba'),
#   'word': 'padri',
#   'occurrences': {'padri': 26}},
#  {'_id': ObjectId('60e030610d9eac679f7fadbb'),
#   'word': 'riflette',
#   'occurrences': {'riflette': 4}},
#  {'_id': ObjectId('60e030610d9eac679f7fadbc'),
#   'word': 'rito',
#   'occurrences': {'rito': 47, 'srito': 1, 'rdto': 1, 'ritmo': 1}},
#  {'_id': ObjectId('60e030610d9eac679f7fadbd'),
#   'word': 'odierno',
#   'occurrences': {'odierno': 10}},
#  {'_id': ObjectId('60e030610d9eac679f7fadbe'),
#   'word': 'alta',
#   'occurrences': {'alta': 25}},
#  ...]
