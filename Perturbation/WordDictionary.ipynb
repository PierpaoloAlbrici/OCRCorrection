# %%
import pymongo
import string
from tqdm.notebook import tqdm
from collections import Counter 

client = pymongo.MongoClient('mongodb://localhost:27017')
db = client['vatican']
dataset = db['phrasesDataset']
wordsDataset = db['wordsDataset']

docs = list(dataset.find())

# %%
#wordsDataset.drop()
wordsDataset.count()
# Out:
# C:\Users\piera\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
# 0

# %%
chars = "solenità'd\mczkwfhjuxgbvrpyq8192!#"
CHAR_INDEX = dict((c, i) for i, c in enumerate(chars))

def preprocess(s):
    out = ""
    for c in s.lower():
        if c in CHAR_INDEX.keys():
            out += c
        else:
            out += '#'
    return "".join(out)

# %%
word = dict()

for i, d in tqdm(enumerate(docs)):
    for j, s in enumerate(d['sentences']):
        for k, w in enumerate(s[0]):
            word.setdefault(s[1][k], []).append(preprocess(w))            
            
for wk in tqdm(word.keys()):
    item = dict(Counter(word.get(wk)))
    wordsDataset.insert_one({'word': preprocess(wk), 'occurrences': item})
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14567.0), HTML(value='')))

# %%
a = list(wordsDataset.find())
a
# Out:
# [{'_id': ObjectId('60e574486e4986b0d41c6255'),
#   'word': 'solennità',
#   'occurrences': {'solennità': 38,
#    "solennita'̀": 2,
#    'soleennità': 1,
#    'solenkità': 1,
#    'solennitxà': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6256'),
#   'word': "dell\\'immacolata",
#   'occurrences': {"dell\\'immacolata": 12}},
#  {'_id': ObjectId('60e574486e4986b0d41c6257'),
#   'word': 'concezione',
#   'occurrences': {'concezione': 7, 'consezione': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6258'),
#   'word': 'della',
#   'occurrences': {'della': 1716,
#    'adella': 2,
#    'odella': 1,
#    'delfla': 1,
#    'jdella': 1,
#    'dellm': 1,
#    'dellla': 1,
#    'deplla': 1,
#    'dellxa': 1,
#    'idella': 1,
#    'kdella': 1,
#    'dellna': 2,
#    'duella': 1,
#    'dexlla': 1,
#    'dalla': 1,
#    'deilla': 1,
#    'delra': 1,
#    'dcebla': 1,
#    'dflla': 1,
#    'dellpa': 1,
#    'dellb': 2,
#    'dellqa': 1,
#    'lella': 2,
#    'desla': 1,
#    'dnlla': 1,
#    'delli': 1,
#    'dglla': 1,
#    'devlla': 1,
#    'delxa': 1,
#    'dewla': 1,
#    'xdella': 1,
#    'sdella': 1,
#    'delloa': 1,
#    'mdella': 1,
#    'delula': 1,
#    'edella': 1,
#    'dbella': 1,
#    'uella': 1,
#    'demlla': 1,
#    'tella': 1,
#    'dellea': 1,
#    'dnella': 1,
#    'deltla': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6259'),
#   'word': 'beata',
#   'occurrences': {'beata': 16}},
#  {'_id': ObjectId('60e574486e4986b0d41c625a'),
#   'word': 'vergine',
#   'occurrences': {'vergine': 21, 'vezrgine': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c625b'),
#   'word': 'maria',
#   'occurrences': {'maria': 136,
#    'maaria': 1,
#    'marzia': 1,
#    'mnria': 1,
#    'maroia': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c625c'),
#   'word': 'omelia',
#   'occurrences': {'omelia': 43, 'omllia': 1, 'omelira': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c625d'),
#   'word': 'del',
#   'occurrences': {'del': 1486,
#    'dtl': 2,
#    'doel': 3,
#    'deg': 1,
#    'den': 2,
#    'ddel': 1,
#    'dehl': 1,
#    'deql': 1,
#    'dyel': 1,
#    'dlel': 2,
#    'zdel': 1,
#    'adel': 1,
#    'dkel': 1,
#    'dsel': 2,
#    'yel': 1,
#    'deh': 1,
#    'jdel': 1,
#    'ydel': 1,
#    'ddl': 1,
#    'dml': 1,
#    'dal': 1,
#    'denl': 1,
#    'deol': 1,
#    'dmel': 1,
#    'deq': 1,
#    'fel': 1,
#    'dnl': 1,
#    'decl': 1,
#    'dzl': 1,
#    'oel': 1,
#    'dev': 1,
#    'devl': 1,
#    'dael': 1,
#    'der': 1,
#    'derl': 1,
#    'udel': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c625e'),
#   'word': 'santo',
#   'occurrences': {'santo': 155, 'panto': 1, 'lsanto': 1, 'sanbo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c625f'),
#   'word': 'padre',
#   'occurrences': {'padre': 111, 'padse': 1, 'pabre': 1, 'paddre': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6260'),
#   'word': 'giovanni',
#   'occurrences': {'gioqanni': 1,
#    'giovanni': 100,
#    'gjovanni': 1,
#    'gioovanni': 1,
#    'giovaani': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6261'),
#   'word': 'xxiii',
#   'occurrences': {'xxiii': 22}},
#  {'_id': ObjectId('60e574486e4986b0d41c6262'),
#   'word': 'basilica',
#   'occurrences': {'basilica': 81, 'basiwlica': 1, 'basblica': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6263'),
#   'word': 'vaticana',
#   'occurrences': {'vaticana': 101,
#    'valticana': 1,
#    'vatiecana': 1,
#    'vaticagna': 1,
#    'vaticanp': 1,
#    'vaticxna': 1,
#    'vathcana': 1,
#    'vaticxana': 1,
#    'vbaticana': 1,
#    'vatwicana': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6264'),
#   'word': 'lunedì',
#   'occurrences': {'lunedì': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6265'),
#   'word': '#',
#   'occurrences': {'#': 9416}},
#  {'_id': ObjectId('60e574486e4986b0d41c6266'),
#   'word': '8',
#   'occurrences': {'8': 33}},
#  {'_id': ObjectId('60e574486e4986b0d41c6267'),
#   'word': 'dicembre',
#   'occurrences': {'dicembre': 31}},
#  {'_id': ObjectId('60e574486e4986b0d41c6268'),
#   'word': '1982',
#   'occurrences': {'1982': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6269'),
#   'word': 'diletti',
#   'occurrences': {'diletti': 167,
#    'divletti': 1,
#    'disetti': 1,
#    'dilgtti': 1,
#    'diwletti': 1,
#    'diletpti': 1,
#    'ailetti': 1,
#    'liletti': 1,
#    'dilettci': 1,
#    'dilxetti': 1,
#    'diletwti': 1,
#    'dilxtti': 1,
#    'dioletti': 1,
#    'dieetti': 1,
#    'dilettz': 1,
#    'cdiletti': 1,
#    'diwetti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c626a'),
#   'word': 'figli',
#   'occurrences': {'figli': 262,
#    'figlz': 1,
#    'jigli': 1,
#    'figfli': 1,
#    'iigli': 1,
#    'yfigli': 1,
#    'cigli': 1,
#    'fijli': 1,
#    'fxgli': 1,
#    'fignli': 1,
#    'fligli': 1,
#    'figui': 1,
#    'figyli': 1,
#    'fiigli': 1,
#    'fiygli': 1,
#    'filli': 1,
#    'figqli': 1,
#    'fizlxi': 1,
#    'feigli': 1,
#    'fiwgli': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c626b'),
#   'word': 'nostri',
#   'occurrences': {'nostri': 155,
#    'nostui': 1,
#    'nosari': 1,
#    'nqostri': 1,
#    'nomstri': 1,
#    'nostrf': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c626c'),
#   'word': '!',
#   'occurrences': {'!': 271}},
#  {'_id': ObjectId('60e574486e4986b0d41c626d'),
#   'word': 'per',
#   'occurrences': {'per': 1112,
#    'pepr': 1,
#    'mer': 1,
#    'puer': 1,
#    'peg': 1,
#    'wper': 1,
#    'pzr': 1,
#    'yer': 1,
#    'oper': 1,
#    'pewr': 1,
#    'pesr': 1,
#    'pep': 1,
#    'lper': 1,
#    'cper': 2,
#    'pmer': 1,
#    'bper': 1,
#    'pem': 1,
#    'pet': 1,
#    'uper': 2,
#    'mper': 1,
#    'pjer': 1,
#    'pedr': 1,
#    'pbr': 1,
#    'pekr': 1,
#    'pef': 1,
#    'pir': 1,
#    'qer': 1,
#    'plr': 1,
#    'pper': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c626e'),
#   'word': 'ogni',
#   'occurrences': {'ogni': 211,
#    'ognwi': 1,
#    'hgni': 1,
#    'fgni': 1,
#    'ogpni': 1,
#    'ogmni': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c626f'),
#   'word': 'giorno',
#   'occurrences': {'giorno': 64}},
#  {'_id': ObjectId('60e574486e4986b0d41c6270'),
#   'word': 'vita',
#   'occurrences': {'vita': 316,
#    'tita': 1,
#    'viti': 1,
#    'avita': 1,
#    'rita': 1,
#    'vcta': 1,
#    'vitm': 1,
#    'viyta': 1,
#    'vitt': 1,
#    'xvita': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6271'),
#   'word': 'il',
#   'occurrences': {'iq': 1,
#    'il': 1871,
#    'kl': 1,
#    'vil': 1,
#    'im': 1,
#    'hil': 1,
#    'idl': 2,
#    'bl': 1,
#    'ikl': 1,
#    'in': 1,
#    'icl': 1,
#    'yl': 1,
#    'yil': 1,
#    'ix': 1,
#    'jil': 1,
#    'nql': 1,
#    'dil': 1,
#    'pil': 1,
#    'iul': 1,
#    'fil': 1,
#    'if': 1,
#    'io': 1,
#    'ial': 1,
#    'ik': 2,
#    'ir': 1,
#    'ic': 1,
#    'qil': 2,
#    'ig': 1,
#    'ij': 1,
#    'wl': 1,
#    'xl': 1,
#    'cl': 1,
#    'iy': 1,
#    'ol': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6272'),
#   'word': 'signore',
#   'occurrences': {'signore': 204,
#    'fsignore': 1,
#    'signozre': 1,
#    'spignore': 1,
#    'signort': 1,
#    'signdre': 1,
#    'tignore': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6273'),
#   'word': 'riserva',
#   'occurrences': {'riserva': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6274'),
#   'word': 'alle',
#   'occurrences': {'alle': 172, 'allfe': 1, 'ally': 1, 'alee': 1, 'olle': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6275'),
#   'word': 'anime',
#   'occurrences': {'anime': 118, 'anpime': 1, 'animi': 1, 'apime': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6276'),
#   'word': 'nostre',
#   'occurrences': {'nostre': 80,
#    'nostrd': 1,
#    'nostye': 1,
#    'nosxre': 1,
#    'nvstre': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6277'),
#   'word': 'le',
#   'occurrences': {'le': 826,
#    're': 1,
#    'lne': 2,
#    'lce': 1,
#    'mle': 2,
#    'lre': 1,
#    'vle': 1,
#    'ls': 1,
#    'lt': 1,
#    'rle': 1,
#    'de': 1,
#    'lye': 1,
#    'ale': 1,
#    'ile': 1,
#    'lxe': 1,
#    'lm': 1,
#    'hle': 1,
#    'lbe': 1,
#    'te': 2,
#    'wle': 1,
#    'ln': 1,
#    'lge': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6278'),
#   'word': 'sue',
#   'occurrences': {'sue': 76, 'suge': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6279'),
#   'word': 'consolazioni',
#   'occurrences': {'consolazioni': 9, 'consolazisni': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c627a'),
#   'word': 'e',
#   'occurrences': {'e': 4315}},
#  {'_id': ObjectId('60e574486e4986b0d41c627b'),
#   'word': 'grazie',
#   'occurrences': {'grazie': 22}},
#  {'_id': ObjectId('60e574486e4986b0d41c627c'),
#   'word': '#',
#   'occurrences': {'#': 3681}},
#  {'_id': ObjectId('60e574486e4986b0d41c627d'),
#   'word': 'questo',
#   'occurrences': {'questo': 446,
#    'quisto': 1,
#    'qkesto': 1,
#    'quesrto': 1,
#    'questto': 1,
#    'qusesto': 1,
#    'quvesto': 1,
#    'bquesto': 1,
#    'qyesto': 1,
#    'qkuesto': 1,
#    'qtuesto': 1,
#    'quesato': 1,
#    'qpesto': 1,
#    'qussto': 1,
#    'quesno': 1,
#    'qcestlo': 1,
#    'qoesto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c627e'),
#   'word': 'dedicato',
#   'occurrences': {'dedicato': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c627f'),
#   'word': 'al',
#   'occurrences': {'al': 575,
#    'ai': 1,
#    'aal': 1,
#    'acl': 1,
#    'as': 1,
#    'tl': 2,
#    'am': 1,
#    'aa': 1,
#    'jl': 1,
#    'ajl': 1,
#    'ul': 1,
#    'apl': 1,
#    'ral': 1,
#    'vl': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6280'),
#   'word': 'culto',
#   'occurrences': {'culto': 43, 'cultzo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6281'),
#   'word': 'di',
#   'occurrences': {'di': 4522,
#    'bdi': 1,
#    'vdi': 1,
#    'dbi': 1,
#    'dli': 1,
#    'gdi': 3,
#    'dl': 2,
#    'dm': 1,
#    'dhi': 1,
#    'pi': 1,
#    'ni': 4,
#    'ddi': 2,
#    'dr': 3,
#    'ldi': 2,
#    'dgi': 3,
#    'dai': 1,
#    'edi': 2,
#    'oi': 1,
#    'odi': 1,
#    'wi': 1,
#    'xdi': 1,
#    'ei': 1,
#    'dc': 1,
#    'dt': 2,
#    'dji': 3,
#    'sdi': 2,
#    'dn': 2,
#    'ci': 1,
#    'ds': 1,
#    'dmi': 2,
#    'kdi': 2,
#    'dri': 2,
#    'dk': 2,
#    'zi': 2,
#    'wdi': 1,
#    'ydi': 2,
#    'idi': 1,
#    'ai': 1,
#    'dxi': 1,
#    'doi': 2,
#    'dni': 3,
#    'adi': 2,
#    'hdi': 1,
#    'dti': 1,
#    'de': 1,
#    'dvi': 1,
#    'qi': 1,
#    'hi': 1,
#    'dsi': 1,
#    'ji': 1,
#    'dui': 2,
#    'vi': 1,
#    'tdi': 1,
#    'xi': 1,
#    'dci': 1,
#    'ti': 1,
#    'dki': 1,
#    'dv': 1,
#    'df': 1,
#    'ri': 1,
#    'db': 1,
#    'li': 1,
#    'rdi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6282'),
#   'word': 'nel',
#   'occurrences': {'nel': 394,
#    'ncl': 1,
#    'nerl': 1,
#    'nbl': 1,
#    'nejl': 1,
#    'neel': 1,
#    'nwel': 1,
#    'net': 1,
#    'nuel': 1,
#    'oel': 1,
#    'nex': 1,
#    'mel': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6283'),
#   'word': 'suo',
#   'occurrences': {'suo': 285,
#    'ysuo': 1,
#    'subo': 1,
#    'shxo': 1,
#    'kuo': 1,
#    'fuo': 1,
#    'suno': 1,
#    'sufo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6284'),
#   'word': 'altissimo',
#   'occurrences': {'altissimo': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c6285'),
#   'word': 'privilegio',
#   'occurrences': {'privilegio': 7, 'prkvilegio': 1, 'privilegie': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6286'),
#   'word': "dell\\'immacolato",
#   'occurrences': {"dell\\'immacolato": 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6287'),
#   'word': 'concepimento',
#   'occurrences': {'concepimento': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c6288'),
#   'word': 'è',
#   'occurrences': {'è': 894,
#    'oè': 1,
#    'ec̀': 1,
#    "e'̀": 11,
#    'ej': 1,
#    'm̀': 1,
#    'eb̀': 1,
#    'b̀': 1,
#    'j̀': 1,
#    'ep̀': 1,
#    'à': 2,
#    'l̀': 1,
#    'eẁ': 1,
#    'v̀': 2,
#    'd̀': 1,
#    'eq̀': 1,
#    'ò': 2,
#    'ì': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6289'),
#   'word': 'nostro',
#   'occurrences': {'nostro': 331,
#    'nosxro': 1,
#    'kostro': 1,
#    'novtro': 1,
#    'nostruo': 1,
#    'nosxtro': 1,
#    'nlostro': 1,
#    'nogtro': 1,
#    'nsstro': 1,
#    'xnostro': 1,
#    'noastro': 1,
#    'nhostro': 1,
#    'nonstro': 1,
#    'nostrm': 1,
#    'nostto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628a'),
#   'word': 'spirito',
#   'occurrences': {'spirito': 187, 'bspirito': 1, 'cpirito': 1, 'spiritf': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628b'),
#   'word': 'uno',
#   'occurrences': {'uno': 42, 'xuno': 1, 'nno': 1, 'unmo': 1, 'ono': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628c'),
#   'word': 'dei',
#   'occurrences': {'dei': 624,
#    'den': 1,
#    'dedi': 1,
#    'deoi': 1,
#    'dgei': 1,
#    'cei': 1,
#    'rei': 1,
#    'deqi': 1,
#    'dwi': 1,
#    'deei': 1,
#    'dxi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628d'),
#   'word': 'più',
#   'occurrences': {'più': 469,
#    'piv̀': 1,
#    'xpiù': 1,
#    'piul': 1,
#    'pid̀': 1,
#    'mpiù': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628e'),
#   'word': 'fausti',
#   'occurrences': {'fausti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c628f'),
#   'word': 'questi',
#   'occurrences': {'questi': 114, 'questoi': 1, 'qdesti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6290'),
#   'word': 'ultimi',
#   'occurrences': {'ultimi': 10, 'uztimi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6291'),
#   'word': 'mesi',
#   'occurrences': {'mesi': 12}},
#  {'_id': ObjectId('60e574486e4986b0d41c6292'),
#   'word': 'la',
#   'occurrences': {'la': 2162,
#    'ila': 1,
#    'mla': 1,
#    'pa': 1,
#    'nla': 1,
#    'na': 2,
#    'ola': 2,
#    'sla': 2,
#    'ya': 1,
#    'lda': 2,
#    'va': 1,
#    'ea': 1,
#    'gla': 1,
#    'oa': 1,
#    'lp': 1,
#    'lsh': 1,
#    'fa': 1,
#    'lra': 2,
#    'ala': 2,
#    'ua': 1,
#    'lca': 2,
#    'lja': 1,
#    'lr': 1,
#    'jla': 1,
#    'lba': 1,
#    'lj': 1,
#    'bla': 1,
#    'qa': 1,
#    'lwa': 2,
#    'qla': 2,
#    'lv': 1,
#    'pla': 1,
#    'lea': 1,
#    'lxa': 1,
#    'kla': 1,
#    'ma': 3,
#    'fla': 1,
#    'lla': 2,
#    'lna': 1,
#    'lfa': 1,
#    'ka': 1,
#    'tla': 2,
#    'lu': 1,
#    'lt': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6293'),
#   'word': 'vostra',
#   'occurrences': {'vostra': 62, 'vostbra': 1, 'qvostra': 1, 'vlstra': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6294'),
#   'word': 'presenza',
#   'occurrences': {'presenza': 29, 'precenza': 1, 'prtesenza': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6295'),
#   'word': 'cari',
#   'occurrences': {'cari': 28, 'carb': 1, 'icari': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6296'),
#   'word': 'fratelli',
#   'occurrences': {'fratelli': 166,
#    'fratellyi': 1,
#    'fratello': 1,
#    'fratelrli': 1,
#    'foratelli': 1,
#    'fratxlli': 1,
#    'frateulli': 1,
#    'fratwlli': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6297'),
#   'word': 'bergamo',
#   'occurrences': {'bergamo': 20, 'berxamo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6298'),
#   'word': 'circostanze',
#   'occurrences': {'circostanze': 24, 'cdircostanze': 1, 'circzstanze': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6299'),
#   'word': 'che',
#   'occurrences': {'che': 2049,
#    'chf': 1,
#    'eche': 2,
#    'chge': 2,
#    'fche': 2,
#    'jhe': 1,
#    'dhe': 1,
#    'hhe': 1,
#    'chd': 1,
#    'chi': 1,
#    'cce': 1,
#    'chfe': 1,
#    'cee': 2,
#    'chie': 1,
#    'chhe': 1,
#    'she': 1,
#    'ache': 1,
#    'cqe': 1,
#    'chv': 1,
#    'chh': 1,
#    'chj': 2,
#    'coe': 1,
#    'chee': 1,
#    'chxe': 1,
#    'cfe': 1,
#    'chle': 1,
#    'qhe': 1,
#    'cxhe': 1,
#    'bche': 1,
#    'chme': 1,
#    'cye': 1,
#    'uche': 1,
#    'tche': 1,
#    'rche': 1,
#    'chg': 1,
#    'ehe': 1,
#    'vche': 1,
#    'cve': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c629a'),
#   'word': "l\\'hanno",
#   'occurrences': {"l\\'hanno": 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c629b'),
#   'word': 'effettuata',
#   'occurrences': {'effettuata': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c629c'),
#   'word': 'con',
#   'occurrences': {'con': 612,
#    'cyn': 1,
#    'cor': 1,
#    'coh': 1,
#    'chon': 1,
#    'icon': 1,
#    'cmon': 1,
#    'coc': 1,
#    'dcon': 1,
#    'cox': 1,
#    'wcon': 1,
#    'jcon': 1,
#    'cbon': 1,
#    'xcon': 1,
#    'jon': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c629d'),
#   'word': 'cui',
#   'occurrences': {'cui': 302,
#    'cuxi': 1,
#    'culi': 1,
#    'cpi': 1,
#    'mcui': 1,
#    'cufi': 1,
#    'cut': 1,
#    'rcui': 1,
#    'sui': 1,
#    'cuii': 1,
#    'cpui': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c629e'),
#   'word': 'si',
#   'occurrences': {'si': 605,
#    'su': 1,
#    'vsi': 2,
#    'bsi': 1,
#    'soi': 1,
#    'zi': 1,
#    'wsi': 1,
#    'xi': 1,
#    'tsi': 1,
#    'sx': 1,
#    'wi': 1,
#    'psi': 1,
#    'sf': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c629f'),
#   'word': 'afferma',
#   'occurrences': {'afferma': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a0'),
#   'word': 'sotto',
#   'occurrences': {'sotto': 49}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a1'),
#   'word': 'queste',
#   'occurrences': {'queste': 82, 'queszte': 1, 'questme': 1, 'quewte': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a2'),
#   'word': 'magnifiche',
#   'occurrences': {'magnifiche': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a3'),
#   'word': 'volte',
#   'occurrences': {'volte': 24}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a4'),
#   'word': 'innanzi',
#   'occurrences': {'innanzi': 51, 'innawnzi': 1, 'yinnanzi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a5'),
#   'word': 'a',
#   'occurrences': {'a': 1523}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a6'),
#   'word': 'tanti',
#   'occurrences': {'tanti': 44, 'tanhi': 1, 'tanthi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a7'),
#   'word': 'altri',
#   'occurrences': {'altri': 60}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a8'),
#   'word': 'tutti',
#   'occurrences': {'tutti': 392,
#    'tuttl': 1,
#    'cutti': 1,
#    'tubti': 1,
#    'xtutti': 1,
#    'tuttli': 1,
#    'tuttji': 1,
#    'tqutti': 1,
#    'tutto': 1,
#    'titti': 1,
#    'tutoti': 1,
#    'tuttm': 1,
#    'tugtti': 1,
#    'tuttd': 1,
#    'kutti': 1,
#    'tuttmi': 1,
#    'txutti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62a9'),
#   'word': 'nella',
#   'occurrences': {'nella': 438,
#    'nrella': 1,
#    'neklla': 1,
#    'nellz': 1,
#    'nelma': 1,
#    'nzlla': 1,
#    'nglla': 1,
#    'pella': 1,
#    'sella': 1,
#    'njlla': 1,
#    'nvella': 1,
#    'nlella': 1,
#    'qella': 1,
#    'nellma': 1,
#    'nelwa': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62aa'),
#   'word': 'fede',
#   'occurrences': {'fede': 96, 'oede': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ab'),
#   'word': 'appartenenti',
#   'occurrences': {'appartenenti': 13}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ac'),
#   'word': 'diverse',
#   'occurrences': {'diverse': 9, 'diverle': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ad'),
#   'word': 'diocesi',
#   'occurrences': {'diocesi': 43, 'diuocesi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ae'),
#   'word': "d\\'italia",
#   'occurrences': {"d\\'italia": 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c62af'),
#   'word': 'mondo',
#   'occurrences': {'mondo': 309,
#    'cmondo': 1,
#    'mondto': 1,
#    'mmondo': 3,
#    'monduo': 1,
#    'mondbo': 1,
#    'mwndo': 1,
#    'mwondo': 1,
#    'moqndo': 1,
#    'mondy': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b0'),
#   'word': 'i',
#   'occurrences': {'i': 810}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b1'),
#   'word': 'occhi',
#   'occurrences': {'occhi': 51}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b2'),
#   'word': 'cuore',
#   'occurrences': {'cuore': 142,
#    'ocuore': 1,
#    'cuorfe': 1,
#    'cuorle': 2,
#    'cuoke': 1,
#    'cuorke': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b3'),
#   'word': 'motivo',
#   'occurrences': {'motivo': 40, 'nmotivo': 1, 'mktivo': 1, 'mothivo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b4'),
#   'word': 'gioia',
#   'occurrences': {'gioia': 41, 'mgioia': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b5'),
#   'word': 'composta',
#   'occurrences': {'composta': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b6'),
#   'word': 'profonda',
#   'occurrences': {'profonda': 21}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b7'),
#   'word': 'ma',
#   'occurrences': {'ma': 294,
#    'mn': 1,
#    'mr': 1,
#    'fma': 1,
#    'fa': 1,
#    'mq': 1,
#    'zma': 1,
#    'qma': 1,
#    'nma': 1,
#    'maa': 1,
#    'my': 1,
#    'mi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b8'),
#   'word': 'straordinariamente',
#   'occurrences': {'straordinariamente': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62b9'),
#   'word': 'benedetta',
#   'occurrences': {'benedetta': 16, 'benedqetta': 1, 'bencedetta': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ba'),
#   'word': 'vi',
#   'occurrences': {'vi': 265, 'zvi': 1, 'wvi': 1, 'bvi': 1, 'vj': 1, 'vei': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62bb'),
#   'word': 'ringraziamo',
#   'occurrences': {'ringraziamo': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c62bc'),
#   'word': 'già',
#   'occurrences': {'già': 54, 'gial': 1, 'ghià': 1, 'gjià': 1, 'giyà': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62bd'),
#   'word': 'ci',
#   'occurrences': {'ci': 446,
#    'nci': 1,
#    'mci': 1,
#    'zi': 3,
#    'yi': 1,
#    'cci': 1,
#    'co': 1,
#    'cw': 1,
#    'cei': 2,
#    'hi': 1,
#    'cl': 1,
#    'li': 1,
#    'ici': 1,
#    'jci': 1,
#    'cmi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62be'),
#   'word': 'preme',
#   'occurrences': {'preme': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c62bf'),
#   'word': 'effondere',
#   'occurrences': {'effzndere': 1, 'effondere': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c0'),
#   'word': 'piene',
#   'occurrences': {'piene': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c1'),
#   'word': 'mani',
#   'occurrences': {'mani': 29, 'zmani': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c2'),
#   'word': 'sopra',
#   'occurrences': {'sopra': 47}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c3'),
#   'word': 'voi',
#   'occurrences': {'voi': 225,
#    'vos': 1,
#    'vodi': 1,
#    'veoi': 1,
#    'uvoi': 1,
#    'voa': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c4'),
#   'word': 'primizia',
#   'occurrences': {'primizia': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c5'),
#   'word': 'delle',
#   'occurrences': {'delle': 365,
#    'ddelle': 1,
#    'devle': 1,
#    'dxelle': 1,
#    'gdelll': 1,
#    'dtlle': 1,
#    'nelle': 1,
#    'delde': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c6'),
#   'word': 'benedizioni',
#   'occurrences': {'benedizioni': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c7'),
#   'word': 'gratitudine',
#   'occurrences': {'gratitudine': 13}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c8'),
#   'word': 'presenti',
#   'occurrences': {'presenti': 21}},
#  {'_id': ObjectId('60e574486e4986b0d41c62c9'),
#   'word': 'quanti',
#   'occurrences': {'quanti': 82, 'qualnti': 1, 'qutanti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ca'),
#   'word': 'rappresentate',
#   'occurrences': {'rappresentate': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c62cb'),
#   'word': 'portate',
#   'occurrences': {'portate': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c62cc'),
#   'word': 'viva',
#   'occurrences': {'viva': 34}},
#  {'_id': ObjectId('60e574486e4986b0d41c62cd'),
#   'word': 'vibrante',
#   'occurrences': {'vibrante': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ce'),
#   'word': 'essa',
#   'occurrences': {'essa': 74, 'ersa': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62cf'),
#   'word': 'volge',
#   'occurrences': {'volge': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d0'),
#   'word': 'innanzitutto',
#   'occurrences': {'innanzitutto': 17, 'innanzituttvo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d1'),
#   'word': 'venerato',
#   'occurrences': {'venerato': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d2'),
#   'word': 'fratello',
#   'occurrences': {'fratello': 18, 'fratollo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d3'),
#   'word': 'figlio',
#   'occurrences': {'figlio': 29}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d4'),
#   'word': 'monsignor',
#   'occurrences': {'monsignor': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d5'),
#   'word': 'giuseppe',
#   'occurrences': {'giuseppe': 14}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d6'),
#   'word': 'piazzi',
#   'occurrences': {'piazzi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d7'),
#   'word': 'degnissimo',
#   'occurrences': {'degnissimo': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d8'),
#   'word': 'tanto',
#   'occurrences': {'tanto': 62, 'ttanto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62d9'),
#   'word': 'caro',
#   'occurrences': {'caro': 20}},
#  {'_id': ObjectId('60e574486e4986b0d41c62da'),
#   'word': 'ed',
#   'occurrences': {'ed': 451,
#    'med': 1,
#    'ezd': 2,
#    'eed': 1,
#    'fed': 1,
#    'ebd': 1,
#    'wed': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62db'),
#   'word': 'amato',
#   'occurrences': {'amato': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c62dc'),
#   'word': 'presule',
#   'occurrences': {'presule': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c62dd'),
#   'word': 'nostra',
#   'occurrences': {'nostra': 372,
#    'nosthra': 1,
#    'nnostra': 1,
#    'nostrd': 1,
#    'noswtra': 1,
#    'nzstra': 1,
#    'dnostra': 1,
#    'nosvtra': 1,
#    'noztra': 1,
#    'nospra': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62de'),
#   'word': '#',
#   'occurrences': {'#': 570}},
#  {'_id': ObjectId('60e574486e4986b0d41c62df'),
#   'word': 'ai',
#   'occurrences': {'ai': 228, 'rai': 1, 'as': 1, 'aai': 1, 'agi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e0'),
#   'word': 'signori',
#   'occurrences': {'signori': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e1'),
#   'word': 'canonici',
#   'occurrences': {'canonici': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e2'),
#   'word': 'ceto',
#   'occurrences': {'ceto': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e3'),
#   'word': 'fu',
#   'occurrences': {'fu': 91, 'gfu': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e4'),
#   'word': 'così',
#   'occurrences': {'così': 202,
#    'codsì': 1,
#    'cosẁ': 1,
#    'cosit̀': 1,
#    "cosi'̀": 1,
#    'cosin': 1,
#    'cosil̀': 1,
#    'coosì': 1,
#    'cossì': 1,
#    'caosì': 1,
#    'coshì': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e5'),
#   'word': 'appartenere',
#   'occurrences': {'appartenere': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e6'),
#   'word': 'anche',
#   'occurrences': {'anche': 216,
#    'afnche': 1,
#    'anuche': 1,
#    'panche': 1,
#    'dnche': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e7'),
#   'word': 'se',
#   'occurrences': {'se': 109, 'sce': 1, 'mse': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e8'),
#   'word': 'semplice',
#   'occurrences': {'semplice': 26}},
#  {'_id': ObjectId('60e574486e4986b0d41c62e9'),
#   'word': 'titolo',
#   'occurrences': {'titolo': 27}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ea'),
#   'word': 'onore',
#   'occurrences': {'onore': 65, 'ononre': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62eb'),
#   'word': 'anni',
#   'occurrences': {'anni': 79}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ec'),
#   'word': 'parroci',
#   'occurrences': {'parroci': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ed'),
#   'word': 'sacerdoti',
#   'occurrences': {'sacerdoti': 48}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ee'),
#   'word': 'venuti',
#   'occurrences': {'venuti': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ef'),
#   'word': 'sacrificio',
#   'occurrences': {'sacrificio': 49}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f0'),
#   'word': 'personale',
#   'occurrences': {'personale': 27}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f1'),
#   'word': 'in',
#   'occurrences': {'in': 1267,
#    'iwn': 2,
#    'uin': 1,
#    'hn': 2,
#    'ein': 2,
#    'sn': 1,
#    'ij': 1,
#    'ain': 1,
#    'ik': 2,
#    'ic': 2,
#    'cin': 1,
#    'din': 1,
#    'kn': 1,
#    'iin': 1,
#    'ibn': 1,
#    'ih': 1,
#    'win': 1,
#    'imn': 1,
#    'zn': 1,
#    'tin': 1,
#    'an': 1,
#    'ien': 1,
#    'ign': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f2'),
#   'word': 'eletta',
#   'occurrences': {'eletta': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f3'),
#   'word': 'schiera',
#   'occurrences': {'schiera': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f4'),
#   'word': 'salutare',
#   'occurrences': {'salutare': 16}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f5'),
#   'word': 'loro',
#   'occurrences': {'loro': 231,
#    'loreo': 1,
#    'horo': 1,
#    'lorm': 1,
#    'lorw': 1,
#    'vloro': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f6'),
#   'word': 'antico',
#   'occurrences': {'antico': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f7'),
#   'word': 'condiscepolo',
#   'occurrences': {'condiscepolo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f8'),
#   'word': 'o',
#   'occurrences': {'o': 174}},
#  {'_id': ObjectId('60e574486e4986b0d41c62f9'),
#   'word': 'maestro',
#   'occurrences': {'maestro': 17, 'maastro': 1, 'maestrxo': 1, 'madstro': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62fa'),
#   'word': 'direttore',
#   'occurrences': {'direttore': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c62fb'),
#   'word': 'spirituale',
#   'occurrences': {'spirituale': 83, 'scpirituale': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62fc'),
#   'word': 'negli',
#   'occurrences': {'negli': 36}},
#  {'_id': ObjectId('60e574486e4986b0d41c62fd'),
#   'word': 'servizio',
#   'occurrences': {'servizio': 65, 'servieio': 1, 'wervizio': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c62fe'),
#   'word': 'poi',
#   'occurrences': {'poi': 83}},
#  {'_id': ObjectId('60e574486e4986b0d41c62ff'),
#   'word': 'nei',
#   'occurrences': {'nei': 121,
#    'neo': 1,
#    'aei': 1,
#    'hnei': 1,
#    'pei': 1,
#    'nsei': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6300'),
#   'word': '##',
#   'occurrences': {'##': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6301'),
#   'word': 'trascorse',
#   'occurrences': {'trascorse': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6302'),
#   'word': 'vari',
#   'occurrences': {'vari': 22, 'vaai': 1, 'vawri': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6303'),
#   'word': 'uffici',
#   'occurrences': {'uffici': 3, 'auffici': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6304'),
#   'word': 'ministeri',
#   'occurrences': {'ministeri': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6305'),
#   'word': 'affidatigli',
#   'occurrences': {'affidatigli': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6306'),
#   'word': 'dalla',
#   'occurrences': {'dalla': 153,
#    'dallla': 1,
#    'qalla': 1,
#    'dalja': 1,
#    'daella': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6307'),
#   'word': 'santa',
#   'occurrences': {'santa': 166,
#    'saqta': 1,
#    'sanrta': 1,
#    'xanta': 1,
#    'sankta': 1,
#    'swanta': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6308'),
#   'word': 'sede',
#   'occurrences': {'sede': 32}},
#  {'_id': ObjectId('60e574486e4986b0d41c6309'),
#   'word': 'non',
#   'occurrences': {'non': 529,
#    'npn': 1,
#    'nnn': 1,
#    'noa': 1,
#    'mnon': 1,
#    'noun': 1,
#    'don': 1,
#    'cnon': 1,
#    'nxon': 1,
#    'noon': 1,
#    'ion': 1,
#    'nojn': 1,
#    'qnon': 1,
#    'jon': 1,
#    'nan': 1,
#    'ntn': 1,
#    'npon': 1,
#    'notn': 1,
#    'nin': 1,
#    'vkon': 1,
#    'nog': 1,
#    'nhn': 1,
#    'unon': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c630a'),
#   'word': 'desiderò',
#   'occurrences': {'desiderò': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c630b'),
#   'word': 'altro',
#   'occurrences': {'altro': 31, 'altrl': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c630c'),
#   'word': 'essere',
#   'occurrences': {'essere': 106, 'essore': 1, 'esxsere': 1, 'eosere': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c630d'),
#   'word': 'amico',
#   'occurrences': {'amico': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c630e'),
#   'word': 'ciascuno',
#   'occurrences': {'ciascuno': 63, 'jciascuno': 1, 'ciancuno': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c630f'),
#   'word': 'grato',
#   'occurrences': {'grato': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6310'),
#   'word': 'saluto',
#   'occurrences': {'saluto': 32, 'salutg': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6311'),
#   'word': 'particolare',
#   'occurrences': {'particolare': 40, 'particolapre': 1, 'particolaee': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6312'),
#   'word': 'accento',
#   'occurrences': {'accento': 4, 'accefto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6313'),
#   'word': 'rispetto',
#   'occurrences': {'rispetto': 33, 'rispntto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6314'),
#   'word': 'affezione',
#   'occurrences': {'affezione': 8}},
#  {'_id': ObjectId('60e574486e4986b0d41c6315'),
#   'word': 'nobili',
#   'occurrences': {'nobili': 12, 'nocbili': 1, 'nobiali': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6316'),
#   'word': 'copiosi',
#   'occurrences': {'copiosi': 8}},
#  {'_id': ObjectId('60e574486e4986b0d41c6317'),
#   'word': 'rappresentanti',
#   'occurrences': {'rappresentanti': 14, 'rappresentanlti': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6318'),
#   'word': "dell\\'ordine",
#   'occurrences': {"dell\\'ordine": 15}},
#  {'_id': ObjectId('60e574486e4986b0d41c6319'),
#   'word': 'civico',
#   'occurrences': {'civico': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c631a'),
#   'word': 'sociale',
#   'occurrences': {'sociale': 56, 'vsociale': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c631b'),
#   'word': 'variamente',
#   'occurrences': {'variamente': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c631c'),
#   'word': 'disposti',
#   'occurrences': {'disposti': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c631d'),
#   'word': 'gradi',
#   'occurrences': {'gradi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c631e'),
#   'word': 'competenze',
#   'occurrences': {'competenze': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c631f'),
#   'word': 'attribuzioni',
#   'occurrences': {'attribuzioni': 5, 'attribuuzioni': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6320'),
#   'word': 'furono',
#   'occurrences': {'furono': 28, 'fursno': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6321'),
#   'word': 'sempre',
#   'occurrences': {'sempre': 211,
#    'sempge': 1,
#    'semprx': 1,
#    'sedpre': 1,
#    'semprpe': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6322'),
#   'word': 'cortesi',
#   'occurrences': {'cortesi': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6323'),
#   'word': 'amabili',
#   'occurrences': {'amabili': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6324'),
#   'word': 'verso',
#   'occurrences': {'verso': 62, 'vefso': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6325'),
#   'word': 'persona',
#   'occurrences': {'persona': 47, 'perwona': 1, 'npersona': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6326'),
#   'word': 'seminaristi',
#   'occurrences': {'seminaristi': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c6327'),
#   'word': 'riguardiamo',
#   'occurrences': {'riguardiamo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6328'),
#   'word': 'speciale',
#   'occurrences': {'speciale': 24, 'specialce': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6329'),
#   'word': 'predilezione',
#   'occurrences': {'predilezione': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c632a'),
#   'word': 'perchè',
#   'occurrences': {'perchè': 70, "perche'̀": 2, 'perschè': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c632b'),
#   'word': 'essi',
#   'occurrences': {'essi': 43, 'xessi': 1, 'essoi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c632c'),
#   'word': 'sono',
#   'occurrences': {'sono': 237, 'tono': 1, 'eono': 1, 'swono': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c632d'),
#   'word': 'fiore',
#   'occurrences': {'fiore': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c632e'),
#   'word': 'speranze',
#   'occurrences': {'speranze': 18}},
#  {'_id': ObjectId('60e574486e4986b0d41c632f'),
#   'word': 'belle',
#   'occurrences': {'belle': 10, 'belye': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6330'),
#   'word': '#',
#   'occurrences': {'#': 1015}},
#  {'_id': ObjectId('60e574486e4986b0d41c6331'),
#   'word': 'spes',
#   'occurrences': {'spes': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6332'),
#   'word': 'messis',
#   'occurrences': {'messis': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6333'),
#   'word': 'semine',
#   'occurrences': {'semine': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6334'),
#   'word': 'membri',
#   'occurrences': {'membri': 11, 'qmembri': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6335'),
#   'word': 'associazioni',
#   'occurrences': {'associazioni': 8}},
#  {'_id': ObjectId('60e574486e4986b0d41c6336'),
#   'word': 'cattoliche',
#   'occurrences': {'cattoliche': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c6337'),
#   'word': 'tutte',
#   'occurrences': {'tutte': 131,
#    'ztutte': 1,
#    'tustte': 1,
#    'tzutte': 1,
#    'lutte': 1,
#    'tkutte': 1,
#    'tuttle': 1,
#    'tptte': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6338'),
#   'word': 'altre',
#   'occurrences': {'altre': 38}},
#  {'_id': ObjectId('60e574486e4986b0d41c6339'),
#   'word': 'istituzioni',
#   'occurrences': {'istituzioni': 17}},
#  {'_id': ObjectId('60e574486e4986b0d41c633a'),
#   'word': 'qui',
#   'occurrences': {'qui': 194,
#    'qti': 1,
#    'quy': 1,
#    'qug': 1,
#    'qzui': 1,
#    'qup': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c633b'),
#   'word': 'convenuti',
#   'occurrences': {'convenuti': 14}},
#  {'_id': ObjectId('60e574486e4986b0d41c633c'),
#   'word': 'inoltre',
#   'occurrences': {'inoltre': 17}},
#  {'_id': ObjectId('60e574486e4986b0d41c633d'),
#   'word': 'fedeli',
#   'occurrences': {'fedeli': 71, 'fedeali': 1, 'fedeyli': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c633e'),
#   'word': 'poterono',
#   'occurrences': {'poterono': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c633f'),
#   'word': 'venire',
#   'occurrences': {'venire': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c6340'),
#   'word': 'roma',
#   'occurrences': {'roma': 152, 'rxoma': 1, 'romb': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6341'),
#   'word': 'agli',
#   'occurrences': {'agli': 56}},
#  {'_id': ObjectId('60e574486e4986b0d41c6342'),
#   'word': 'ammalati',
#   'occurrences': {'ammalati': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c6343'),
#   'word': 'sofferenti',
#   'occurrences': {'sofferenti': 13}},
#  {'_id': ObjectId('60e574486e4986b0d41c6344'),
#   'word': 'poveri',
#   'occurrences': {'poveri': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c6345'),
#   'word': 'tribolati',
#   'occurrences': {'tribolati': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6346'),
#   'word': 'nello',
#   'occurrences': {'nello': 25, 'nejllo': 1, 'naello': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6347'),
#   'word': 'bambini',
#   'occurrences': {'bambini': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c6348'),
#   'word': 'anziani',
#   'occurrences': {'anziani': 11}},
#  {'_id': ObjectId('60e574486e4986b0d41c6349'),
#   'word': 'abbraccio',
#   'occurrences': {'abbraccio': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c634a'),
#   'word': 'come',
#   'occurrences': {'come': 416,
#    'cope': 1,
#    'cobme': 1,
#    'comue': 1,
#    'kcome': 1,
#    'comce': 1,
#    'coime': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c634b'),
#   'word': 'sguardo',
#   'occurrences': {'sguardo': 21, 'swguardo': 1, 'sguarhdo': 1, 'oguardo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c634c'),
#   'word': 'va',
#   'occurrences': {'va': 21, 'voa': 1, 'ba': 1, 'vaa': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c634d'),
#   'word': 'cercare',
#   'occurrences': {'cercare': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c634e'),
#   'word': 'punti',
#   'occurrences': {'punti': 54, 'puntw': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c634f'),
#   'word': 'noi',
#   'occurrences': {'noi': 326,
#    'knoi': 1,
#    'nooi': 1,
#    'nwoi': 1,
#    'nki': 1,
#    'nuoi': 1,
#    'nof': 1,
#    'hnoi': 1,
#    'nofi': 1,
#    'nori': 1,
#    'qoi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6350'),
#   'word': 'noti',
#   'occurrences': {'noti': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6351'),
#   'word': 'cara',
#   'occurrences': {'cara': 19}},
#  {'_id': ObjectId('60e574486e4986b0d41c6352'),
#   'word': 'terra',
#   'occurrences': {'terra': 117,
#    'tejrra': 1,
#    'terrya': 1,
#    'tezrra': 1,
#    'perra': 1,
#    'terla': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6353'),
#   'word': 'natìa',
#   'occurrences': {'natìa': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6354'),
#   'word': 'dove',
#   'occurrences': {'dove': 65, 'doce': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6355'),
#   'word': 'un',
#   'occurrences': {'un': 397,
#    'run': 1,
#    'utn': 1,
#    'uzn': 2,
#    'uyn': 1,
#    'ui': 1,
#    'pun': 1,
#    'ugm': 1,
#    'xun': 1,
#    'vn': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6356'),
#   'word': 'tutto',
#   'occurrences': {'tutto': 188,
#    'ctutto': 1,
#    'tutgo': 1,
#    'tuctto': 1,
#    'tuttx': 1,
#    'ptutto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6357'),
#   'word': 'bello',
#   'occurrences': {'bello': 13}},
#  {'_id': ObjectId('60e574486e4986b0d41c6358'),
#   'word': 'degno',
#   'occurrences': {'degno': 10}},
#  {'_id': ObjectId('60e574486e4986b0d41c6359'),
#   'word': 'immutato',
#   'occurrences': {'immutato': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c635a'),
#   'word': 'immutabile',
#   'occurrences': {'immutabile': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c635b'),
#   'word': 'amore',
#   'occurrences': {'amore': 55}},
#  {'_id': ObjectId('60e574486e4986b0d41c635c'),
#   'word': 'mistero',
#   'occurrences': {'mistero': 30}},
#  {'_id': ObjectId('60e574486e4986b0d41c635d'),
#   'word': 'misericordia',
#   'occurrences': {'misericordia': 25}},
#  {'_id': ObjectId('60e574486e4986b0d41c635e'),
#   'word': 'avvolge',
#   'occurrences': {'avvolge': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c635f'),
#   'word': 'nulla',
#   'occurrences': {'nulla': 20, 'nutlla': 1, 'nulyla': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6360'),
#   'word': 'toglie',
#   'occurrences': {'toglie': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6361'),
#   'word': 'alla',
#   'occurrences': {'alla': 583,
#    'alila': 1,
#    'alda': 1,
#    'aclla': 1,
#    'acla': 1,
#    'allsa': 1,
#    'illa': 1,
#    'allq': 1,
#    'falla': 1,
#    'alhla': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6362'),
#   'word': 'umiltà',
#   'occurrences': {'umiltà': 14, 'umdiltà': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6363'),
#   'word': 'povertà',
#   'occurrences': {'povertà': 9, 'poxertà': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6364'),
#   'word': 'neppure',
#   'occurrences': {'neppure': 4, 'naeppure': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6365'),
#   'word': 'impedisce',
#   'occurrences': {'impedisce': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6366'),
#   'word': 'entrare',
#   'occurrences': {'entrare': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6367'),
#   'word': 'cantico',
#   'occurrences': {'cantico': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c6368'),
#   'word': 'ringraziamento',
#   'occurrences': {'ringraziamento': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c6369'),
#   'word': 'da',
#   'occurrences': {'da': 475,
#    'sa': 1,
#    'dea': 1,
#    'wda': 1,
#    'dh': 1,
#    'dr': 1,
#    'ja': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c636a'),
#   'word': 'parecchi',
#   'occurrences': {'parecchi': 12}},
#  {'_id': ObjectId('60e574486e4986b0d41c636b'),
#   'word': 'giorni',
#   'occurrences': {'giorni': 48, 'giorhi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c636c'),
#   'word': 'levate',
#   'occurrences': {'levate': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c636d'),
#   'word': 'intorno',
#   'occurrences': {'intorno': 44}},
#  {'_id': ObjectId('60e574486e4986b0d41c636e'),
#   'word': 'altari',
#   'occurrences': {'altarj': 1, 'altari': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c636f'),
#   'word': 'serena',
#   'occurrences': {'serena': 19}},
#  {'_id': ObjectId('60e574486e4986b0d41c6370'),
#   'word': 'vostre',
#   'occurrences': {'vostre': 49, 'vohstre': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6371'),
#   'word': 'case',
#   'occurrences': {'case': 15}},
#  {'_id': ObjectId('60e574486e4986b0d41c6372'),
#   'word': 'ricordo',
#   'occurrences': {'ricordo': 42, 'ricoordo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6373'),
#   'word': 'vostro',
#   'occurrences': {'vostro': 44, 'kostro': 1, 'jostro': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6374'),
#   'word': 'concittadino',
#   'occurrences': {'concittadino': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6375'),
#   'word': 'solcata',
#   'occurrences': {'solcata': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6376'),
#   'word': 'prodigi',
#   'occurrences': {'prodigi': 6}},
#  {'_id': ObjectId('60e574486e4986b0d41c6377'),
#   'word': 'pietà',
#   'occurrences': {'pietà': 57, 'zpietà': 1, 'piestà': 1, 'pijtà': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6378'),
#   'word': 'religiosa',
#   'occurrences': {'religiosa': 55, 'religioba': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6379'),
#   'word': 'sentita',
#   'occurrences': {'sentita': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c637a'),
#   'word': 'generosità',
#   'occurrences': {'generosità': 9}},
#  {'_id': ObjectId('60e574486e4986b0d41c637b'),
#   'word': 'operosa',
#   'occurrences': {'operosa': 9, 'operoka': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c637c'),
#   'word': 'costante',
#   'occurrences': {'costante': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c637d'),
#   'word': 'questa',
#   'occurrences': {'questa': 404,
#    'iuesta': 2,
#    'aquesta': 1,
#    'questca': 1,
#    'hquesta': 1,
#    'queata': 1,
#    'quesga': 1,
#    'quvsta': 1,
#    'quests': 1,
#    'questz': 1,
#    'qeuesta': 1,
#    'qquesta': 1,
#    'qluesta': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c637e'),
#   'word': 'volta',
#   'occurrences': {'volta': 35, 'voltz': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c637f'),
#   'word': 'fece',
#   'occurrences': {'fece': 18, 'fedce': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6380'),
#   'word': "l\\'antico",
#   'occurrences': {"l\\'antico": 5, 'l\\antico': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6381'),
#   'word': 'popolo',
#   'occurrences': {'popolo': 105}},
#  {'_id': ObjectId('60e574486e4986b0d41c6382'),
#   'word': 'traendo',
#   'occurrences': {'traendo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6383'),
#   'word': 'piccolo',
#   'occurrences': {'piccolo': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c6384'),
#   'word': 'davide',
#   'occurrences': {'davide': 5}},
#  {'_id': ObjectId('60e574486e4986b0d41c6385'),
#   'word': 'dai',
#   'occurrences': {'dai': 69, 'pai': 1, 'daji': 1, 'dav': 1, 'dvi': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6386'),
#   'word': 'pastori',
#   'occurrences': {'pastori': 11}},
#  {'_id': ObjectId('60e574486e4986b0d41c6387'),
#   'word': 'betlemme',
#   'occurrences': {'betlemme': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c6388'),
#   'word': 'abbia',
#   'occurrences': {'abbia': 20}},
#  {'_id': ObjectId('60e574486e4986b0d41c6389'),
#   'word': 'scelto',
#   'occurrences': {'scelto': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c638a'),
#   'word': 'nuovo',
#   'occurrences': {'nuovo': 70, 'cnuovo': 1, 'snuovo': 1, 'nyuovo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c638b'),
#   'word': 'sommo',
#   'occurrences': {'sommo': 14}},
#  {'_id': ObjectId('60e574486e4986b0d41c638c'),
#   'word': 'pontefice',
#   'occurrences': {'pontefice': 34, 'pontefgce': 1, 'pongtefice': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c638d'),
#   'word': 'facendolo',
#   'occurrences': {'facendolo': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c638e'),
#   'word': 'depositario',
#   'occurrences': {'depositario': 3, 'depositwario': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c638f'),
#   'word': 'grande',
#   'occurrences': {'grande': 207,
#    'granne': 1,
#    'grandke': 1,
#    'grandse': 1,
#    'granmde': 1,
#    'graande': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6390'),
#   'word': 'tradizione',
#   'occurrences': {'tradizione': 28}},
#  {'_id': ObjectId('60e574486e4986b0d41c6391'),
#   'word': 'apostolica',
#   'occurrences': {'apostolica': 65, 'bpostolica': 1, 'apcostolica': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6392'),
#   'word': 'suggellata',
#   'occurrences': {'suggellata': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c6393'),
#   'word': 'dal',
#   'occurrences': {'dal': 172, 'kdal': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6394'),
#   'word': 'sangue',
#   'occurrences': {'sangue': 40, 'sancgue': 1, 'sakngue': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6395'),
#   'word': 'figliolo',
#   'occurrences': {'figliolo': 3}},
#  {'_id': ObjectId('60e574486e4986b0d41c6396'),
#   'word': 'tale',
#   'occurrences': {'tale': 45, 'taxle': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6397'),
#   'word': 'avvenimento',
#   'occurrences': {'avvenimento': 26, 'avhvenimento': 1, 'zvvenimento': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c6398'),
#   'word': 'parliamo',
#   'occurrences': {'parliamo': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c6399'),
#   'word': 'obbligarci',
#   'occurrences': {'obbligarci': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c639a'),
#   'word': 'sciogliere',
#   'occurrences': {'sciogliere': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c639b'),
#   'word': 'calzari',
#   'occurrences': {'calzari': 2}},
#  {'_id': ObjectId('60e574486e4986b0d41c639c'),
#   'word': "nell\\'atto",
#   'occurrences': {"nell\\'atto": 8, "nell\\i'atto": 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c639d'),
#   'word': 'procedere',
#   'occurrences': {'procedere': 4}},
#  {'_id': ObjectId('60e574486e4986b0d41c639e'),
#   'word': 'roveto',
#   'occurrences': {'roveto': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c639f'),
#   'word': 'ardente',
#   'occurrences': {'ardente': 17}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a0'),
#   'word': 'carità',
#   'occurrences': {'carità': 113, 'sarità': 1, 'cjarità': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a1'),
#   'word': 'divina',
#   'occurrences': {'divina': 60, 'dikina': 1, 'divira': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a2'),
#   'word': 'attende',
#   'occurrences': {'attende': 13}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a3'),
#   'word': 'consuma',
#   'occurrences': {'consuma': 1}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a4'),
#   'word': 'constatare',
#   'occurrences': {'constatare': 7}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a5'),
#   'word': 'manifestazione',
#   'occurrences': {'manifestazione': 17}},
#  {'_id': ObjectId('60e574486e4986b0d41c63a6'),
#   'word': 'bontà',
#   'occurrences': {'bontà': 29, 'bontl̀': 1, 'bontav': 1}},
# ...
#  {'_id': ObjectId('60e574496e4986b0d41c65ae'),
#   'word': 'giornata',
#   'occurrences': {'giornata': 22}},
#  {'_id': ObjectId('60e574496e4986b0d41c65af'),
#   'word': 'ricordi',
#   'occurrences': {'ricordi': 30}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b0'),
#   'word': 'immacolata',
#   'occurrences': {'immacolata': 26}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b1'),
#   'word': 'fanno',
#   'occurrences': {'fanno': 15}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b2'),
#   'word': 'esaltare',
#   'occurrences': {'esaltare': 5}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b3'),
#   'word': 'tempio',
#   'occurrences': {'tempio': 35}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b4'),
#   'word': 'vaticano',
#   'occurrences': {'vaticano': 50, 'vaticgno': 1, 'vaticfano': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b5'),
#   'word': 'quando',
#   'occurrences': {'quando': 47, 'quanddo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b6'),
#   'word': '1\\',
#   'occurrences': {'1\\': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b7'),
#   'word': "'",
#   'occurrences': {"'": 38}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b8'),
#   'word': '18##',
#   'occurrences': {'18##': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65b9'),
#   'word': 'ix',
#   'occurrences': {'ix': 21, 'vx': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ba'),
#   'word': 'leggeva',
#   'occurrences': {'leggeva': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65bb'),
#   'word': 'bolla',
#   'occurrences': {'bolla': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c65bc'),
#   'word': 'definizione',
#   'occurrences': {'definizione': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c65bd'),
#   'word': 'dogmatica',
#   'occurrences': {'dogmatica': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65be'),
#   'word': 'raggio',
#   'occurrences': {'raggio': 7}},
#  {'_id': ObjectId('60e574496e4986b0d41c65bf'),
#   'word': 'sole',
#   'occurrences': {'sole': 8, 'solre': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c0'),
#   'word': 'irruppe',
#   'occurrences': {'irruppe': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c1'),
#   'word': 'avvolse',
#   'occurrences': {'avvolse': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c2'),
#   'word': 'luce',
#   'occurrences': {'luce': 103, 'lucq': 1, 'luse': 1, 'juce': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c3'),
#   'word': 'madre',
#   'occurrences': {'madre': 88, 'madge': 1, 'mmadre': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c4'),
#   'word': 'celeste',
#   'occurrences': {'celeste': 56, 'chleste': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c5'),
#   'word': 'diffonde',
#   'occurrences': {'diffonde': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c6'),
#   'word': 'trasmette',
#   'occurrences': {'trasmette': 2, 'trasmlette': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c7'),
#   'word': 'letizia',
#   'occurrences': {'letizia': 48, 'letizim': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c8'),
#   'word': 'rafforza',
#   'occurrences': {'rafforza': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65c9'),
#   'word': 'buone',
#   'occurrences': {'buone': 32, 'ruone': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ca'),
#   'word': 'volontà',
#   'occurrences': {'volontà': 44, 'uolontà': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65cb'),
#   'word': 'affratella',
#   'occurrences': {'affratella': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c65cc'),
#   'word': 'animi',
#   'occurrences': {'animi': 15}},
#  {'_id': ObjectId('60e574496e4986b0d41c65cd'),
#   'word': 'rammentiamo',
#   'occurrences': {'rammentiamo': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ce'),
#   'word': "l\\'altro",
#   'occurrences': {"l\\'altro": 11, "y\\'altro": 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65cf'),
#   'word': 'celebrando',
#   'occurrences': {'celebrando': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d0'),
#   'word': 'mezzo',
#   'occurrences': {'mezzo': 29, 'mezzu': 1, 'mekzo': 1, 'cezzo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d1'),
#   'word': 'secolo',
#   'occurrences': {'secolo': 35, 'secmolo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d2'),
#   'word': 'quella',
#   'occurrences': {'quella': 104, 'qquella': 1, 'quelqa': 1, 'qullla': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d3'),
#   'word': 'proclamazione',
#   'occurrences': {'proilamazione': 1,
#    'proeclamazione': 1,
#    'proclamazione': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d4'),
#   'word': 'apparve',
#   'occurrences': {'apparve': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d5'),
#   'word': 'giovanissimo',
#   'occurrences': {'giovanissimo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d6'),
#   'word': 'emanazione',
#   'occurrences': {'emanazione': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d7'),
#   'word': 'dissipò',
#   'occurrences': {'dissipò': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d8'),
#   'word': 'volto',
#   'occurrences': {'volto': 17}},
#  {'_id': ObjectId('60e574496e4986b0d41c65d9'),
#   'word': 'traccia',
#   'occurrences': {'traccia': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65da'),
#   'word': 'preoccupazione',
#   'occurrences': {'preoccupazione': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c65db'),
#   'word': 'gravi',
#   'occurrences': {'gravi': 28, 'gravni': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65dc'),
#   'word': 'interessi',
#   'occurrences': {'interessi': 8}},
#  {'_id': ObjectId('60e574496e4986b0d41c65dd'),
#   'word': 'rese',
#   'occurrences': {'rese': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c65de'),
#   'word': 'splendente',
#   'occurrences': {'splendente': 17, 'splendentx': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65df'),
#   'word': 'quello',
#   'occurrences': {'quello': 51}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e0'),
#   'word': 'mosè',
#   'occurrences': {'mosè': 5}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e1'),
#   'word': 'sul',
#   'occurrences': {'sul': 71}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e2'),
#   'word': 'sinai',
#   'occurrences': {'sinai': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e3'),
#   'word': 'conforto',
#   'occurrences': {'conforto': 31, 'ccnforto': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e4'),
#   'word': 'benedizione',
#   'occurrences': {'benedizione': 75,
#    'bcenedizione': 1,
#    'benedizionne': 1,
#    'benedixione': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e5'),
#   'word': 'lei',
#   'occurrences': {'lei': 20, 'glei': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e6'),
#   'word': 'prepararci',
#   'occurrences': {'prepararci': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e7'),
#   'word': 'attendevano',
#   'occurrences': {'attendevano': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e8'),
#   'word': "quest\\'ultimo",
#   'occurrences': {"quest\\'ultimo": 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65e9'),
#   'word': 'margine',
#   'occurrences': {'margine': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ea'),
#   'word': 'volle',
#   'occurrences': {'volle': 12}},
#  {'_id': ObjectId('60e574496e4986b0d41c65eb'),
#   'word': 'riservato',
#   'occurrences': {'riservato': 10}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ec'),
#   'word': 'singolare',
#   'occurrences': {'singolare': 23, 'sintgolare': 1, 'sinxolare': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ed'),
#   'word': 'consacrare',
#   'occurrences': {'consacrare': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ee'),
#   'word': 'lourdes',
#   'occurrences': {'lourdes': 17}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ef'),
#   'word': 'vastissimo',
#   'occurrences': {'vastissimo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f0'),
#   'word': 'sotterraneo',
#   'occurrences': {'sotterraneo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f1'),
#   'word': 'congiunge',
#   'occurrences': {'congiunge': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f2'),
#   'word': 'unico',
#   'occurrences': {'unico': 10}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f3'),
#   'word': 'palpito',
#   'occurrences': {'palpito': 14}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f4'),
#   'word': 'entusiasmo',
#   'occurrences': {'entusiasmo': 7}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f5'),
#   'word': 'x#',
#   'occurrences': {'x#': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f6'),
#   'word': 'offrire',
#   'occurrences': {'offrire': 18}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f7'),
#   'word': 'redenti',
#   'occurrences': {'redenti': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f8'),
#   'word': 'eleva',
#   'occurrences': {'eleva': 6}},
#  {'_id': ObjectId('60e574496e4986b0d41c65f9'),
#   'word': 'divenuta',
#   'occurrences': {'divenuta': 8}},
#  {'_id': ObjectId('60e574496e4986b0d41c65fa'),
#   'word': 'supplicazione',
#   'occurrences': {'supplicazione': 8}},
#  {'_id': ObjectId('60e574496e4986b0d41c65fb'),
#   'word': 'affinche#',
#   'occurrences': {'affinche#': 72,
#    'afjfinche#': 1,
#    'affinch##': 1,
#    'agffinche#': 1,
#    "affinche'#": 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65fc'),
#   'word': 'ottenga',
#   'occurrences': {'ottenga': 9}},
#  {'_id': ObjectId('60e574496e4986b0d41c65fd'),
#   'word': 'sovrabbondanza',
#   'occurrences': {'sovrabbondanza': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c65fe'),
#   'word': 'favori',
#   'occurrences': {'favori': 8}},
#  {'_id': ObjectId('60e574496e4986b0d41c65ff'),
#   'word': 'fiducioso',
#   'occurrences': {'fiducioso': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6600'),
#   'word': 'abbandono',
#   'occurrences': {'abbandono': 7}},
#  {'_id': ObjectId('60e574496e4986b0d41c6601'),
#   'word': 'preservi',
#   'occurrences': {'preservi': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c6602'),
#   'word': 'pericoli',
#   'occurrences': {'pericoli': 6}},
#  {'_id': ObjectId('60e574496e4986b0d41c6603'),
#   'word': 'futuri',
#   'occurrences': {'futuri': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c6604'),
#   'word': 'costruire',
#   'occurrences': {'costruire': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c6605'),
#   'word': 'sabbia',
#   'occurrences': {'sabbia': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6606'),
#   'word': "dell\\'agitarci",
#   'occurrences': {"dell\\'agitarci": 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6607'),
#   'word': 'invano',
#   'occurrences': {'invano': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c6608'),
#   'word': 'piuttosto',
#   'occurrences': {'piuttosto': 14}},
#  {'_id': ObjectId('60e574496e4986b0d41c6609'),
#   'word': 'chiarifichi',
#   'occurrences': {'chiarifichi': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c660a'),
#   'word': 'menti',
#   'occurrences': {'menti': 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c660b'),
#   'word': 'purifichi',
#   'occurrences': {'purifichi': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c660c'),
#   'word': 'dia',
#   'occurrences': {'dia': 9, 'dka': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c660d'),
#   'word': 'sicurezza',
#   'occurrences': {'sicurezza': 27}},
#  {'_id': ObjectId('60e574496e4986b0d41c660e'),
#   'word': 'passi',
#   'occurrences': {'passi': 13}},
#  {'_id': ObjectId('60e574496e4986b0d41c660f'),
#   'word': "l\\'avvento",
#   'occurrences': {"l\\'avvento": 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c6610'),
#   'word': 'regno',
#   'occurrences': {'regno': 37}},
#  {'_id': ObjectId('60e574496e4986b0d41c6611'),
#   'word': 'sulle',
#   'occurrences': {'sulle': 50, 'suale': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6612'),
#   'word': 'singole',
#   'occurrences': {'singole': 15, 'syngole': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6613'),
#   'word': 'religiose',
#   'occurrences': {'religiose': 23, 'relvgiose': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6614'),
#   'word': 'civiche',
#   'occurrences': {'civiche': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6615'),
#   'word': "sull\\'intera",
#   'occurrences': {"sull\\'intera": 2}},
#  {'_id': ObjectId('60e574496e4986b0d41c6616'),
#   'word': 'umanità',
#   'occurrences': {'umanità': 15}},
#  {'_id': ObjectId('60e574496e4986b0d41c6617'),
#   'word': 'messa',
#   'occurrences': {'messa': 25, 'messq': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6618'),
#   'word': "nell\\'arcibasilica",
#   'occurrences': {"nell\\'arcibasilica": 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c6619'),
#   'word': 'lateranense',
#   'occurrences': {'lateranense': 11}},
#  {'_id': ObjectId('60e574496e4986b0d41c661a'),
#   'word': 'domenica',
#   'occurrences': {'domenica': 132,
#    'domenaica': 1,
#    'domcngica': 1,
#    'domenifa': 1,
#    'domeniqca': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c661b'),
#   'word': '2#',
#   'occurrences': {'2#': 7, '2i': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c661c'),
#   'word': 'novembre',
#   'occurrences': {'novembre': 29, 'lnovembre': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c661d'),
#   'word': '19#8',
#   'occurrences': {'19#8': 7}},
#  {'_id': ObjectId('60e574496e4986b0d41c661e'),
#   'word': 'venerabili',
#   'occurrences': {'venerabili': 84,
#    'venegabili': 1,
#    'henerabili': 1,
#    'vehnerabili': 1,
#    'vjnerabili': 1,
#    'venerabeli': 1,
#    'venerafbili': 1,
#    'zenerabili': 1,
#    'venerabila': 1,
#    'venerambili': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c661f'),
#   'word': 'scambiato',
#   'occurrences': {'scambiato': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6620'),
#   'word': 'soglie',
#   'occurrences': {'soglie': 6}},
#  {'_id': ObjectId('60e574496e4986b0d41c6621'),
#   'word': 'cattedrale',
#   'occurrences': {'cattedrale': 5}},
#  {'_id': ObjectId('60e574496e4986b0d41c6622'),
#   'word': 'signor',
#   'occurrences': {'signor': 10, 'sdignor': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6623'),
#   'word': 'cardinale',
#   'occurrences': {'cardinale': 32, 'cardinalae': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6624'),
#   'word': 'arciprete',
#   'occurrences': {'arciprete': 3}},
#  {'_id': ObjectId('60e574496e4986b0d41c6625'),
#   'word': 'amiamo',
#   'occurrences': {'amiamo': 29, 'admiamo': 1, 'amtiamo': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6626'),
#   'word': 'aggiungere',
#   'occurrences': {'aggiungere': 8}},
#  {'_id': ObjectId('60e574496e4986b0d41c6627'),
#   'word': 'edificazione',
#   'occurrences': {'edificazione': 29}},
#  {'_id': ObjectId('60e574496e4986b0d41c6628'),
#   'word': 'tre',
#   'occurrences': {'tre': 41}},
#  {'_id': ObjectId('60e574496e4986b0d41c6629'),
#   'word': 'pensieri',
#   'occurrences': {'pensieri': 30, 'pensierm': 1, 'pensierj': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c662a'),
#   'word': 'vorremmo',
#   'occurrences': {'vorremmo': 11}},
#  {'_id': ObjectId('60e574496e4986b0d41c662b'),
#   'word': 'pervenissero',
#   'occurrences': {'pervenissero': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c662c'),
#   'word': 'eco',
#   'occurrences': {'eco': 12}},
#  {'_id': ObjectId('60e574496e4986b0d41c662d'),
#   'word': 'due',
#   'occurrences': {'due': 89, 'dpue': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c662e'),
#   'word': 'solenni',
#   'occurrences': {'solenni': 17, 'soqenni': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c662f'),
#   'word': 'voci',
#   'occurrences': {'voci': 24}},
#  {'_id': ObjectId('60e574496e4986b0d41c6630'),
#   'word': 'risuonarono',
#   'occurrences': {'risuonarono': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6631'),
#   'word': 'sommi',
#   'occurrences': {'sommi': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6632'),
#   'word': 'pontefici',
#   'occurrences': {'pontefici': 13, 'pontefqici': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6633'),
#   'word': 'leone',
#   'occurrences': {'leone': 42, 'leonye': 1, 'lleone': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6634'),
#   'word': 'gregorio',
#   'occurrences': {'gregorio': 29, 'gvegorio': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6635'),
#   'word': 'gloriosi',
#   'occurrences': {'gloriosi': 9}},
#  {'_id': ObjectId('60e574496e4986b0d41c6636'),
#   'word': 'ambedue',
#   'occurrences': {'ambedue': 4, 'nambedue': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c6637'),
#   'word': 'dottori',
#   'occurrences': {'dottori': 11}},
#  {'_id': ObjectId('60e574496e4986b0d41c6638'),
#   'word': 'padri',
#   'occurrences': {'padri': 26}},
#  {'_id': ObjectId('60e574496e4986b0d41c6639'),
#   'word': 'riflette',
#   'occurrences': {'riflette': 4}},
#  {'_id': ObjectId('60e574496e4986b0d41c663a'),
#   'word': 'rito',
#   'occurrences': {'rito': 49, 'qito': 1}},
#  {'_id': ObjectId('60e574496e4986b0d41c663b'),
#   'word': 'odierno',
#   'occurrences': {'odierno': 10}},
#  {'_id': ObjectId('60e574496e4986b0d41c663c'),
#   'word': 'alta',
#   'occurrences': {'alta': 22, 'ahta': 1, 'altoa': 2}},
#  ...]
